# %% [markdown]
# # Contents and why we need this lab
#
# This lab is about implementing neural networks yourself before we start using other frameworks that hide some computation from you. It builds on the first lab, where you derived the equations for neural network forward and backward propagation and gradient descent parameter updates.
#
# All the frameworks for deep learning you will meet from now on use automatic differentiation (autodiff), so you do not have to code the backward step yourself. In this version of this lab, you will develop your own autodif implementation.

# %% [markdown]
# # External source of information
#
# [Nanograd](https://github.com/rasmusbergpalm/nanograd) is a minimalistic version of autodiff developed by [Rasmus Berg Palm](https://rasmusbergpalm.github.io) that we use for our framework.

# %% [markdown]
# # This notebook will follow the next steps:
#
# 1. Nanograd automatic differentiation framework
# 2. Finite difference method
# 3. Data generation
# 4. Defining and initializing the network
# 5. Forward pass
# 6. Training loop
# 7. Testing your model
# 8. Further extensions

# %% [markdown]
# # Nanograd automatic differention framework

# %% [markdown]
# The [Nanograd](https://github.com/rasmusbergpalm/nanograd) framework defines a class Var which both holds a value and gradient value that we can use to store the intermediate values when we apply the chain rule of differentiation.

# %%
# Copy and pasted from https://github.com/rasmusbergpalm/nanograd/blob/3a1bf9e9e724da813bfccf91a6f309abdade9f39/nanograd.py

from math import exp, log

class Var:
    """
    A variable which holds a float and enables gradient computations.
    """

    def __init__(self, val: float, grad_fn=lambda: []):
        assert type(val) == float
        self.v = val
        self.grad_fn = grad_fn
        self.grad = 0.0

    def backprop(self, bp):
        self.grad += bp
        for input, grad in self.grad_fn():
            input.backprop(grad * bp)

    def backward(self):
        self.backprop(1.0)

    def __add__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v + other.v, lambda: [(self, 1.0), (other, 1.0)])

    def __mul__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v * other.v, lambda: [(self, other.v), (other, self.v)])

    def __pow__(self, power):
        assert type(power) in {float, int}, "power must be float or int"
        return Var(self.v ** power, lambda: [(self, power * self.v ** (power - 1))])

    def __neg__(self: 'Var') -> 'Var':
        return Var(-1.0) * self

    def __sub__(self: 'Var', other: 'Var') -> 'Var':
        return self + (-other)

    def __truediv__(self: 'Var', other: 'Var') -> 'Var':
        return self * other ** -1

    def __repr__(self):
        return "Var(v=%.4f, grad=%.4f)" % (self.v, self.grad)

    def relu(self):
        return Var(self.v if self.v > 0.0 else 0.0, lambda: [(self, 1.0 if self.v > 0.0 else 0.0)])
    
    # * Changes from part f)
    def identity(self):
        return Var(self.v, lambda: [(self, 1)])
    
    def tanh(self):
        return Var((exp(self.v)-exp(-self.v))/(exp(self.v)+exp(-self.v)), lambda: [(self, 1-((exp(self.v)-exp(-self.v))/(exp(self.v)+exp(-self.v)))**2)])
    
    def sigmoid(self):
        return Var(1/(1+exp(-self.v)), lambda: [(self, (1/(1+exp(-self.v)))*(1-(1/(1+exp(-self.v)))))])
    
    # * CHanges from part k)
    def exp(self):
        return Var(exp(self.v), lambda: [(self, exp(self.v))])
    
    def log(self):
        return Var(log(self.v), lambda: [(self, self.v ** -1)])

# %% [markdown]
# A few examples illustrate how we can use this:

# %%
a = Var(3.0)
b = Var(5.0)
f = a * b

f.backward()

for v in [a, b, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=5.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)

# %%
a = Var(3.0)
b = Var(5.0)
c = a * b
d = Var(9.0)
e = a * d
f = c + e

f.backward()

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=14.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)
# Var(v=9.0000, grad=3.0000)
# Var(v=27.0000, grad=1.0000)
# Var(v=42.0000, grad=1.0000)

# %% [markdown]
# ## Exercise a) What is being calculated?
#
# Explain briefly the output of the code? What is the expression we differentiate and with respect to what variables?

# %% [markdown]
# **Answer:**
#
# The `Var` class is a class which stores a value, and overloads various operators such that when we perform operations on other instances of `Var`, a new instance of `Var` is returned containing both the calculated value, as well as a lambda function of the resulting gradient from the operation. When we then define chains of operations using our `Var` instances, we get a graph structure that we can iterate over by running the `.backward()` method which updates the gradient of every `Var` in the graph.
# <br> We're given two expressions. For the first one, `a` and `b` are both assigned to a `Var` with their respective values of 3 and 5. `f` is defined to be `a*b`. The calculated value of `f` is 15, while the gradient of `a = 5` and the gradient of `b=3`.
# <br> The following examples appears to be a continuation of the first expression, now with `c = a*b` and `d = Var(9.0)` with `e = a*d`, `f = c+e`. Running the `.backward()` method again we find the gradient of each variable with respect to `f`.

# %% [markdown]
# ## Exercise b) How does the backward function work?
#
# You need to understand how the backward function calculates the gradients. We can use the two examples above to help with that.
#
# Go through the following four steps and answer the questions on the way:
#
# 1. We represent the two expressions as graphs as shown below. Fill in the missing expressions for the different derivatives.
#
# 2. In the remainder, consider the first expression. Make a schematic of the data structure generated when we define the expression for f (e.g., write a list of which objects are created and the corresponding values of their member variables).
#
# 3. Then execute the backward function by hand to convince yourself that it indeed calculates the gradients with respect to the variables.
#
# 4. Write down the sequence of calls to backprop.

# %%
# If you have not installed networkx and matplotlib, you can install them by running
# !pip install networkx matplotlib

import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create a directed graph
G = nx.DiGraph()

# Add edges with labels
G.add_edge('a', 'f', label='df/da=d(ab)/da=b=5')
G.add_edge('b', 'f', label='df/db=d(ab)/db=a=3')

# Manually define positions for a tree layout
pos = {
    'a': (0, 1),
    'b': (0, -1),
    'f': (1, 0),
}
# Draw the graph nodes and edges
nx.draw(G, pos, with_labels=True, node_shape='o', node_size=3000, node_color='lightblue', arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.title("Graph of example one")
plt.show()

# %%
# Create a directed graph
G = nx.DiGraph()

# Add edges with labels
G.add_edge('a', 'f', label='df/da=(df/dc)(dc/da)+(df/de)(de/da)=1*b+1*d=14')
G.add_edge('b', 'f', label='df/db=(df/dc)(dc/db))=1*a=3')

# Manually define positions for a tree layout
pos = {
    'a': (0, 1),
    'b': (0, -1),
    'f': (1, 0),
}
# Draw the graph nodes and edges
nx.draw(G, pos, with_labels=True, node_shape='o', node_size=3000, node_color='lightblue', arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.title("Graph of example two")
plt.show()

# %%
# Create a directed graph
G = nx.DiGraph()

# Add edges with labels
G.add_edge('a', 'c', label='dc/da=d(ab)/a=b=5')
G.add_edge('b', 'c', label='dc/db=d(ab)/db=a=3')
G.add_edge('a', 'e', label='de/da=d(ad)/da=d=9')
G.add_edge('d', 'e', label='de/dd=d(ad)/dd=a=3')
G.add_edge('c', 'f', label='df/dc=d(c+e)/dc=1')
G.add_edge('e', 'f', label='df/de=d(c+e)/de=1')

# Manually define positions for a tree layout
pos = {
    'a': (0, 0),
    'b': (0, 2),
    'c': (1, 1),
    'd': (0, -2),
    'e': (1, -1),
    'f': (2, 0)
}

# Draw the graph nodes and edges
nx.draw(G, pos, with_labels=True, node_shape='o', node_size=3000, node_color='lightblue', arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.title("Graph of example two")
plt.show()

# %% [markdown]
# <br> In the two cells below the `Var` class definition, we have two examples for how to use the `Var` class. In the first example, the following expression is defined:
# $$
# \begin{align}
# f = ab \quad \text{with a = 3, \ and b = 5}
# \end{align}
# $$
# The gradient is automatically calculated by the class when we call the `.backward()` method. This is the computation being performed:
# $$
# \begin{align}
# \text{Example 1:} & \\
# & \text{f.grad} = \frac{\partial f}{\partial f} = \frac{\partial (ab)}{\partial (ab)} = 1 \\
# & \text{b.grad} = \frac{\partial f}{\partial b} = \frac{\partial (ab)}{\partial b} = a = 3 \\
# & \text{a.grad} = \frac{\partial f}{\partial a} = \frac{\partial (ab)}{\partial a} = b = 5 \\
#
# \end{align}
# $$

# %% [markdown]
# For the next example, we perform a calculation defined by this expression:
# $$
# \begin{align}
# & c = ab, \quad e = ad, \quad f = c + e \quad \text{Or, equivalently} \quad f = a(b+d) \\
# & \text{With} \quad a = 3, \quad b = 5,\quad d = 9 \\
# \end{align}
# $$
# The result is this:
# $$
# \begin{align}
# \text{Example 2:} & \\
# \text{f.grad} &= \dfrac{\partial f}{\partial f} = \dfrac{\partial (c+e)}{\partial (c+e)} = 1 \\
# \text{e.grad}&= \dfrac{\partial f}{\partial e} = \dfrac{\partial (c+e)}{\partial e} = 1\\
# \text{c.grad} &= \dfrac{\partial f}{\partial c} = \dfrac{\partial (c+e)}{\partial c} = 1\\
# \text{d.grad} &= \dfrac{\partial f}{\partial b} = \dfrac{\partial f}{\partial e}\dfrac{\partial e}{\partial d} = \dfrac{\partial (c+e)}{\partial e}\dfrac{\partial ad}{\partial d} = a = 3\\
# \text{b.grad} &= \dfrac{\partial f}{\partial b} = \dfrac{\partial f}{\partial c}\dfrac{\partial c}{\partial b} = \dfrac{\partial (c+e)}{\partial c}\dfrac{\partial ab}{\partial b} = a = 3\\
# \text{a.grad} &= \dfrac{\partial f}{\partial a} = \dfrac{\partial f}{\partial c}\dfrac{\partial c}{\partial a}+\dfrac{\partial f}{\partial e}\dfrac{\partial e}{\partial a} = \dfrac{\partial (c+e)}{\partial c}\dfrac{\partial ab}{\partial a}+\dfrac{\partial (c+e)}{\partial e}\dfrac{\partial ad}{\partial a} = 1\cdot b + 1\cdot d = 5 + 9 = 14
# \end{align}
# $$

# %% [markdown]
# ## Exercise c) What happens if we run backward again?
#
# Try to execute the code below. Explain what happens.

# %%
f.backward()

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=28.0000)
# Var(v=5.0000, grad=6.0000)
# Var(v=15.0000, grad=2.0000)
# Var(v=9.0000, grad=6.0000)
# Var(v=27.0000, grad=2.0000)
# Var(v=42.0000, grad=2.0000)

# %% [markdown]
# **Answer:**
# <br>
# We see that the value remains the same as before, but the gradient is applied once more. Running it once more we can understand that the result of the gradient calculation is seemingly added again for every execution. In other words, since we only run backwards again (and thus computes the backpropagation gradients by summing them up), but we don't also run FF, we never actually modify our input, and so backward would yield the same output (grad) as before. Since we sum all gradient for any given neuron, we essentially sum the previous gradient with the current, which we are able to see when running backward multiple times.

# %% [markdown]
# ## Exercise d) Zero gradient
#
# We can zero the gradient by backpropagating a -1.0 as is shown in the example below. (If you have run backward multiple time then you also have to run the cell below an equal amount of times.) Explain what is going on.

# %%
a = Var(2.0)

for v in [a, b, c, d, e, f]:
    print(v)

f.backprop(-1.0)

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=2.0000, grad=0.0000)
# Var(v=5.0000, grad=6.0000)
# Var(v=15.0000, grad=2.0000)
# Var(v=9.0000, grad=6.0000)
# Var(v=27.0000, grad=2.0000)
# Var(v=42.0000, grad=2.0000)
# Var(v=2.0000, grad=0.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)
# Var(v=9.0000, grad=3.0000)
# Var(v=27.0000, grad=1.0000)
# Var(v=42.0000, grad=1.0000)

# %% [markdown]
# **Answer**
# <br> From exercise c) we gathered that the gradients are updated by adding the calculated value to their existing value (initialized at `0`). As such, by backpropagating a `-1.0`, the gradients calculated are precisely (-1) times whatever they were prior. This is because the operation being performed here is entirely linear, consisting only of multiplication and addition. The result, then, is that we add `-x` to `x` for all x, where x is each of the variables, thus canceling out each calculated gradient value resulting in a zero gradient. As we were told in the previous part, when running backward multiple times, we would then need to run "negative backward" an equal amount of times.

# %% [markdown]
# ## Exercise e) Test correctness of derivatives with the finite difference method
#
# Write a small function that uses [the finite difference method](https://en.wikipedia.org/wiki/Finite_difference_method) to numerically test that backpropation implementation is working. In short we will use
# $$
# \frac{\partial f(a)}{\partial a} \approx \frac{f(a+da)-f(a)}{da}
# $$
# for $da \ll 1$.
#
# As an example, we could approximate the derivative of the function $f(a)=a^2$ in e.g. the value $a=4$ using the finite difference method. This amounts to inserting the relevant values and approximating the gradient $f'(4)$ with the fraction above.

# %% [markdown]
# **Answer:**

# %%
# f function - try to change the code to test other types of functions as well (such as different polynomials etc.)
def f_function(a):
  a = Var(a)
  f = a ** 2
  f.backward()
  return a,f

# here is the arbitrary polynomial -0.4x^3 + 5x^2 + 2x - 5
def f_function2(a):
  a = Var(a)
  b = a ** 3
  c = Var(-0.4) * b
  d = a ** 2
  e = Var(5.0) * d
  f = Var(2.0) * a
  g = Var(-3.0)
  h = c + e 
  i = f + g
  j = h + i
  j.backward()
  return a,j

print("Function 1: (autodif)")
for v in f_function(4.0):
  print(v)

print("Function 2 (autodiff):")
for v in f_function2(4.0):
  print(v)

# Insert your finite difference code here
def finite_difference(da=1e-10):
    """
    This function compute the finite difference between

    Input:
    da:          The finite difference                           (float)

    Output:
    finite_difference: numerical approximation to the derivative (float)
    """


    def f(x):
      return x ** 2
    
    def f2(x):
      return (-0.4 * (x** 3)) + (5 * (x ** 2)) + (2 * x) - 5 

    a = 4.0

    fa_da1 = f(a + da)
    fa1 = f(a) 

    fa_da2 = f2(a + da)
    fa2 = f2(a)

    finite_difference1 = (fa_da1 - fa1) / da
    finite_difference2 = (fa_da2 - fa2) / da


    return finite_difference1, finite_difference2

print("Function 1 (finite differences)")
print(finite_difference()[0])

print("Function 2 (finite differences)")
print(finite_difference()[1])
# Out:
# Function 1: (autodif)
# Var(v=4.0000, grad=8.0000)
# Var(v=16.0000, grad=1.0000)
# Function 2 (autodiff):
# Var(v=4.0000, grad=22.8000)
# Var(v=59.4000, grad=1.0000)
# Function 1 (finite differences)
# 8.000000661922968
# Function 2 (finite differences)
# 22.79996635934367

# %% [markdown]
# The finite differences approximation with `da = 1e-10` produces results which are very close to the autodiff numbers for both our functions $f(a)=a^2$ and $f(a)=-0.4a^3 + 5a^2 + 2a - 5$.

# %% [markdown]
# # Create an artificial dataset to play with
#
# We create a non-linear 1d regression task. The generator supports various noise levels and it creates train, validation and test sets. You can modify it yourself if you want more or less challenging tasks.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
def data_generator(noise=0.1, n_samples=300, D1=True):
    # Create covariates and response variable
    if D1:
        X = np.linspace(-3, 3, num=n_samples).reshape(-1,1) # 1-D
        np.random.shuffle(X)
        y = np.random.normal((0.5*np.sin(X[:,0]*3) + X[:,0]), noise) # 1-D with trend
    else:
        X = np.random.multivariate_normal(np.zeros(3), noise*np.eye(3), size = n_samples) # 3-D
        np.random.shuffle(X)
        y = np.sin(X[:,0]) - 5*(X[:,1]**2) + 0.5*X[:,2] # 3-D

    # Stack them together vertically to split data set
    data_set = np.vstack((X.T,y)).T

    train, validation, test = np.split(data_set, [int(0.35*n_samples), int(0.7*n_samples)], axis=0)

    # Standardization of the data, remember we do the standardization with the training set mean and standard deviation
    train_mu = np.mean(train, axis=0)
    train_sigma = np.std(train, axis=0)

    train = (train-train_mu)/train_sigma
    validation = (validation-train_mu)/train_sigma
    test = (test-train_mu)/train_sigma

    x_train, x_validation, x_test = train[:,:-1], validation[:,:-1], test[:,:-1]
    y_train, y_validation, y_test = train[:,-1], validation[:,-1], test[:,-1]

    return x_train, y_train,  x_validation, y_validation, x_test, y_test

# %%
D1 = True
x_train, y_train,  x_validation, y_validation, x_test, y_test = data_generator(noise=0.5, D1=D1)

# %%
if D1:
    plt.scatter(x_train[:,0], y_train);
    plt.scatter(x_validation[:,0], y_validation);
    plt.scatter(x_test[:,0], y_test);
else:
    plt.scatter(x_train[:,1], y_train);
    plt.scatter(x_validation[:,1], y_validation);
    plt.scatter(x_test[:,1], y_test);
plt.show()

# %%
# convert from nparray to Var
def nparray_to_Var(x):
  if x.ndim==1:
    y = [[Var(float(x[i]))] for i in range(x.shape[0])] # always work with list of list
  else:
    y = [[Var(float(x[i,j])) for j in range(x.shape[1])] for i in range(x.shape[0])]
  return y

x_train = nparray_to_Var(x_train)
y_train = nparray_to_Var(y_train)
x_validation = nparray_to_Var(x_validation)
y_validation = nparray_to_Var(y_validation)
x_test = nparray_to_Var(x_test)
y_test = nparray_to_Var(y_test)

# %% [markdown]
# # Defining and initializing the network
#
# The steps to create a feed forward neural network are the following:
#
# 1. **Number of hidden layer and hidden units**. We have to define the number of hidden units in each layer. The number of features in X and the output dimensionality (the size of Y) are given but the numbers in between are set by the researcher. Remember that for each unit in each layer beside in the input has a bias term.
# 2. **Activation functions** for each hidden layer. Each hidden layer in your list must have an activation function (it can also be the linear activation which is equivalent to identity function). The power of neural networks comes from non-linear activation functions that learn representations (features) from the data allowing us to learn from it.
# 3. **Parameter initialization**. We will initialize the weights to have random values. This is done in practice by drawing pseudo random numbers from a Gaussian or uniform distribution. It turns out that for deeper models we have to be careful about how we scale the random numbers. This will be the topic of the exercise below. For now we will just use unit variance Gaussians.
#
# In order to make life easier for ourselves we define a DenseLayer class that takes care of initialization and the forward pass. We can also extend it later with print and advanced initialization capabilities. For the latter we have introduced a Initializer class.
#
# Note that we use Sequence in the code below. A Sequence is an ordered list. This means the order we insert and access items are the same.

# %% [markdown]
# We were unsure if we needed to actually implement an Initializer class or not, so we did.

# %%
import random

class Initializer:

  def init_weights(self, n_in, n_out):
    return [[Var(random.gauss(mu = 0, sigma = 1)) for _ in range(n_in)] for _ in range(n_out)] # use same method as in next section, but leave mean (mu) & std (sigma) as 1

  def init_bias(self, n_out):
    return [Var(0.0) for _ in range(n_out)] # same as before

# %%
import random

class NormalInitializer(Initializer):

  def __init__(self, mean=0, std=0.1):
    self.mean = mean
    self.std = std

  def init_weights(self, n_in, n_out):
    return [[Var(random.gauss(self.mean, self.std)) for _ in range(n_out)] for _ in range(n_in)]

  def init_bias(self, n_out):
    return [Var(0.0) for _ in range(n_out)]

class ConstantInitializer(Initializer):

  def __init__(self, weight=1.0, bias=0.0):
    self.weight = weight
    self.bias = bias

  def init_weights(self, n_in, n_out):
    return [[Var(self.weight) for _ in range(n_out)] for _ in range(n_in)]

  def init_bias(self, n_out):
    return [Var(self.bias) for _ in range(n_out)]

# %%
from typing import Sequence

class DenseLayer:
    def __init__(self, n_in: int, n_out: int, act_fn, initializer = NormalInitializer()):
        self.weights = initializer.init_weights(n_in, n_out)
        self.bias = initializer.init_bias(n_out)
        self.act_fn = act_fn

    def __repr__(self):
        return 'Weights: ' + repr(self.weights) + ' Biases: ' + repr(self.bias)

    def parameters(self) -> Sequence[Var]:
      params = []
      for r in self.weights:
        params += r

      return params + self.bias

    def forward(self, single_input: Sequence[Var]) -> Sequence[Var]:
        # self.weights is a matrix with dimension n_in x n_out. We check that the dimensionality of the input
        # to the current layer matches the number of nodes in the current layer
        assert len(self.weights) == len(single_input), "weights and single_input must match in first dimension"
        weights = self.weights
        out = []
        # For some given data point single_input, we now want to calculate the resulting value in each node in the current layer
        # We therefore loop over the (number of) nodes in the current layer:
        for j in range(len(weights[0])):
            # Initialize the node value depending on its corresponding parameters.
            node = self.bias[j] # We set the bias for each neuron, but since self.bias is a list of Var's, we need to index to the j'th bias # <- Insert code
            # We now finish the linear transformation corresponding to the parameters of the currently considered node.
            for i in range(len(single_input)):
                node += self.weights[i][j] * single_input[i] # We then add the \sum of the weight multiplied with the input, from neuron 1 .. i to neuron j (indexed [i][j])   # <- Insert code
            node = self.act_fn(node)
            out.append(node)

        return out

# %% [markdown]
# ## Exercise f) Add more activation functions
#
# To have a full definition of the neural network, we must define an activation function for every layer. Several activation functions have been proposed and have different characteristics. In the Var class we have already defined the rectified linear init (relu).
#
# Implement the following activation functions in the Var class:
#
# * Identity: $$\mathrm{identity}(x) = x$$
# * Hyperbolic tangent: $$\tanh(x)$$
# * Sigmoid (or logistic function): $$\mathrm{sigmoid}(x) = \frac{1}{1.0 + \exp(-x ) }$$  Hint: $\mathrm{sigmoid}'(x)= \mathrm{sigmoid}(x)(1-\mathrm{sigmoid}(x))$.
#
# Hint: You can seek inspiration in the relu method in the Var class.

# %% [markdown]
# The actual changes have been implemented in the `Var` class.
# ```py
#     def identity(self):
#         return Var(self.v, lambda: [(self, 1)])
#
#     def tanh(self):
#         return Var((exp(self.v)-exp(-self.v))/(exp(self.v)+exp(-self.v)), lambda: [(self, 1-((exp(self.v)-exp(-self.v))/(exp(self.v)+exp(-self.v)))**2)])
#
#     def sigmoid(self):
#         return Var(1/(1+exp(-self.v)), lambda: [(self, (1/(1+exp(-self.v)))*(1-(1/(1+exp(-self.v)))))])
# ```

# %% [markdown]
# ## Exercise g) Complete the forward pass
#
# In the code below we initialize a 1-5-1 network and pass the training set through it. *The forward method in DenseLayer is **not** complete*. It just outputs zeros right now. The method forward should perform an [affine transformation](https://en.wikipedia.org/wiki/Affine_transformation) on the input followed by an application of the activation function.

# %% [markdown]
# **Answer**
#
# We need to do the forward pass, which is described (as in the previous notebook) as:
# $$
# \text{node}_j = b_j + \sum_{i} w_{ij} * x_i
# $$
# We first compute the bias for the single neuron, j:
# ```py
#     node = self.bias[j] # We set the bias for each neuron, but since self.bias is a list of Var's, we need to index to the j'th bias # <- Insert code
# ```
#
# After computing the bias term, we need to index once more, to access the weights and the corresponding inputs, and so we use the next for loop:
# ```py
#     node += self.weights[i][j] * single_input[i] # We then add the \sum of the weight multiplied with the input, from neuron 1 .. i to neuron j (indexed [i][j])   # <- Insert code
# ````

# %%
NN = [
    DenseLayer(1, 5, lambda x: x.relu()),
    DenseLayer(5, 1, lambda x: x.identity())
]

def forward(input, network):

  def forward_single(x, network):
    for layer in network:
        x = layer.forward(x)
    return x

  output = [ forward_single(input[n], network) for n in range(len(input))]
  return output

print(forward(x_train, NN))
# Out:
# [[Var(v=0.0092, grad=0.0000)], [Var(v=0.0185, grad=0.0000)], [Var(v=0.0017, grad=0.0000)], [Var(v=-0.0215, grad=0.0000)], [Var(v=0.0136, grad=0.0000)], [Var(v=0.0126, grad=0.0000)], [Var(v=0.0082, grad=0.0000)], [Var(v=-0.0052, grad=0.0000)], [Var(v=-0.0222, grad=0.0000)], [Var(v=0.0051, grad=0.0000)], [Var(v=0.0142, grad=0.0000)], [Var(v=-0.0137, grad=0.0000)], [Var(v=0.0114, grad=0.0000)], [Var(v=-0.0156, grad=0.0000)], [Var(v=0.0061, grad=0.0000)], [Var(v=0.0119, grad=0.0000)], [Var(v=0.0219, grad=0.0000)], [Var(v=0.0104, grad=0.0000)], [Var(v=0.0011, grad=0.0000)], [Var(v=0.0036, grad=0.0000)], [Var(v=-0.0102, grad=0.0000)], [Var(v=-0.0045, grad=0.0000)], [Var(v=0.0160, grad=0.0000)], [Var(v=0.0161, grad=0.0000)], [Var(v=-0.0060, grad=0.0000)], [Var(v=-0.0161, grad=0.0000)], [Var(v=0.0207, grad=0.0000)], [Var(v=0.0228, grad=0.0000)], [Var(v=0.0024, grad=0.0000)], [Var(v=0.0144, grad=0.0000)], [Var(v=-0.0202, grad=0.0000)], [Var(v=0.0035, grad=0.0000)], [Var(v=-0.0176, grad=0.0000)], [Var(v=-0.0191, grad=0.0000)], [Var(v=0.0110, grad=0.0000)], [Var(v=-0.0035, grad=0.0000)], [Var(v=-0.0219, grad=0.0000)], [Var(v=-0.0083, grad=0.0000)], [Var(v=-0.0155, grad=0.0000)], [Var(v=-0.0111, grad=0.0000)], [Var(v=-0.0078, grad=0.0000)], [Var(v=-0.0106, grad=0.0000)], [Var(v=0.0215, grad=0.0000)], [Var(v=-0.0132, grad=0.0000)], [Var(v=-0.0104, grad=0.0000)], [Var(v=-0.0127, grad=0.0000)], [Var(v=0.0138, grad=0.0000)], [Var(v=0.0130, grad=0.0000)], [Var(v=-0.0048, grad=0.0000)], [Var(v=0.0133, grad=0.0000)], [Var(v=0.0058, grad=0.0000)], [Var(v=0.0005, grad=0.0000)], [Var(v=0.0145, grad=0.0000)], [Var(v=-0.0107, grad=0.0000)], [Var(v=0.0231, grad=0.0000)], [Var(v=0.0203, grad=0.0000)], [Var(v=-0.0071, grad=0.0000)], [Var(v=-0.0080, grad=0.0000)], [Var(v=0.0076, grad=0.0000)], [Var(v=-0.0189, grad=0.0000)], [Var(v=0.0135, grad=0.0000)], [Var(v=-0.0133, grad=0.0000)], [Var(v=-0.0220, grad=0.0000)], [Var(v=0.0066, grad=0.0000)], [Var(v=0.0048, grad=0.0000)], [Var(v=-0.0181, grad=0.0000)], [Var(v=-0.0194, grad=0.0000)], [Var(v=0.0170, grad=0.0000)], [Var(v=-0.0138, grad=0.0000)], [Var(v=0.0067, grad=0.0000)], [Var(v=-0.0053, grad=0.0000)], [Var(v=-0.0024, grad=0.0000)], [Var(v=0.0132, grad=0.0000)], [Var(v=0.0077, grad=0.0000)], [Var(v=-0.0019, grad=0.0000)], [Var(v=0.0209, grad=0.0000)], [Var(v=-0.0096, grad=0.0000)], [Var(v=-0.0093, grad=0.0000)], [Var(v=-0.0122, grad=0.0000)], [Var(v=0.0218, grad=0.0000)], [Var(v=0.0033, grad=0.0000)], [Var(v=0.0020, grad=0.0000)], [Var(v=-0.0199, grad=0.0000)], [Var(v=-0.0027, grad=0.0000)], [Var(v=-0.0101, grad=0.0000)], [Var(v=-0.0044, grad=0.0000)], [Var(v=-0.0037, grad=0.0000)], [Var(v=-0.0112, grad=0.0000)], [Var(v=-0.0205, grad=0.0000)], [Var(v=-0.0214, grad=0.0000)], [Var(v=0.0079, grad=0.0000)], [Var(v=-0.0065, grad=0.0000)], [Var(v=-0.0119, grad=0.0000)], [Var(v=0.0123, grad=0.0000)], [Var(v=-0.0169, grad=0.0000)], [Var(v=-0.0204, grad=0.0000)], [Var(v=0.0057, grad=0.0000)], [Var(v=0.0009, grad=0.0000)], [Var(v=0.0197, grad=0.0000)], [Var(v=-0.0120, grad=0.0000)], [Var(v=0.0129, grad=0.0000)], [Var(v=-0.0117, grad=0.0000)], [Var(v=-0.0179, grad=0.0000)], [Var(v=0.0063, grad=0.0000)], [Var(v=0.0184, grad=0.0000)]]

# %% [markdown]
# ## Exercise h) Print all network parameters
#
# Make a function that prints all the parameters of the network (weights and biases) with information about in which layer the appear. In the object oriented spirit you should introduce a method in the DenseLayer class to print the parameters of a layer. Hint: You can take inspiration from the corresponding method in Var.

# %% [markdown]
# **Answer**
# In the `Var` class, we were given a pre-defined method to view the parameters:
# ```py
#     def __repr__(self):
#         return "Var(v=%.4f, grad=%.4f)" % (self.v, self.grad)
# ```
# Which we now have to implement (or in our case improve) in the `DenseLayer` class.
# We notice the same method already has been implemented, but is lacking the part about which layer the parameters lie in.
# When we print out the biases, we would just need to print out all biases for the given layer we find ourselves in, but when printing the weights, we would need to print the `out` weights, e.g. those coming from layer $j-1$:
# We re-used the code from earlier to showcase it visually.

# %%
# Create a directed graph
G = nx.DiGraph()

# Add edges with labels
G.add_edge('L1_a', 'L2_c', label='weight L1->L2')
G.add_edge('L1_b', 'L2_c', label='weight L1->L2')

# Manually define positions for a tree layout
pos = {
    'L1_a': (0, 2),
    'L1_b': (0, 0),
    'L2_c': (1, 1),
}

# Draw the graph nodes and edges
nx.draw(G, pos, with_labels=True, node_shape='o', node_size=3000, node_color='lightblue', arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.title("Graph of example two")
plt.show()

# %% [markdown]
# And so we take the already existing `__repr__` method in `DenseLayer` and use it in a function that iteratively loops through each layer to print out the parameters.
# We look at the `__repr__` method:
# ```py
#     def __repr__(self):
#         return 'Weights: ' + repr(self.weights) + ' Biases: ' + repr(self.bias)
# ```

# %%
# Insert code here and in the DenseLayer class
def parameter_lookup(nn): # nn input would have the DenseLayer class
    for layer, neuron in enumerate(nn): # we run the class with nn[1], nn[2], ..., nn[layer], which returns a single layer's parameters, so we "just" run `.__repr__()` on it
        print(f"Layer {layer}: \n{neuron}") # neuron is automatically neuron.__repr__()

# %% [markdown]
# ## Visualization
#
# Now that we have defined our activation functions we can visualize them to see what they look like:

# %%
x = np.linspace(-6, 6, 100)

# convert from Var to ndarray
def Var_to_nparray(x):
  y = np.zeros((len(x),len(x[0])))
  for i in range(len(x)):
    for j in range(len(x[0])):
      y[i,j] = x[i][j].v
  return y

# define 1-1 network with weight = 1 and relu activation
NN = [ DenseLayer(1, 1, lambda x: x.relu(), initializer = ConstantInitializer(1.0)) ]
y = Var_to_nparray(forward(nparray_to_Var(x), NN))

#y = Var_to_nparray(relu(nparray_to_Var(x)))
plt.plot(x,y)
plt.show()

# %%
# Testing all activation layers

x = np.linspace(-6, 6, 100)
units = {
    "identity": lambda x: x.identity(),
    "sigmoid": lambda x: x.sigmoid(),
    "relu": lambda x: x.relu(),
    "tanh": lambda x: x.tanh()
}

plt.figure(figsize=(5, 5))
[plt.plot(x, Var_to_nparray(forward(nparray_to_Var(x), [DenseLayer(1, 1, unit, initializer = ConstantInitializer(1.0))]) ), label=unit_name, lw=2) for unit_name, unit in units.items()] # unit(nparray_to_Var(x))), label=unit_name, lw=2) for unit_name, unit in units.items()]
plt.legend(loc=2, fontsize=16)
plt.title('Our activation functions', fontsize=20)
plt.ylim([-2, 5])
plt.xlim([-6, 6])
plt.show()

# %% [markdown]
# # Advanced initialization schemes
#
# If we are not careful with initialization, the signals we propagate forward ($a^{(l)}$, $l=1,\ldots,L$) and backward ($\delta^l$, $l=L,L-1,\ldots,1$) can blow up or shrink to zero. A statistical analysis of the variance of the signals for different activation functions can be found in these two papers: [Glorot initialization](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf) and [He initialization](https://arxiv.org/pdf/1502.01852v1.pdf).
#
# The result of the analyses are proposals for how to make the initialization such that the variance of the signals (forward and backward) are kept approxmimatly constant when propagating from layer to layer. The exact expressions depend upon the non-linear activation function used. In Glorot initialization, the aim is to keep both the forward and backward variances constant whereas He only aims at keeping the variance in the forward pass constant.
#
# We define $n_{in}$ and $n_{out}$ as the number of input units and output units of a particular layer.
#
# The Glorot initialization has the form:
#
# $$w_{ij} \sim N \bigg( 0, \, \frac{2 \alpha }{n_{in} + n_{out}} \bigg) \ . $$
#
# where $N(\mu,\sigma^2)$ is a Gaussian distribution with mean $\mu$ and variance $\sigma^2$ and $\alpha$ is a parameter that depends upon the activation function used. For $\tanh$, $\alpha=1$ and for Rectified Linear Unit (ReLU) activations, $\alpha=2$. (It is also possible to use a uniform distribution for initialization, see [this blog post](https://mmuratarat.github.io/2019-02-25/xavier-glorot-he-weight-init).)
#
# The He initialization is very similar
#
# $$w_{ij} \sim N \bigg( 0, \, \frac{\alpha}{n_{in}} \bigg) \ . $$

# %% [markdown]
# ## Exercise i) Glorot and He initialization
#
# Using the Initializer class, implement functions that implement Glorot and He
#
# Explain briefly how you would test numerically that these initializations have the sought after property. Hint: See plots in Glorot paper.
#
# Comment: If you want to be more advanced then try to make a universal initializer taking both the activation function and type (Glorot or He) as argument.

# %% [markdown]
# **Answer**
#
# We use the equations to calculate the `std`:

# %%
import math # std is sqrt(sigma^2) and since He and Glorot are gaussian distributed, we use sigma^2
## Glorot
def DenseLayer_Glorot_tanh(n_in: int, n_out: int):
  alpha = 1
  std = math.sqrt((2 * alpha) / (n_in + n_out)) # <- replace with proper initialization
  return DenseLayer(n_in, n_out, lambda x: x.tanh(), initializer = NormalInitializer(std))

## He
def DenseLayer_He_relu(n_in: int, n_out: int):
  alpha = 2
  std = math.sqrt((alpha / n_in)) # <- replace with proper initialization
  return DenseLayer(n_in, n_out, lambda x: x.relu(), initializer = NormalInitializer(std))

# %% [markdown]
# We also try to make it using a universal initializer, using the same method for weights and biases as used in the class provided (unlike the one we made ourselves we don't force mu and sigma, but instead use the given input provided from the `act_func` and `type`).
#
# The class uses a dict to define the values for alpha. Since we ourselves sometimes write e.g. `reLU` we also added a bit of catch statements to ensure no hassle.
#
# The `std` is then computed as before, and mean is set to $0$ (gaussian).

# %%
import math

class Universal_Initializer(Initializer):
    def __init__(self, n_in: int, n_out: int, act_func: str, type: str = "glorot"):
        alphas = {"reLU": 2, "relu": 2, "tanh": 1}
        alpha = alphas.get(act_func, 1) # to access dict, if nothing is found returns 1 instead of KeyError
        
        if type == ("glorot" or "Glorot"):
            var = (2 * alpha) / (n_in + n_out)
            
        elif type == ("he" or "He"):
            var = (alpha / n_in)
            
        else:
            raise ValueError("Unknown activation function given. Only Glorot or He accepted.")
            
        self.mean = 0
        self.std = math.sqrt(var)
        
    def init_weights(self, n_in, n_out):
        return [[Var(random.gauss(self.mean, self.std)) for _ in range(n_in)] for _ in range(n_out)]
    
    def init_bias(self, n_out):
        return [Var(self.bias) for _ in range(n_out)]

# %% [markdown]
# ## Exercise j) Forward pass unit test
#
# Write a bit of code to make a unit test that the forward pass works. This can be done by defining a simple network with for example all weights equal to one (using the ConstantInitializer method) and identity activation functions.
#
# Hints: Use the [assert](https://www.w3schools.com/python/ref_keyword_assert.asp), the nparray_to_Var and the Var_to_nparray commands.

# %% [markdown]
# **Answer**
# We set up a test array to run use the `forward()` on, and use the `DenseLayer` class initialized with `ConstantInitializer`, activation function `identity()` we defined in the `Var` class earlier.
# To easily check if we've done it correctly, we set bias 0 and weights 1 (agian, constant), and then use the `assert()` on a converted `np.array()` to easily check the list format.

# %%
# Insert code here
import numpy as np
test_input = np.array([[2.0], [5.0]])

# Bias = 0, weights all = 1 (since initializer is Constant...)
# test[0] -> 0 + 2.0 * 1 = 2.0
# test[1] -> 0 + 5.0 * 1 = 5.0

test_nn = Var_to_nparray(forward(nparray_to_Var(test_input), [DenseLayer(1, 1, act_fn=lambda x: x.identity(), initializer = ConstantInitializer(weight=1.0, bias=0.0))]) )

print(f"Test input: {test_input.tolist()}\nTest NN:    {test_nn.tolist()}\n")

assert(test_nn.tolist() == test_input.tolist())
print("Test succeeded")
# Out:
# Test input: [[2.0], [5.0]]
# Test NN:    [[2.0], [5.0]]
#
# Test succeeded

# %% [markdown]
# # Loss functions
#
# We are only missing a loss function to we need to define a loss function and its derivative with respect to the output of the neural network $y$

# %%
def squared_loss(t, y):

  # add check that sizes agree

  def squared_loss_single(t, y):
    Loss = Var(0.0)
    for i in range(len(t)): # sum over outputs
      Loss += (t[i]-y[i]) ** 2
    return Loss

  Loss = Var(0.0)
  for n in range(len(t)): # sum over training data
    Loss += squared_loss_single(t[n],y[n])
  return Loss

# %% [markdown]
# ## Exercise k) Implement cross entropy loss
#
# Insert code below to implement cross-entropy loss for general dimensionality of $t$. Use a logits formulation:
# $$
# \rm{Loss} = - \sum_i t_i \, log \, p_i
# $$
# with $p$ given by the the softmax function in terms of the logits $h$:
# $$
# p_i = \frac{\exp(h_i)}{\sum_{i'} \exp(h_{i'})} .
# $$
# Inserting $p$ in the expression for the loss gives
# $$
# \rm{Loss} = - \sum_i t_i h_i + \rm{LogSumExp}(h) \ ,
# $$
# where
# $$
# \rm{LogSumExp}(h) = \log \sum_i \exp h_i \ .
# $$
# This is true for $t$ being a one-hot vector.
#
# Call the function to convince yourself it works.
#
# In practice you want to implement a [numerically stable](https://leimao.github.io/blog/LogSumExp/) version of LogSumExp. But we will not bother about that here.
#
# Help: You can add these methods in the Var class:
# ```py
#     def exp(self):
#         return Var(exp(self.v), lambda: [(self, exp(self.v))])
#
#     def log(self):
#         return Var(log(self.v), lambda: [(self, self.v ** -1)])
# ```

# %% [markdown]
# Normally we would just iterate in a normal way using `+=`, but since we use the `Var` class' `__add__` we can't use in-place addition (regular python class method `__iadd__`). We do the same for the negative sum.
#
# Generally, we initialize our two terms with initialized `Var` value as `0.0` so we have `Var` objects we can work with.
#
# And so we define:
# $$
# \text{first\_term} = - \sum_{i} t_i * h_i
# $$
# And
# $$
# \text{log\_sum\_exp} = \log \left(\sum_i \exp\left(h_i\right)\right)
# $$
#
# Since we go up to two different sums (like in the previous squared loss), we need two different loops.
# As explained before, we use the (re)defined `__add__` and compute both terms, which we then lastly add together and return the computed loss.

# %%
def cross_entropy_loss(t, h):
    # Insert code here
    first_term = Var(0.0) #initialize with Var(0.0)
    for i in range(len(t)):
        first_term = first_term - Var(t[i]) * h[i] # Loss = - \sum_i t_i h_i + LogSumExp which we do in just a second

    sum_exp = Var(0.0)
    for i in range(len(h)):
        sum_exp = sum_exp + h[i].exp() # \sum_i exp(h_i)
    
    log_sum_exp = sum_exp.log() #takes the log of previois
    
    Loss = first_term + log_sum_exp
    
    return Loss

# %% [markdown]
# # Backward pass
#
# Now the magic happens! We get the calculation of the gradients for free. Just do:

# %%
NN = [
    DenseLayer(1, 5, lambda x: x.relu()),
    DenseLayer(5, 1, lambda x: x.identity())
]

output = forward(x_train, NN)

Loss = squared_loss(y_train,output)
Loss.backward()

# %% [markdown]
# and the gradients will be calculated:

# %%
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]
# Out:
# Layer 0
#  Weights: [[Var(v=0.0597, grad=0.7606), Var(v=-0.0385, grad=3.2490), Var(v=-0.0422, grad=-17.9639), Var(v=-0.0373, grad=2.3465), Var(v=0.1399, grad=-1.2503)]] Biases: [Var(v=0.0000, grad=0.6534), Var(v=0.0000, grad=-2.9535), Var(v=0.0000, grad=16.3300), Var(v=0.0000, grad=-2.1331), Var(v=0.0000, grad=-1.0741)]
# Layer 1
#  Weights: [[Var(v=-0.0075, grad=-6.0602)], [Var(v=-0.0336, grad=3.7198)], [Var(v=0.1860, grad=4.0723)], [Var(v=-0.0243, grad=3.5993)], [Var(v=0.0123, grad=-14.1927)]] Biases: [Var(v=0.0000, grad=0.6407)]
# [None, None]

# %% [markdown]
# # Backward pass unit test
#
# Above we used finite differences to test that Nanograd is actually doing what it is supposed to do. We can in principle try the same for the neural network. But we will trust that the test above is enough.

# %% [markdown]
# # Training and validation
#
# We are ready to train some neural networks!
#
# We initialize again:

# %%
NN = [
    DenseLayer(1, 15, lambda x: x.relu()),
    DenseLayer(15, 50, lambda x: x.relu()),
    DenseLayer(50, 1, lambda x: x.identity())
]

output = forward(x_train, NN)

Loss = squared_loss(y_train,output)
Loss.backward()

# %% [markdown]
# and make an update:
#
# We introduce a help function parameters to have a handle in all parameters in the network.

# %%
print('Network before update:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]

def parameters(network):
  params = []
  for layer in range(len(network)):
    params += network[layer].parameters()
  return params

def update_parameters(params, learning_rate=0.01):
  for p in params:
    p.v -= learning_rate*p.grad

def zero_gradients(params):
  for p in params:
    p.grad = 0.0

update_parameters(parameters(NN))

print('\nNetwork after update:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]

zero_gradients(parameters(NN))

print('\nNetwork after zeroing gradients:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]
# Out:
# Network before update:
# Layer 0
#  Weights: [[Var(v=-0.0047, grad=0.9775), Var(v=-0.0013, grad=-1.8290), Var(v=0.2009, grad=0.3641), Var(v=0.1255, grad=-5.3144), Var(v=-0.1704, grad=7.7215), Var(v=-0.1712, grad=-2.4609), Var(v=0.2687, grad=-4.7051), Var(v=-0.0125, grad=2.3325), Var(v=-0.0258, grad=1.6468), Var(v=0.0254, grad=-2.9124), Var(v=0.0140, grad=-2.7776), Var(v=0.0031, grad=3.4131), Var(v=0.0872, grad=6.6595), Var(v=-0.0910, grad=3.1523), Var(v=-0.0557, grad=7.1939)]] Biases: [Var(v=0.0000, grad=-0.8882), Var(v=0.0000, grad=1.6619), Var(v=0.0000, grad=0.3129), Var(v=0.0000, grad=-4.5663), Var(v=0.0000, grad=-7.0162), Var(v=0.0000, grad=2.2361), Var(v=0.0000, grad=-4.0428), Var(v=0.0000, grad=-2.1195), Var(v=0.0000, grad=-1.4964), Var(v=0.0000, grad=-2.5025), Var(v=0.0000, grad=-2.3866), Var(v=0.0000, grad=2.9327), Var(v=0.0000, grad=5.7221), Var(v=0.0000, grad=-2.8643), Var(v=0.0000, grad=-6.5367)]
# Layer 1
#  Weights: [[Var(v=-0.2247, grad=0.0000), Var(v=0.0556, grad=0.0595), Var(v=0.1324, grad=0.0000), Var(v=-0.0330, grad=-0.0004), Var(v=-0.0708, grad=-0.0075), Var(v=-0.0510, grad=0.0242), Var(v=0.1347, grad=0.0000), Var(v=0.0620, grad=0.0373), Var(v=0.1457, grad=-0.1003), Var(v=-0.2905, grad=-0.0378), Var(v=-0.0574, grad=0.0000), Var(v=0.0933, grad=0.0000), Var(v=0.0836, grad=0.0000), Var(v=0.0805, grad=0.0000), Var(v=-0.0653, grad=-0.0256), Var(v=0.0481, grad=0.0387), Var(v=-0.0350, grad=0.0000), Var(v=0.0452, grad=0.0000), Var(v=-0.0104, grad=0.0000), Var(v=0.1432, grad=0.0000), Var(v=-0.0083, grad=-0.0288), Var(v=-0.0758, grad=-0.1163), Var(v=-0.0175, grad=-0.0422), Var(v=-0.0558, grad=0.0374), Var(v=-0.1679, grad=0.0000), Var(v=-0.0775, grad=0.0000), Var(v=-0.0199, grad=0.0000), Var(v=0.0854, grad=-0.0093), Var(v=0.0964, grad=0.0000), Var(v=0.1166, grad=-0.0740), Var(v=0.1898, grad=-0.0510), Var(v=-0.0390, grad=0.0156), Var(v=-0.1313, grad=0.0000), Var(v=-0.0844, grad=0.0000), Var(v=-0.1123, grad=-0.0397), Var(v=0.0586, grad=0.0000), Var(v=0.0517, grad=-0.0298), Var(v=-0.1556, grad=0.0000), Var(v=-0.0073, grad=-0.0655), Var(v=0.0739, grad=0.0000), Var(v=-0.0059, grad=0.0038), Var(v=0.1115, grad=0.0000), Var(v=0.0740, grad=0.0000), Var(v=-0.0211, grad=0.0411), Var(v=0.0607, grad=0.0015), Var(v=0.0544, grad=0.0000), Var(v=0.1443, grad=0.0000), Var(v=-0.0161, grad=0.0000), Var(v=-0.1619, grad=0.0000), Var(v=-0.0233, grad=0.0000)], [Var(v=-0.2746, grad=0.0000), Var(v=-0.2211, grad=0.0165), Var(v=0.0719, grad=0.0000), Var(v=0.1481, grad=-0.0001), Var(v=-0.1397, grad=-0.0021), Var(v=0.0198, grad=0.0067), Var(v=-0.0934, grad=0.0000), Var(v=-0.0662, grad=0.0104), Var(v=-0.0763, grad=-0.0279), Var(v=0.0346, grad=-0.0105), Var(v=0.1042, grad=0.0000), Var(v=0.0449, grad=0.0000), Var(v=0.0686, grad=0.0000), Var(v=-0.1068, grad=0.0000), Var(v=-0.0673, grad=-0.0071), Var(v=-0.1310, grad=0.0107), Var(v=-0.1058, grad=0.0000), Var(v=0.1109, grad=0.0000), Var(v=0.0847, grad=0.0000), Var(v=-0.0769, grad=0.0000), Var(v=-0.0540, grad=-0.0080), Var(v=-0.1314, grad=-0.0323), Var(v=-0.0349, grad=-0.0117), Var(v=0.0060, grad=0.0104), Var(v=-0.0197, grad=0.0000), Var(v=-0.2386, grad=0.0000), Var(v=-0.0434, grad=0.0000), Var(v=-0.1524, grad=-0.0026), Var(v=0.0695, grad=0.0000), Var(v=0.0049, grad=-0.0205), Var(v=0.0026, grad=-0.0142), Var(v=-0.0069, grad=0.0043), Var(v=-0.1028, grad=0.0000), Var(v=0.0897, grad=0.0000), Var(v=-0.0544, grad=-0.0110), Var(v=-0.0163, grad=0.0000), Var(v=-0.1214, grad=-0.0083), Var(v=0.0812, grad=0.0000), Var(v=0.0388, grad=-0.0182), Var(v=-0.0283, grad=0.0000), Var(v=0.0120, grad=0.0011), Var(v=0.0526, grad=0.0000), Var(v=-0.0645, grad=0.0000), Var(v=-0.0690, grad=0.0114), Var(v=-0.0565, grad=0.0004), Var(v=0.0340, grad=0.0000), Var(v=-0.0935, grad=0.0000), Var(v=-0.1142, grad=0.0000), Var(v=0.1760, grad=0.0000), Var(v=-0.1904, grad=0.0000)], [Var(v=-0.1930, grad=0.0000), Var(v=0.0588, grad=-2.7098), Var(v=0.0613, grad=0.0000), Var(v=-0.0352, grad=0.0000), Var(v=-0.0642, grad=0.0000), Var(v=0.1261, grad=-1.1015), Var(v=0.1263, grad=0.0000), Var(v=-0.1685, grad=0.0000), Var(v=-0.1195, grad=0.0000), Var(v=-0.1990, grad=0.0000), Var(v=-0.0522, grad=0.0000), Var(v=-0.2055, grad=0.0000), Var(v=-0.1984, grad=0.0000), Var(v=0.0047, grad=0.0000), Var(v=-0.0519, grad=1.1655), Var(v=0.0138, grad=0.0000), Var(v=0.0556, grad=0.0000), Var(v=-0.1583, grad=0.0000), Var(v=-0.1015, grad=0.0000), Var(v=-0.0316, grad=0.0000), Var(v=-0.0286, grad=0.0000), Var(v=0.0732, grad=5.2992), Var(v=0.0764, grad=1.9230), Var(v=-0.0663, grad=-1.7055), Var(v=-0.1002, grad=0.0000), Var(v=-0.0314, grad=0.0000), Var(v=0.0739, grad=0.5107), Var(v=-0.0987, grad=0.0000), Var(v=-0.0004, grad=-0.2372), Var(v=0.1974, grad=3.3707), Var(v=-0.0376, grad=0.0000), Var(v=0.1081, grad=-0.7125), Var(v=0.0398, grad=0.0000), Var(v=0.0592, grad=0.0000), Var(v=-0.0740, grad=1.8085), Var(v=0.0342, grad=-0.2460), Var(v=0.1057, grad=1.3557), Var(v=-0.0305, grad=-1.0359), Var(v= ...
# Layer 2
#  Weights: [[Var(v=-0.0273, grad=0.0000)], [Var(v=0.1348, grad=-2.0359)], [Var(v=0.0776, grad=0.0000)], [Var(v=-0.0010, grad=3.4567)], [Var(v=-0.0170, grad=0.6540)], [Var(v=0.0548, grad=-4.1759)], [Var(v=0.1974, grad=0.0000)], [Var(v=0.0845, grad=0.3455)], [Var(v=-0.2274, grad=1.9600)], [Var(v=-0.0857, grad=0.0359)], [Var(v=0.1034, grad=0.0000)], [Var(v=-0.0311, grad=0.0000)], [Var(v=-0.0524, grad=0.0000)], [Var(v=-0.0413, grad=0.0000)], [Var(v=-0.0580, grad=0.0206)], [Var(v=0.0877, grad=0.8532)], [Var(v=-0.0137, grad=0.0000)], [Var(v=-0.0040, grad=0.0000)], [Var(v=-0.1016, grad=0.0000)], [Var(v=0.0266, grad=0.0000)], [Var(v=-0.0654, grad=1.6133)], [Var(v=-0.2636, grad=0.0685)], [Var(v=-0.0957, grad=-1.6357)], [Var(v=0.0848, grad=0.6231)], [Var(v=0.1616, grad=0.0000)], [Var(v=-0.2373, grad=0.0000)], [Var(v=-0.0254, grad=-0.5913)], [Var(v=-0.0211, grad=2.5924)], [Var(v=0.0118, grad=-4.5588)], [Var(v=-0.1677, grad=2.5772)], [Var(v=-0.1156, grad=0.2638)], [Var(v=0.0354, grad=-1.8836)], [Var(v=0.1358, grad=0.0000)], [Var(v=-0.0427, grad=0.0000)], [Var(v=-0.0900, grad=1.2603)], [Var(v=0.0122, grad=-0.0737)], [Var(v=-0.0674, grad=-1.8778)], [Var(v=0.0515, grad=-1.6696)], [Var(v=-0.1483, grad=1.8824)], [Var(v=-0.1291, grad=0.0000)], [Var(v=0.0087, grad=-3.5245)], [Var(v=0.0089, grad=-2.5700)], [Var(v=-0.0062, grad=-4.1182)], [Var(v=0.0932, grad=-6.1707)], [Var(v=0.0033, grad=4.5368)], [Var(v=0.0905, grad=-3.0488)], [Var(v=0.0007, grad=-6.1192)], [Var(v=0.1802, grad=-2.2161)], [Var(v=0.0068, grad=-2.1165)], [Var(v=0.0252, grad=0.0000)]] Biases: [Var(v=0.0000, grad=-0.3504)]
#
# Network after update:
# Layer 0
#  Weights: [[Var(v=-0.0145, grad=0.9775), Var(v=0.0170, grad=-1.8290), Var(v=0.1972, grad=0.3641), Var(v=0.1787, grad=-5.3144), Var(v=-0.2476, grad=7.7215), Var(v=-0.1466, grad=-2.4609), Var(v=0.3158, grad=-4.7051), Var(v=-0.0359, grad=2.3325), Var(v=-0.0422, grad=1.6468), Var(v=0.0545, grad=-2.9124), Var(v=0.0418, grad=-2.7776), Var(v=-0.0310, grad=3.4131), Var(v=0.0206, grad=6.6595), Var(v=-0.1226, grad=3.1523), Var(v=-0.1276, grad=7.1939)]] Biases: [Var(v=0.0089, grad=-0.8882), Var(v=-0.0166, grad=1.6619), Var(v=-0.0031, grad=0.3129), Var(v=0.0457, grad=-4.5663), Var(v=0.0702, grad=-7.0162), Var(v=-0.0224, grad=2.2361), Var(v=0.0404, grad=-4.0428), Var(v=0.0212, grad=-2.1195), Var(v=0.0150, grad=-1.4964), Var(v=0.0250, grad=-2.5025), Var(v=0.0239, grad=-2.3866), Var(v=-0.0293, grad=2.9327), Var(v=-0.0572, grad=5.7221), Var(v=0.0286, grad=-2.8643), Var(v=0.0654, grad=-6.5367)]
# Layer 1
#  Weights: [[Var(v=-0.2247, grad=0.0000), Var(v=0.0550, grad=0.0595), Var(v=0.1324, grad=0.0000), Var(v=-0.0330, grad=-0.0004), Var(v=-0.0707, grad=-0.0075), Var(v=-0.0513, grad=0.0242), Var(v=0.1347, grad=0.0000), Var(v=0.0617, grad=0.0373), Var(v=0.1467, grad=-0.1003), Var(v=-0.2901, grad=-0.0378), Var(v=-0.0574, grad=0.0000), Var(v=0.0933, grad=0.0000), Var(v=0.0836, grad=0.0000), Var(v=0.0805, grad=0.0000), Var(v=-0.0651, grad=-0.0256), Var(v=0.0477, grad=0.0387), Var(v=-0.0350, grad=0.0000), Var(v=0.0452, grad=0.0000), Var(v=-0.0104, grad=0.0000), Var(v=0.1432, grad=0.0000), Var(v=-0.0080, grad=-0.0288), Var(v=-0.0747, grad=-0.1163), Var(v=-0.0170, grad=-0.0422), Var(v=-0.0561, grad=0.0374), Var(v=-0.1679, grad=0.0000), Var(v=-0.0775, grad=0.0000), Var(v=-0.0199, grad=0.0000), Var(v=0.0855, grad=-0.0093), Var(v=0.0964, grad=0.0000), Var(v=0.1174, grad=-0.0740), Var(v=0.1903, grad=-0.0510), Var(v=-0.0392, grad=0.0156), Var(v=-0.1313, grad=0.0000), Var(v=-0.0844, grad=0.0000), Var(v=-0.1119, grad=-0.0397), Var(v=0.0586, grad=0.0000), Var(v=0.0520, grad=-0.0298), Var(v=-0.1556, grad=0.0000), Var(v=-0.0067, grad=-0.0655), Var(v=0.0739, grad=0.0000), Var(v=-0.0060, grad=0.0038), Var(v=0.1115, grad=0.0000), Var(v=0.0740, grad=0.0000), Var(v=-0.0215, grad=0.0411), Var(v=0.0607, grad=0.0015), Var(v=0.0544, grad=0.0000), Var(v=0.1443, grad=0.0000), Var(v=-0.0161, grad=0.0000), Var(v=-0.1619, grad=0.0000), Var(v=-0.0233, grad=0.0000)], [Var(v=-0.2746, grad=0.0000), Var(v=-0.2212, grad=0.0165), Var(v=0.0719, grad=0.0000), Var(v=0.1481, grad=-0.0001), Var(v=-0.1397, grad=-0.0021), Var(v=0.0197, grad=0.0067), Var(v=-0.0934, grad=0.0000), Var(v=-0.0663, grad=0.0104), Var(v=-0.0760, grad=-0.0279), Var(v=0.0347, grad=-0.0105), Var(v=0.1042, grad=0.0000), Var(v=0.0449, grad=0.0000), Var(v=0.0686, grad=0.0000), Var(v=-0.1068, grad=0.0000), Var(v=-0.0672, grad=-0.0071), Var(v=-0.1311, grad=0.0107), Var(v=-0.1058, grad=0.0000), Var(v=0.1109, grad=0.0000), Var(v=0.0847, grad=0.0000), Var(v=-0.0769, grad=0.0000), Var(v=-0.0539, grad=-0.0080), Var(v=-0.1311, grad=-0.0323), Var(v=-0.0348, grad=-0.0117), Var(v=0.0059, grad=0.0104), Var(v=-0.0197, grad=0.0000), Var(v=-0.2386, grad=0.0000), Var(v=-0.0434, grad=0.0000), Var(v=-0.1524, grad=-0.0026), Var(v=0.0695, grad=0.0000), Var(v=0.0051, grad=-0.0205), Var(v=0.0027, grad=-0.0142), Var(v=-0.0069, grad=0.0043), Var(v=-0.1028, grad=0.0000), Var(v=0.0897, grad=0.0000), Var(v=-0.0543, grad=-0.0110), Var(v=-0.0163, grad=0.0000), Var(v=-0.1214, grad=-0.0083), Var(v=0.0812, grad=0.0000), Var(v=0.0389, grad=-0.0182), Var(v=-0.0283, grad=0.0000), Var(v=0.0120, grad=0.0011), Var(v=0.0526, grad=0.0000), Var(v=-0.0645, grad=0.0000), Var(v=-0.0691, grad=0.0114), Var(v=-0.0565, grad=0.0004), Var(v=0.0340, grad=0.0000), Var(v=-0.0935, grad=0.0000), Var(v=-0.1142, grad=0.0000), Var(v=0.1760, grad=0.0000), Var(v=-0.1904, grad=0.0000)], [Var(v=-0.1930, grad=0.0000), Var(v=0.0859, grad=-2.7098), Var(v=0.0613, grad=0.0000), Var(v=-0.0352, grad=0.0000), Var(v=-0.0642, grad=0.0000), Var(v=0.1371, grad=-1.1015), Var(v=0.1263, grad=0.0000), Var(v=-0.1685, grad=0.0000), Var(v=-0.1195, grad=0.0000), Var(v=-0.1990, grad=0.0000), Var(v=-0.0522, grad=0.0000), Var(v=-0.2055, grad=0.0000), Var(v=-0.1984, grad=0.0000), Var(v=0.0047, grad=0.0000), Var(v=-0.0636, grad=1.1655), Var(v=0.0138, grad=0.0000), Var(v=0.0556, grad=0.0000), Var(v=-0.1583, grad=0.0000), Var(v=-0.1015, grad=0.0000), Var(v=-0.0316, grad=0.0000), Var(v=-0.0286, grad=0.0000), Var(v=0.0202, grad=5.2992), Var(v=0.0572, grad=1.9230), Var(v=-0.0493, grad=-1.7055), Var(v=-0.1002, grad=0.0000), Var(v=-0.0314, grad=0.0000), Var(v=0.0687, grad=0.5107), Var(v=-0.0987, grad=0.0000), Var(v=0.0020, grad=-0.2372), Var(v=0.1637, grad=3.3707), Var(v=-0.0376, grad=0.0000), Var(v=0.1153, grad=-0.7125), Var(v=0.0398, grad=0.0000), Var(v=0.0592, grad=0.0000), Var(v=-0.0921, grad=1.8085), Var(v=0.0367, grad=-0.2460), Var(v=0.0922, grad=1.3557), Var(v=-0.0201, grad=-1.0359), Var(v=- ...
# Layer 2
#  Weights: [[Var(v=-0.0273, grad=0.0000)], [Var(v=0.1552, grad=-2.0359)], [Var(v=0.0776, grad=0.0000)], [Var(v=-0.0355, grad=3.4567)], [Var(v=-0.0235, grad=0.6540)], [Var(v=0.0966, grad=-4.1759)], [Var(v=0.1974, grad=0.0000)], [Var(v=0.0810, grad=0.3455)], [Var(v=-0.2470, grad=1.9600)], [Var(v=-0.0860, grad=0.0359)], [Var(v=0.1034, grad=0.0000)], [Var(v=-0.0311, grad=0.0000)], [Var(v=-0.0524, grad=0.0000)], [Var(v=-0.0413, grad=0.0000)], [Var(v=-0.0582, grad=0.0206)], [Var(v=0.0791, grad=0.8532)], [Var(v=-0.0137, grad=0.0000)], [Var(v=-0.0040, grad=0.0000)], [Var(v=-0.1016, grad=0.0000)], [Var(v=0.0266, grad=0.0000)], [Var(v=-0.0815, grad=1.6133)], [Var(v=-0.2643, grad=0.0685)], [Var(v=-0.0793, grad=-1.6357)], [Var(v=0.0786, grad=0.6231)], [Var(v=0.1616, grad=0.0000)], [Var(v=-0.2373, grad=0.0000)], [Var(v=-0.0195, grad=-0.5913)], [Var(v=-0.0470, grad=2.5924)], [Var(v=0.0574, grad=-4.5588)], [Var(v=-0.1934, grad=2.5772)], [Var(v=-0.1182, grad=0.2638)], [Var(v=0.0543, grad=-1.8836)], [Var(v=0.1358, grad=0.0000)], [Var(v=-0.0427, grad=0.0000)], [Var(v=-0.1026, grad=1.2603)], [Var(v=0.0130, grad=-0.0737)], [Var(v=-0.0487, grad=-1.8778)], [Var(v=0.0682, grad=-1.6696)], [Var(v=-0.1672, grad=1.8824)], [Var(v=-0.1291, grad=0.0000)], [Var(v=0.0439, grad=-3.5245)], [Var(v=0.0346, grad=-2.5700)], [Var(v=0.0350, grad=-4.1182)], [Var(v=0.1549, grad=-6.1707)], [Var(v=-0.0421, grad=4.5368)], [Var(v=0.1210, grad=-3.0488)], [Var(v=0.0619, grad=-6.1192)], [Var(v=0.2024, grad=-2.2161)], [Var(v=0.0280, grad=-2.1165)], [Var(v=0.0252, grad=0.0000)]] Biases: [Var(v=0.0035, grad=-0.3504)]
#
# Network after zeroing gradients:
# Layer 0
#  Weights: [[Var(v=-0.0145, grad=0.0000), Var(v=0.0170, grad=0.0000), Var(v=0.1972, grad=0.0000), Var(v=0.1787, grad=0.0000), Var(v=-0.2476, grad=0.0000), Var(v=-0.1466, grad=0.0000), Var(v=0.3158, grad=0.0000), Var(v=-0.0359, grad=0.0000), Var(v=-0.0422, grad=0.0000), Var(v=0.0545, grad=0.0000), Var(v=0.0418, grad=0.0000), Var(v=-0.0310, grad=0.0000), Var(v=0.0206, grad=0.0000), Var(v=-0.1226, grad=0.0000), Var(v=-0.1276, grad=0.0000)]] Biases: [Var(v=0.0089, grad=0.0000), Var(v=-0.0166, grad=0.0000), Var(v=-0.0031, grad=0.0000), Var(v=0.0457, grad=0.0000), Var(v=0.0702, grad=0.0000), Var(v=-0.0224, grad=0.0000), Var(v=0.0404, grad=0.0000), Var(v=0.0212, grad=0.0000), Var(v=0.0150, grad=0.0000), Var(v=0.0250, grad=0.0000), Var(v=0.0239, grad=0.0000), Var(v=-0.0293, grad=0.0000), Var(v=-0.0572, grad=0.0000), Var(v=0.0286, grad=0.0000), Var(v=0.0654, grad=0.0000)]
# Layer 1
#  Weights: [[Var(v=-0.2247, grad=0.0000), Var(v=0.0550, grad=0.0000), Var(v=0.1324, grad=0.0000), Var(v=-0.0330, grad=0.0000), Var(v=-0.0707, grad=0.0000), Var(v=-0.0513, grad=0.0000), Var(v=0.1347, grad=0.0000), Var(v=0.0617, grad=0.0000), Var(v=0.1467, grad=0.0000), Var(v=-0.2901, grad=0.0000), Var(v=-0.0574, grad=0.0000), Var(v=0.0933, grad=0.0000), Var(v=0.0836, grad=0.0000), Var(v=0.0805, grad=0.0000), Var(v=-0.0651, grad=0.0000), Var(v=0.0477, grad=0.0000), Var(v=-0.0350, grad=0.0000), Var(v=0.0452, grad=0.0000), Var(v=-0.0104, grad=0.0000), Var(v=0.1432, grad=0.0000), Var(v=-0.0080, grad=0.0000), Var(v=-0.0747, grad=0.0000), Var(v=-0.0170, grad=0.0000), Var(v=-0.0561, grad=0.0000), Var(v=-0.1679, grad=0.0000), Var(v=-0.0775, grad=0.0000), Var(v=-0.0199, grad=0.0000), Var(v=0.0855, grad=0.0000), Var(v=0.0964, grad=0.0000), Var(v=0.1174, grad=0.0000), Var(v=0.1903, grad=0.0000), Var(v=-0.0392, grad=0.0000), Var(v=-0.1313, grad=0.0000), Var(v=-0.0844, grad=0.0000), Var(v=-0.1119, grad=0.0000), Var(v=0.0586, grad=0.0000), Var(v=0.0520, grad=0.0000), Var(v=-0.1556, grad=0.0000), Var(v=-0.0067, grad=0.0000), Var(v=0.0739, grad=0.0000), Var(v=-0.0060, grad=0.0000), Var(v=0.1115, grad=0.0000), Var(v=0.0740, grad=0.0000), Var(v=-0.0215, grad=0.0000), Var(v=0.0607, grad=0.0000), Var(v=0.0544, grad=0.0000), Var(v=0.1443, grad=0.0000), Var(v=-0.0161, grad=0.0000), Var(v=-0.1619, grad=0.0000), Var(v=-0.0233, grad=0.0000)], [Var(v=-0.2746, grad=0.0000), Var(v=-0.2212, grad=0.0000), Var(v=0.0719, grad=0.0000), Var(v=0.1481, grad=0.0000), Var(v=-0.1397, grad=0.0000), Var(v=0.0197, grad=0.0000), Var(v=-0.0934, grad=0.0000), Var(v=-0.0663, grad=0.0000), Var(v=-0.0760, grad=0.0000), Var(v=0.0347, grad=0.0000), Var(v=0.1042, grad=0.0000), Var(v=0.0449, grad=0.0000), Var(v=0.0686, grad=0.0000), Var(v=-0.1068, grad=0.0000), Var(v=-0.0672, grad=0.0000), Var(v=-0.1311, grad=0.0000), Var(v=-0.1058, grad=0.0000), Var(v=0.1109, grad=0.0000), Var(v=0.0847, grad=0.0000), Var(v=-0.0769, grad=0.0000), Var(v=-0.0539, grad=0.0000), Var(v=-0.1311, grad=0.0000), Var(v=-0.0348, grad=0.0000), Var(v=0.0059, grad=0.0000), Var(v=-0.0197, grad=0.0000), Var(v=-0.2386, grad=0.0000), Var(v=-0.0434, grad=0.0000), Var(v=-0.1524, grad=0.0000), Var(v=0.0695, grad=0.0000), Var(v=0.0051, grad=0.0000), Var(v=0.0027, grad=0.0000), Var(v=-0.0069, grad=0.0000), Var(v=-0.1028, grad=0.0000), Var(v=0.0897, grad=0.0000), Var(v=-0.0543, grad=0.0000), Var(v=-0.0163, grad=0.0000), Var(v=-0.1214, grad=0.0000), Var(v=0.0812, grad=0.0000), Var(v=0.0389, grad=0.0000), Var(v=-0.0283, grad=0.0000), Var(v=0.0120, grad=0.0000), Var(v=0.0526, grad=0.0000), Var(v=-0.0645, grad=0.0000), Var(v=-0.0691, grad=0.0000), Var(v=-0.0565, grad=0.0000), Var(v=0.0340, grad=0.0000), Var(v=-0.0935, grad=0.0000), Var(v=-0.1142, grad=0.0000), Var(v=0.1760, grad=0.0000), Var(v=-0.1904, grad=0.0000)], [Var(v=-0.1930, grad=0.0000), Var(v=0.0859, grad=0.0000), Var(v=0.0613, grad=0.0000), Var(v=-0.0352, grad=0.0000), Var(v=-0.0642, grad=0.0000), Var(v=0.1371, grad=0.0000), Var(v=0.1263, grad=0.0000), Var(v=-0.1685, grad=0.0000), Var(v=-0.1195, grad=0.0000), Var(v=-0.1990, grad=0.0000), Var(v=-0.0522, grad=0.0000), Var(v=-0.2055, grad=0.0000), Var(v=-0.1984, grad=0.0000), Var(v=0.0047, grad=0.0000), Var(v=-0.0636, grad=0.0000), Var(v=0.0138, grad=0.0000), Var(v=0.0556, grad=0.0000), Var(v=-0.1583, grad=0.0000), Var(v=-0.1015, grad=0.0000), Var(v=-0.0316, grad=0.0000), Var(v=-0.0286, grad=0.0000), Var(v=0.0202, grad=0.0000), Var(v=0.0572, grad=0.0000), Var(v=-0.0493, grad=0.0000), Var(v=-0.1002, grad=0.0000), Var(v=-0.0314, grad=0.0000), Var(v=0.0687, grad=0.0000), Var(v=-0.0987, grad=0.0000), Var(v=0.0020, grad=0.0000), Var(v=0.1637, grad=0.0000), Var(v=-0.0376, grad=0.0000), Var(v=0.1153, grad=0.0000), Var(v=0.0398, grad=0.0000), Var(v=0.0592, grad=0.0000), Var(v=-0.0921, grad=0.0000), Var(v=0.0367, grad=0.0000), Var(v=0.0922, grad=0.0000), Var(v=-0.0201, grad=0.0000), Var(v=-0.2132, grad=0.0000), Var(v=-0.1151 ...
# Layer 2
#  Weights: [[Var(v=-0.0273, grad=0.0000)], [Var(v=0.1552, grad=0.0000)], [Var(v=0.0776, grad=0.0000)], [Var(v=-0.0355, grad=0.0000)], [Var(v=-0.0235, grad=0.0000)], [Var(v=0.0966, grad=0.0000)], [Var(v=0.1974, grad=0.0000)], [Var(v=0.0810, grad=0.0000)], [Var(v=-0.2470, grad=0.0000)], [Var(v=-0.0860, grad=0.0000)], [Var(v=0.1034, grad=0.0000)], [Var(v=-0.0311, grad=0.0000)], [Var(v=-0.0524, grad=0.0000)], [Var(v=-0.0413, grad=0.0000)], [Var(v=-0.0582, grad=0.0000)], [Var(v=0.0791, grad=0.0000)], [Var(v=-0.0137, grad=0.0000)], [Var(v=-0.0040, grad=0.0000)], [Var(v=-0.1016, grad=0.0000)], [Var(v=0.0266, grad=0.0000)], [Var(v=-0.0815, grad=0.0000)], [Var(v=-0.2643, grad=0.0000)], [Var(v=-0.0793, grad=0.0000)], [Var(v=0.0786, grad=0.0000)], [Var(v=0.1616, grad=0.0000)], [Var(v=-0.2373, grad=0.0000)], [Var(v=-0.0195, grad=0.0000)], [Var(v=-0.0470, grad=0.0000)], [Var(v=0.0574, grad=0.0000)], [Var(v=-0.1934, grad=0.0000)], [Var(v=-0.1182, grad=0.0000)], [Var(v=0.0543, grad=0.0000)], [Var(v=0.1358, grad=0.0000)], [Var(v=-0.0427, grad=0.0000)], [Var(v=-0.1026, grad=0.0000)], [Var(v=0.0130, grad=0.0000)], [Var(v=-0.0487, grad=0.0000)], [Var(v=0.0682, grad=0.0000)], [Var(v=-0.1672, grad=0.0000)], [Var(v=-0.1291, grad=0.0000)], [Var(v=0.0439, grad=0.0000)], [Var(v=0.0346, grad=0.0000)], [Var(v=0.0350, grad=0.0000)], [Var(v=0.1549, grad=0.0000)], [Var(v=-0.0421, grad=0.0000)], [Var(v=0.1210, grad=0.0000)], [Var(v=0.0619, grad=0.0000)], [Var(v=0.2024, grad=0.0000)], [Var(v=0.0280, grad=0.0000)], [Var(v=0.0252, grad=0.0000)]] Biases: [Var(v=0.0035, grad=0.0000)]
# [None, None, None]

# %%
# Initialize an arbitrary neural network
NN = [
    DenseLayer(1, 8, lambda x: x.relu()),
    DenseLayer(8, 1, lambda x: x.identity())
]

# Recommended hyper-parameters for 3-D:
#NN = [
#    DenseLayer(3, 16, lambda x: x.relu()),
#    DenseLayer(16, 1, lambda x: x.identity())
#]


### Notice that, when we switch from tanh to relu activation, we decrease the learning rate. This is due the stability of the gradients
## of the activation functions.

# %%
# Initialize training hyperparameters
EPOCHS = 200
LEARN_R = 2e-3

# %%
train_loss = []
val_loss = []

for e in range(EPOCHS):

    # Forward pass and loss computation
    Loss = squared_loss(y_train, forward(x_train, NN))

    # Backward pass
    Loss.backward()

    # gradient descent update
    update_parameters(parameters(NN), LEARN_R)
    zero_gradients(parameters(NN))

    # Training loss
    train_loss.append(Loss.v)

    # Validation
    Loss_validation = squared_loss(y_validation, forward(x_validation, NN))
    val_loss.append(Loss_validation.v)

    if e%10==0:
        print("{:4d}".format(e),
              "({:5.2f}%)".format(e/EPOCHS*100),
              "Train loss: {:4.3f} \t Validation loss: {:4.3f}".format(train_loss[-1], val_loss[-1]))
# Out:
#    0 ( 0.00%) Train loss: 105.058 	 Validation loss: 104.827
#   10 ( 5.00%) Train loss: 27.984 	 Validation loss: 19.351
#   20 (10.00%) Train loss: 14.606 	 Validation loss: 10.837
#   30 (15.00%) Train loss: 14.204 	 Validation loss: 10.563
#   40 (20.00%) Train loss: 13.893 	 Validation loss: 10.397
#   50 (25.00%) Train loss: 13.510 	 Validation loss: 10.161
#   60 (30.00%) Train loss: 13.024 	 Validation loss: 9.877
#   70 (35.00%) Train loss: 12.577 	 Validation loss: 9.582
#   80 (40.00%) Train loss: 12.315 	 Validation loss: 9.397
#   90 (45.00%) Train loss: 12.158 	 Validation loss: 9.336
#  100 (50.00%) Train loss: 12.048 	 Validation loss: 9.302
#  110 (55.00%) Train loss: 11.968 	 Validation loss: 9.238
#  120 (60.00%) Train loss: 11.934 	 Validation loss: 9.196
#  130 (65.00%) Train loss: 11.914 	 Validation loss: 9.157
#  140 (70.00%) Train loss: 11.904 	 Validation loss: 9.128
#  150 (75.00%) Train loss: 11.898 	 Validation loss: 9.107
#  160 (80.00%) Train loss: 11.896 	 Validation loss: 9.090
#  170 (85.00%) Train loss: 11.894 	 Validation loss: 9.078
#  180 (90.00%) Train loss: 11.893 	 Validation loss: 9.069
#  190 (95.00%) Train loss: 11.893 	 Validation loss: 9.062

# %%
plt.plot(range(len(train_loss)), train_loss);
plt.plot(range(len(val_loss)), val_loss);

# %% [markdown]
# # Testing
#
# We have kept the calculation of the test error separate in order to emphasize that you should not use the test set in optimization.

# %%
output_test = forward(x_test, NN)

# %%
y_test_np = Var_to_nparray(y_test)
plt.scatter(y_test_np, Var_to_nparray(output_test));
plt.plot([np.min(y_test_np), np.max(y_test_np)], [np.min(y_test_np), np.max(y_test_np)], color='k');
plt.xlabel("y");
plt.ylabel("$\hat{y}$");
plt.title("Model prediction vs real in the test set, the close to the line the better")
plt.grid(True);
plt.axis('equal');
plt.tight_layout();

Loss_test = squared_loss(y_test, forward(x_test, NN))

print("Test loss:  {:4.3f}".format(Loss_test.v))
# Out:
# Test loss:  9.852

# %%
x_test_np = Var_to_nparray(x_test)
x_train_np = Var_to_nparray(x_train)
y_train_np = Var_to_nparray(y_train)
if D1:
    plt.scatter(x_train_np, y_train_np, label="train data");
    plt.scatter(x_test_np, Var_to_nparray(output_test), label="test prediction");
    plt.scatter(x_test_np, y_test_np, label="test data");
    plt.legend();
    plt.xlabel("x");
    plt.ylabel("y");
else:
    plt.scatter(x_train_np[:,1], y_train, label="train data");
    plt.scatter(x_test_np[:,1], Var_to_nparray(output_test), label="test data prediction");
    plt.scatter(x_test_np[:,1], y_test_np, label="test data");
    plt.legend();
    plt.xlabel("x");
    plt.ylabel("y");

# %% [markdown]
# ## Exercise l) Show overfitting, underfitting and just right fitting
#
# Vary the architecture and other things to show clear signs of overfitting (=training loss significantly lower than test loss) and underfitting (=not fitting enoung to training data so that test performance is also hurt).
#
# See also if you can get a good compromise which leads to a low validation loss.
#
# For this problem do you see any big difference between validation and test loss? The answer here will probably be no. Discuss cases where it is important to keep the two separate.

# %% [markdown]
# **Answer**
# ##### Underfitting
# We define a new neural network, with a single hidden layer with a width of 32 neurons. We train this model for a only 20 epochs which is a lot less than we did before. This yields very substantially higher training and testing error, thus showing underfitting as the model ends with the following loss scores:
# ```py
# 19 (100.00%) Train loss: 17.770 	 Validation loss: 14.492
# ```

# %%
NN_under = [
    DenseLayer(1, 32, lambda x: x.relu()),
    DenseLayer(32, 1, lambda x: x.identity())
]

# %%
# Insert your code for getting overfitting, underfitting and just right fitting
train_loss = []
val_loss = []

EPOCHS = 20
LEARN_R = 0.0008

for e in range(EPOCHS):

    # Forward pass and loss computation
    Loss = squared_loss(y_train, forward(x_train, NN_under))

    # Backward pass
    Loss.backward()

    # gradient descent update
    update_parameters(parameters(NN_under), LEARN_R)
    zero_gradients(parameters(NN_under))

    # Training loss
    train_loss.append(Loss.v)

    # Validation
    Loss_validation = squared_loss(y_validation, forward(x_validation, NN_under))
    val_loss.append(Loss_validation.v)

    if e%5==0 or e==EPOCHS-1:
        print("{:4d}".format(e),
              "({:5.2f}%)".format((e+1)/EPOCHS*100),
              "Train loss: {:4.3f} \t Validation loss: {:4.3f}".format(train_loss[-1], val_loss[-1]))
# Out:
#    0 ( 5.00%) Train loss: 103.492 	 Validation loss: 100.215
#    5 (30.00%) Train loss: 77.748 	 Validation loss: 72.858
#   10 (55.00%) Train loss: 49.266 	 Validation loss: 43.200
#   15 (80.00%) Train loss: 26.315 	 Validation loss: 21.873
#   19 (100.00%) Train loss: 17.770 	 Validation loss: 14.420

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4))

fig.suptitle("Loss during training (Underfitting case)", fontsize=16)

ax1.grid(color="0.7",zorder=0)
ax1.scatter(range(len(train_loss)), train_loss, label="Training loss",zorder=2)
ax1.plot(range(len(train_loss)), train_loss,zorder=2)
ax1.scatter(range(len(val_loss)), val_loss, label="Validation loss",zorder=2)
ax1.plot(range(len(val_loss)), val_loss,zorder=2)
ax1.legend()
ax1.set_xlabel("Linear plot of loss during training", fontsize=12)

ax2.semilogy()
ax2.grid()
ax2.grid(which="minor", color="0.8",zorder=0)
ax2.scatter(range(len(train_loss)), train_loss, label="Training loss",zorder=2)
ax2.plot(range(len(train_loss)), train_loss,zorder=2)
ax2.scatter(range(len(val_loss)), val_loss, label="Validation loss",zorder=2)
ax2.plot(range(len(val_loss)), val_loss,zorder=2)
ax2.legend()
ax2.set_xlabel("Log plot of loss during training", fontsize=12)


plt.show()

# %% [markdown]
# #### Overfitting

# %%
# Initialize an arbitrary neural network
NN = [
    DenseLayer(1, 10, lambda x: x.relu()),
    DenseLayer(10, 12, lambda x: x.relu()),
    DenseLayer(12, 1, lambda x: x.identity())
]

# %%
# Initialize training hyperparameters
EPOCHS = 3000
LEARN_R = 0.002

# %%
train_loss = []
val_loss = []
avgs = []
avgavg = 0
learningrate_history = []

for e in range(EPOCHS):

    # Forward pass and loss computation
    Loss = squared_loss(y_train, forward(x_train, NN))

    # Backward pass
    Loss.backward()

    # gradient descent update
    learningraterightnow =  LEARN_R - ((e/(EPOCHS / LEARN_R))) + 0.0005
    
    if (e < 75):
        learningraterightnow *= 1.5 - (e/150)

    if((e > 75) and (e < 125)):
        train_loss_last_10 = train_loss[-10:]
        train_loss_last_10_but_not_last = train_loss_last_10[:9]
        
        last = train_loss[-1]
        tlb = train_loss_last_10_but_not_last
        avg = sum([(tlb[i] - last) for i in range(len(tlb))]) / len(tlb)
        avgs.append(avg)
        avgavg = abs(sum(avgs) / len(avgs))
    
    if(e == 125):
        print("avgavg: " + str(avgavg))
    
    if((e > 125)):
        train_loss_last_20 = train_loss[-20:]
        train_loss_last_20_but_not_last5 = train_loss_last_20[:15]
        
        last5 = train_loss[-5:]
        last5avg = sum(last5) / len(last5)
        tlb20 = train_loss_last_20_but_not_last5
        avg = sum([(tlb20[i] - last5avg) for i in range(len(tlb20))]) / len(tlb20)
        #targetROC = avgavg * (4 - ((e*3.5)/EPOCHS))
        targetROC = avgavg * ((3 - ((e*3.5)/EPOCHS) + (5 * ((- ((e/EPOCHS)-0.65))**2)))) * 0.75
        #LRboost = exp((log(targetROC) - log(abs(avg)) ) )
        LRboost = log((targetROC + targetROC/12) / (abs(avg) + targetROC/12), 12)
        
        #print(LRboost)


        learningraterightnow += (learningraterightnow * LRboost)
        if(e % 5 == 0):
            print("(LRBoost) " + str(LRboost * LEARN_R) + ", avgavg: " + str(avgavg) + ", " + "avg: " + str(avg))

    if (learningraterightnow < 0.00075):
        learningraterightnow = 0.00075


    learningrate_history.append(learningraterightnow)

    update_parameters(parameters(NN), learningraterightnow)
    zero_gradients(parameters(NN))

    # Training loss
    train_loss.append(Loss.v)

    # Validation
    Loss_validation = squared_loss(y_validation, forward(x_validation, NN))
    val_loss.append(Loss_validation.v)

    if e%5==0:
        print(learningraterightnow)
        print("{:4d}".format(e),
              "({:5.2f}%)".format(e/EPOCHS*100),
# (LRBoost) 0.00039999108474338276, avgavg: 0.013240255410128444, avg: 0.0007404519081977294
# 0.00075
# 2825 (94.17%) Train loss: 7.0079 	 Validation loss: 7.0666 	 Learning rate: 0.00075
# (LRBoost) 0.0003537725950069467, avgavg: 0.013240255410128444, avg: 0.0007847013257703613
# 0.00075
# 2830 (94.33%) Train loss: 7.0071 	 Validation loss: 7.0670 	 Learning rate: 0.00075
# (LRBoost) 0.0004158520440214904, avgavg: 0.013240255410128444, avg: 0.0007133538076709319
# 0.00075
# 2835 (94.50%) Train loss: 7.0058 	 Validation loss: 7.0664 	 Learning rate: 0.00075
# (LRBoost) 0.0001488117827546244, avgavg: 0.013240255410128444, avg: 0.0010282531598488612
# 0.00075
# 2840 (94.67%) Train loss: 7.0057 	 Validation loss: 7.0744 	 Learning rate: 0.00075
# (LRBoost) 0.0002979514889024158, avgavg: 0.013240255410128444, avg: 0.0008308161983232291
# 0.00075
# 2845 (94.83%) Train loss: 7.0055 	 Validation loss: 7.0752 	 Learning rate: 0.00075
# (LRBoost) 0.00020241771715590493, avgavg: 0.013240255410128444, avg: 0.0009422603491543077
# 0.00075
# 2850 (95.00%) Train loss: 7.0060 	 Validation loss: 7.0687 	 Learning rate: 0.00075
# (LRBoost) 0.00042636590732331707, avgavg: 0.013240255410128444, avg: 0.0006837595404597016
# 0.00075
# 2855 (95.17%) Train loss: 7.0051 	 Validation loss: 7.0696 	 Learning rate: 0.00075
# (LRBoost) 0.0003652794341382431, avgavg: 0.013240255410128444, avg: 0.000741023503546027
# 0.00075
# 2860 (95.33%) Train loss: 7.0038 	 Validation loss: 7.0690 	 Learning rate: 0.00075
# (LRBoost) 0.00023253824094265582, avgavg: 0.013240255410128444, avg: 0.0008866768189760658
# 0.00075
# 2865 (95.50%) Train loss: 7.0036 	 Validation loss: 7.0778 	 Learning rate: 0.00075
# (LRBoost) 0.0003064581311512251, avgavg: 0.013240255410128444, avg: 0.0007951636911688098
# 0.00075
# 2870 (95.67%) Train loss: 7.0042 	 Validation loss: 7.0727 	 Learning rate: 0.00075
# (LRBoost) 0.00029033103492195477, avgavg: 0.013240255410128444, avg: 0.0008085723198000494
# 0.00075
# 2875 (95.83%) Train loss: 7.0036 	 Validation loss: 7.0714 	 Learning rate: 0.00075
# (LRBoost) 0.000507145128381349, avgavg: 0.013240255410128444, avg: 0.0005906131764769877
# 0.00075
# 2880 (96.00%) Train loss: 7.0023 	 Validation loss: 7.0711 	 Learning rate: 0.00075
# (LRBoost) 0.00021717868383559273, avgavg: 0.013240255410128444, avg: 0.0008851984867150146
# 0.00075
# 2885 (96.17%) Train loss: 7.0021 	 Validation loss: 7.0801 	 Learning rate: 0.00075
# (LRBoost) 0.0002922043566095254, avgavg: 0.013240255410128444, avg: 0.0007934266612916
# 0.00075
# 2890 (96.33%) Train loss: 7.0028 	 Validation loss: 7.0750 	 Learning rate: 0.00075
# (LRBoost) 0.0005403775568857457, avgavg: 0.013240255410128444, avg: 0.0005539345603025936
# 0.00075
# (LRBoost) 0.0003044346500655244, avgavg: 0.013240255410128444, avg: 0.0007392664908230391
# 0.00075
# 2970 (99.00%) Train loss: 6.9971 	 Validation loss: 7.0852 	 Learning rate: 0.00075
# (LRBoost) 0.0005865633900370942, avgavg: 0.013240255410128444, avg: 0.0004923593042165682
# 0.00075
# 2975 (99.17%) Train loss: 6.9960 	 Validation loss: 7.0920 	 Learning rate: 0.00075
# (LRBoost) 0.00029035343972168905, avgavg: 0.013240255410128444, avg: 0.0007521109018541713
# 0.00075
# 2980 (99.33%) Train loss: 6.9965 	 Validation loss: 7.0862 	 Learning rate: 0.00075
# (LRBoost) 0.0005277125054855687, avgavg: 0.013240255410128444, avg: 0.0005357360917040311
# 0.00075
# 2985 (99.50%) Train loss: 6.9953 	 Validation loss: 7.0950 	 Learning rate: 0.00075
# (LRBoost) 0.0003021224528801362, avgavg: 0.013240255410128444, avg: 0.0007387452671242892
# 0.00075
# 2990 (99.67%) Train loss: 6.9959 	 Validation loss: 7.0869 	 Learning rate: 0.00075
# (LRBoost) 0.0005789682432073076, avgavg: 0.013240255410128444, avg: 0.0004964421321702161
# 0.00075
# 2995 (99.83%) Train loss: 6.9951 	 Validation loss: 7.0964 	 Learning rate: 0.00075

# %%
# More training. This was run a few times.
for e in range(4000):

    # Forward pass and loss computation
    Loss = squared_loss(y_train, forward(x_train, NN))

    # Backward pass
    Loss.backward()

    # gradient descent update
    learningraterightnow = 0.0008

    learningrate_history.append(learningraterightnow)

    update_parameters(parameters(NN), learningraterightnow)
    zero_gradients(parameters(NN))

    # Training loss
    train_loss.append(Loss.v)

    # Validation
    Loss_validation = squared_loss(y_validation, forward(x_validation, NN))
    val_loss.append(Loss_validation.v)

    if e%5==0:
        print(learningraterightnow)
        print("{:4d}".format(e),
              "({:5.2f}%)".format(e/EPOCHS*100),
              "Train loss: {:4.4f} \t Validation loss: {:4.4f} \t Learning rate: {:4.5f}".format(train_loss[-1], val_loss[-1], learningraterightnow))

# %%
plt.plot(range(len(train_loss)), train_loss)
plt.plot(range(len(val_loss)), val_loss)

# %%
figure, axe = plt.subplots()
color = 'blue'
axe.set_xlabel('Epoch')
axe.set_ylabel('Loss', color=color)
axe.plot(range(100, len(train_loss)), train_loss[100:], zorder=2, label=["Training Loss"])
axe.plot(range(100, len(val_loss)), val_loss[100:], zorder=2, label=["Validation Loss"])
axe.tick_params(axis='y', labelcolor=color)

#axe2 = axe.twinx()


color = 'red'
#axe2.set_ylabel("Learning rate", color=color)
#axe2.plot(range(len(learningrate_history)-100), learningrate_history[100:], zorder=2, label="Learning rate", c='red', alpha=0.3)

# plt.plot(range(len(train_loss)-10), train_loss[10:], zorder=2, label=["Training Loss"])
# plt.plot(range(len(val_loss)-10), val_loss[10:], zorder=2, label=["Validation Loss"])
# plt.plot(range(len(learningrate_history)-10), learningrate_history[10:], zorder=2, label="Learning rate", c='red')
plt.grid(alpha=0.3, zorder=1)
plt.legend()
figure.set_size_inches((12,8))

plt.show()

# %%
figure, axe = plt.subplots()
color = 'blue'
axe.set_xlabel('Epoch')
axe.set_ylabel('Loss', color=color)
axe.plot(range(2000, len(train_loss)), train_loss[2000:], zorder=2, label=["Training Loss"])
axe.plot(range(2000, len(val_loss)), val_loss[2000:], zorder=2, label=["Validation Loss"])
axe.tick_params(axis='y', labelcolor=color)
axe.legend()


#axe2 = axe.twinx()

color = 'red'
#axe2.set_ylabel("Learning rate", color=color)
#axe2.plot(range(len(learningrate_history)-2000), learningrate_history[2000:], zorder=2, label="Learning rate", c='red', alpha=0.3)

#plt.figure(figsize=(12,8))
# plt.plot(range(len(train_loss)-10), train_loss[10:], zorder=2, label=["Training Loss"])
# plt.plot(range(len(val_loss)-10), val_loss[10:], zorder=2, label=["Validation Loss"])
# plt.plot(range(len(learningrate_history)-10), learningrate_history[10:], zorder=2, label="Learning rate", c='red')
figure.set_size_inches((12,8))

plt.grid(alpha=0.3, zorder=1)
plt.show()

# %% [markdown]
# #### Just the right fitting

# %% [markdown]
# For this example we wanted to demonstrate a case where, during learning, the loss for both the test set and validation set would plateau, as such seemingly converge onto specific values. For this, we made a very small model with only 31 parameters, and trained it for 5000 epochs.

# %% [markdown]
# You'll also see we experimented with initializing the model to have random parameters. We believe this made had positive results on how quickly our model learns early on in training, but we don't have quantitative evidence of this.

# %%
NN_just = [
    DenseLayer(1, 10, lambda x: x.relu()),
    DenseLayer(10, 1, lambda x: x.identity())
]
print("Params: " + str(len(parameters(NN_just))))
np.random.seed(42)

kw = 1
kb = kw/2

for layer in NN_just:
    for weight_row in layer.weights:
        for w in weight_row:
            w.v = np.random.uniform(-kw, kw)
    for b in layer.bias:
        b.v = np.random.uniform(-kb, kb)

NN_just[0].bias[0].v = 0

arange = np.arange(0,1,0.01)
function = forward(nparray_to_Var(arange), NN_just)
networkvals = []
for a in range(len(function)):
    networkvals.append(function[a][0].v)

plt.plot(networkvals)
# Out:
# Params: 31

# %%
train_loss = []
val_loss = []

EPOCHS = 5000
LEARN_R = 0.0008

for e in range(EPOCHS):

    # Forward pass and loss computation
    Loss = squared_loss(y_train, forward(x_train, NN_just))

    # Backward pass
    Loss.backward()

    # gradient descent update
    update_parameters(parameters(NN_just), LEARN_R)
    zero_gradients(parameters(NN_just))

    # Training loss
    train_loss.append(Loss.v)


    if e%5==0:
        # Validation (we moved the calculation here because it actually takes quite a while)
        Loss_validation = squared_loss(y_validation, forward(x_validation, NN_just))
        val_loss.append(Loss_validation.v)
        print("{:4d}".format(e),
              "({:5.2f}%)".format((e+1)/EPOCHS*100),
              "Train loss: {:4.4f} \t Validation loss: {:4.4f}".format(train_loss[-1], val_loss[-1]))
# Out:
#    0 ( 0.02%) Train loss: 340.4751 	 Validation loss: 119.8489
#    5 ( 0.12%) Train loss: 30.6535 	 Validation loss: 18.5765
#   10 ( 0.22%) Train loss: 14.1245 	 Validation loss: 10.0109
#   15 ( 0.32%) Train loss: 12.5694 	 Validation loss: 9.2945
#   20 ( 0.42%) Train loss: 12.0996 	 Validation loss: 9.0148
#   25 ( 0.52%) Train loss: 11.8016 	 Validation loss: 8.8067
# 4935 (98.72%) Train loss: 9.4314 	 Validation loss: 6.9303
# 4940 (98.82%) Train loss: 9.4316 	 Validation loss: 6.9303
# 4945 (98.92%) Train loss: 9.4314 	 Validation loss: 6.9300
# 4950 (99.02%) Train loss: 9.4315 	 Validation loss: 6.9304
# 4955 (99.12%) Train loss: 9.4313 	 Validation loss: 6.9300
# 4960 (99.22%) Train loss: 9.4312 	 Validation loss: 6.9301
# 4965 (99.32%) Train loss: 9.4312 	 Validation loss: 6.9299
# 4970 (99.42%) Train loss: 9.4312 	 Validation loss: 6.9300
# 4975 (99.52%) Train loss: 9.4312 	 Validation loss: 6.9298
# 4980 (99.62%) Train loss: 9.4311 	 Validation loss: 6.9299
# 4985 (99.72%) Train loss: 9.4310 	 Validation loss: 6.9298
# 4990 (99.82%) Train loss: 9.4308 	 Validation loss: 6.9304
# 4995 (99.92%) Train loss: 9.4309 	 Validation loss: 6.9298

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4))

fig.suptitle("Loss during training (Just the right fit case)", fontsize=16)

ax1.grid(color="0.7",zorder=0)
ax1.plot(range(50, len(train_loss)), train_loss[50:],zorder=2)
ax1.plot(range(25, len(train_loss), 5), val_loss[5:],zorder=2)
ax1.legend()
ax1.set_xlabel("Linear plot of loss during training (epochs 50+)", fontsize=12)

ax2.grid(color="0.7",zorder=0)
ax2.loglog()
n = 50
ax2.plot(range(n, len(train_loss)), train_loss[n:],zorder=2)
ax2.plot(range(n, len(train_loss), 5), val_loss[int(n/5):],zorder=2)
ax2.legend()
ax2.set_xlabel("Loglog plot of loss (epochs 50+)", fontsize=12)


plt.show()
# Out:
# C:\Users\Main\AppData\Local\Temp\ipykernel_26412\3396497119.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# C:\Users\Main\AppData\Local\Temp\ipykernel_26412\3396497119.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend()

# %% [markdown]
# The plot shows that both the training and the validation loss of the model seems to plateau during training. On the loglog plot we see that both these losses seem to go down somewhat linearly, until their rate of change seems to approach zero. But we can see that they're not exactly zero. Nevertheless, training this model until 10 000 epochs reveals that there are no significant improvements before the validation loss begins to ever so slightly increase again.
#
# <bn> Our model ends its training with a train loss of X and a validation loss of X. Importantly here, if we simply compare the absolute values of these losses, our overfitted model just might be better for this case. Perhaps the real perfect fit would have been the overfitted model right before the validation loss begins to go up again. Nevertheless, we decided that we would attempt to produce a clear example of a 'perfect' fit specifically for a very small model, which we believe we've done.

# %% [markdown]
# # Next steps - classification
#
# It is straight forward to extend what we have done to classification.
#
# For numerical stability it is better to make softmax and cross-entropy as one function so we write the cross entropy loss as a function of the logits we talked about last week.
#
# Next week we will see how to perform classification in PyTorch.

# %% [markdown]
# ## Exercise m) optional - Implement backpropagation for classification
#
# Should be possible with very few lines of code. :-)

# %%
# Just add code.

# %% [markdown]
# ## Exercise n) optional - Introduce a NeuralNetwork class
#
# The functions we applied on the neural network (parameters, update_parameters and zero_gradients) can more naturally be included as methods in a NeuralNetwork class. Make such a class and modify the code to use it.

# %%
# just add some code
