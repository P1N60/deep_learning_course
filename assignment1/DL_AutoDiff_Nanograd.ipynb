# %% [markdown]
# # Contents and why we need this lab
#
# This lab is about implementing neural networks yourself before we start using other frameworks that hide some computation from you. It builds on the first lab, where you derived the equations for neural network forward and backward propagation and gradient descent parameter updates.
#
# All the frameworks for deep learning you will meet from now on use automatic differentiation (autodiff), so you do not have to code the backward step yourself. In this version of this lab, you will develop your own autodif implementation.

# %% [markdown]
# # External source of information
#
# [Nanograd](https://github.com/rasmusbergpalm/nanograd) is a minimalistic version of autodiff developed by [Rasmus Berg Palm](https://rasmusbergpalm.github.io) that we use for our framework.

# %% [markdown]
# # This notebook will follow the next steps:
#
# 1. Nanograd automatic differentiation framework
# 2. Finite difference method
# 3. Data generation
# 4. Defining and initializing the network
# 5. Forward pass
# 6. Training loop
# 7. Testing your model
# 8. Further extensions

# %% [markdown]
# # Nanograd automatic differention framework

# %% [markdown]
# The [Nanograd](https://github.com/rasmusbergpalm/nanograd) framework defines a class Var which both holds a value and gradient value that we can use to store the intermediate values when we apply the chain rule of differentiation.

# %%
# Copy and pasted from https://github.com/rasmusbergpalm/nanograd/blob/3a1bf9e9e724da813bfccf91a6f309abdade9f39/nanograd.py

from math import exp, log

class Var:
    """
    A variable which holds a float and enables gradient computations.
    """

    def __init__(self, val: float, grad_fn=lambda: []):
        assert type(val) == float
        self.v = val
        self.grad_fn = grad_fn
        self.grad = 0.0

    def backprop(self, bp):
        self.grad += bp
        for input, grad in self.grad_fn():
            input.backprop(grad * bp)

    def backward(self):
        self.backprop(1.0)

    def __add__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v + other.v, lambda: [(self, 1.0), (other, 1.0)])

    def __mul__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v * other.v, lambda: [(self, other.v), (other, self.v)])

    def __pow__(self, power):
        assert type(power) in {float, int}, "power must be float or int"
        return Var(self.v ** power, lambda: [(self, power * self.v ** (power - 1))])

    def __neg__(self: 'Var') -> 'Var':
        return Var(-1.0) * self

    def __sub__(self: 'Var', other: 'Var') -> 'Var':
        return self + (-other)

    def __truediv__(self: 'Var', other: 'Var') -> 'Var':
        return self * other ** -1

    def __repr__(self):
        return "Var(v=%.4f, grad=%.4f)" % (self.v, self.grad)

    def relu(self):
        return Var(self.v if self.v > 0.0 else 0.0, lambda: [(self, 1.0 if self.v > 0.0 else 0.0)])
    
    # * Changes from part f)
    def identity(self):
        return Var(self.v, lambda: [(self, 1)])
    
    def tanh(self):
        return Var((exp(self.v)-exp(-self.v))/(exp(self.v)+exp(-self.v)), lambda: [(self, 1-((exp(self.v)-exp(-self.v))/(exp(self.v)+exp(-self.v)))**2)])
    
    def sigmoid(self):
        return Var(1/(1+exp(-self.v)), lambda: [(self, (1/(1+exp(-self.v)))*(1-(1/(1+exp(-self.v)))))])
    
    # * CHanges from part k)
    def exp(self):
        return Var(exp(self.v), lambda: [(self, exp(self.v))])
    
    def log(self):
        return Var(log(self.v), lambda: [(self, self.v ** -1)])

# %% [markdown]
# A few examples illustrate how we can use this:

# %%
a = Var(3.0)
b = Var(5.0)
f = a * b

f.backward()

for v in [a, b, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=5.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)

# %%
a = Var(3.0)
b = Var(5.0)
c = a * b
d = Var(9.0)
e = a * d
f = c + e

f.backward()

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=14.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)
# Var(v=9.0000, grad=3.0000)
# Var(v=27.0000, grad=1.0000)
# Var(v=42.0000, grad=1.0000)

# %% [markdown]
# ## Exercise a) What is being calculated?
#
# Explain briefly the output of the code? What is the expression we differentiate and with respect to what variables?

# %% [markdown]
# **Answer:**
#
# The `Var` class is a class which stores a value, and overloads various operators such that when we perform operations on other instances of `Var`, a new instance of `Var` is returned containing both the calculated value, as well as a lambda function of the resulting gradient from the operation. When we then define chains of operations using our `Var` instances, we get a graph structure that we can iterate over by running the `.backward()` method which updates the gradient of every `Var` in the graph.
# <br> We're given two expressions. For the first one, `a` and `b` are both assigned to a `Var` with their respective values of 3 and 5. `f` is defined to be `a*b`. The calculated value of `f` is 15, while the gradient of `a = 5` and the gradient of `b=3`.
# <br> The following examples appears to be a continuation of the first expression, now with `c = a*b` and `d = Var(9.0)` with `e = a*d`, `f = c+e`. Running the `.backward()` method again we find the gradient of each variable with respect to `f`.

# %% [markdown]
# ## Exercise b) How does the backward function work?
#
# You need to understand how the backward function calculates the gradients. We can use the two examples above to help with that.
#
# Go through the following four steps and answer the questions on the way:
#
# 1. We represent the two expressions as graphs as shown below. Fill in the missing expressions for the different derivatives.
#
# 2. In the remainder, consider the first expression. Make a schematic of the data structure generated when we define the expression for f (e.g., write a list of which objects are created and the corresponding values of their member variables).
#
# 3. Then execute the backward function by hand to convince yourself that it indeed calculates the gradients with respect to the variables.
#
# 4. Write down the sequence of calls to backprop.

# %%
# If you have not installed networkx and matplotlib, you can install them by running
# !pip install networkx matplotlib

import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create a directed graph
G = nx.DiGraph()

# Add edges with labels
G.add_edge('a', 'f', label='df/da=d(ab)/da=b=5')
G.add_edge('b', 'f', label='df/db=d(ab)/db=a=3')

# Manually define positions for a tree layout
pos = {
    'a': (0, 1),
    'b': (0, -1),
    'f': (1, 0),
}
# Draw the graph nodes and edges
nx.draw(G, pos, with_labels=True, node_shape='o', node_size=3000, node_color='lightblue', arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.title("Graph of example one")
plt.show()

# %%
# Create a directed graph
G = nx.DiGraph()

# Add edges with labels
G.add_edge('a', 'f', label='df/da=(df/dc)(dc/da)+(df/de)(de/da)=1*b+1*d=14')
G.add_edge('b', 'f', label='df/db=(df/dc)(dc/db))=1*a=3')

# Manually define positions for a tree layout
pos = {
    'a': (0, 1),
    'b': (0, -1),
    'f': (1, 0),
}
# Draw the graph nodes and edges
nx.draw(G, pos, with_labels=True, node_shape='o', node_size=3000, node_color='lightblue', arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.title("Graph of example two")
plt.show()

# %%
# Create a directed graph
G = nx.DiGraph()

# Add edges with labels
G.add_edge('a', 'c', label='dc/da=d(ab)/a=b=5')
G.add_edge('b', 'c', label='dc/db=d(ab)/db=a=3')
G.add_edge('a', 'e', label='de/da=d(ad)/da=d=9')
G.add_edge('d', 'e', label='de/dd=d(ad)/dd=a=3')
G.add_edge('c', 'f', label='df/dc=d(c+e)/dc=1')
G.add_edge('e', 'f', label='df/de=d(c+e)/de=1')

# Manually define positions for a tree layout
pos = {
    'a': (0, 0),
    'b': (0, 2),
    'c': (1, 1),
    'd': (0, -2),
    'e': (1, -1),
    'f': (2, 0)
}

# Draw the graph nodes and edges
nx.draw(G, pos, with_labels=True, node_shape='o', node_size=3000, node_color='lightblue', arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.title("Graph of example two")
plt.show()

# %% [markdown]
# <br> In the two cells below the `Var` class definition, we have two examples for how to use the `Var` class. In the first example, the following expression is defined:
# $$
# \begin{align}
# f = ab \quad \text{with a = 3, \ and b = 5}
# \end{align}
# $$
# The gradient is automatically calculated by the class when we call the `.backward()` method. This is the computation being performed:
# $$
# \begin{align}
# \text{Example 1:} & \\
# & \text{f.grad} = \frac{\partial f}{\partial f} = \frac{\partial (ab)}{\partial (ab)} = 1 \\
# & \text{b.grad} = \frac{\partial f}{\partial b} = \frac{\partial (ab)}{\partial b} = a = 3 \\
# & \text{a.grad} = \frac{\partial f}{\partial a} = \frac{\partial (ab)}{\partial a} = b = 5 \\
#
# \end{align}
# $$

# %% [markdown]
# For the next example, we perform a calculation defined by this expression:
# $$
# \begin{align}
# & c = ab, \quad e = ad, \quad f = c + e \quad \text{Or, equivalently} \quad f = a(b+d) \\
# & \text{With} \quad a = 3, \quad b = 5,\quad d = 9 \\
# \end{align}
# $$
# The result is this:
# $$
# \begin{align}
# \text{Example 2:} & \\
# \text{f.grad} &= \dfrac{\partial f}{\partial f} = \dfrac{\partial (c+e)}{\partial (c+e)} = 1 \\
# \text{e.grad}&= \dfrac{\partial f}{\partial e} = \dfrac{\partial (c+e)}{\partial e} = 1\\
# \text{c.grad} &= \dfrac{\partial f}{\partial c} = \dfrac{\partial (c+e)}{\partial c} = 1\\
# \text{d.grad} &= \dfrac{\partial f}{\partial b} = \dfrac{\partial f}{\partial e}\dfrac{\partial e}{\partial d} = \dfrac{\partial (c+e)}{\partial e}\dfrac{\partial ad}{\partial d} = a = 3\\
# \text{b.grad} &= \dfrac{\partial f}{\partial b} = \dfrac{\partial f}{\partial c}\dfrac{\partial c}{\partial b} = \dfrac{\partial (c+e)}{\partial c}\dfrac{\partial ab}{\partial b} = a = 3\\
# \text{a.grad} &= \dfrac{\partial f}{\partial a} = \dfrac{\partial f}{\partial c}\dfrac{\partial c}{\partial a}+\dfrac{\partial f}{\partial e}\dfrac{\partial e}{\partial a} = \dfrac{\partial (c+e)}{\partial c}\dfrac{\partial ab}{\partial a}+\dfrac{\partial (c+e)}{\partial e}\dfrac{\partial ad}{\partial a} = 1\cdot b + 1\cdot d = 5 + 9 = 14
# \end{align}
# $$

# %% [markdown]
# ## Exercise c) What happens if we run backward again?
#
# Try to execute the code below. Explain what happens.

# %%
f.backward()

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=28.0000)
# Var(v=5.0000, grad=6.0000)
# Var(v=15.0000, grad=2.0000)
# Var(v=9.0000, grad=6.0000)
# Var(v=27.0000, grad=2.0000)
# Var(v=42.0000, grad=2.0000)

# %% [markdown]
# **Answer:**
# <br>
# We see that the value remains the same as before, but the gradient is applied once more. Running it once more we can understand that the result of the gradient calculation is seemingly added again for every execution. In other words, since we only run backwards again (and thus computes the backpropagation gradients by summing them up), but we don't also run FF, we never actually modify our input, and so backward would yield the same output (grad) as before. Since we sum all gradient for any given neuron, we essentially sum the previous gradient with the current, which we are able to see when running backward multiple times.

# %% [markdown]
# ## Exercise d) Zero gradient
#
# We can zero the gradient by backpropagating a -1.0 as is shown in the example below. (If you have run backward multiple time then you also have to run the cell below an equal amount of times.) Explain what is going on.

# %%
a = Var(2.0)

for v in [a, b, c, d, e, f]:
    print(v)

f.backprop(-1.0)

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=2.0000, grad=0.0000)
# Var(v=5.0000, grad=6.0000)
# Var(v=15.0000, grad=2.0000)
# Var(v=9.0000, grad=6.0000)
# Var(v=27.0000, grad=2.0000)
# Var(v=42.0000, grad=2.0000)
# Var(v=2.0000, grad=0.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)
# Var(v=9.0000, grad=3.0000)
# Var(v=27.0000, grad=1.0000)
# Var(v=42.0000, grad=1.0000)

# %% [markdown]
# **Answer**
# <br> From exercise c) we gathered that the gradients are updated by adding the calculated value to their existing value (initialized at `0`). As such, by backpropagating a `-1.0`, the gradients calculated are precisely (-1) times whatever they were prior. This is because the operation being performed here is entirely linear, consisting only of multiplication and addition. The result, then, is that we add `-x` to `x` for all x, where x is each of the variables, thus canceling out each calculated gradient value resulting in a zero gradient. As we were told in the previous part, when running backward multiple times, we would then need to run "negative backward" an equal amount of times.

# %% [markdown]
# ## Exercise e) Test correctness of derivatives with the finite difference method
#
# Write a small function that uses [the finite difference method](https://en.wikipedia.org/wiki/Finite_difference_method) to numerically test that backpropation implementation is working. In short we will use
# $$
# \frac{\partial f(a)}{\partial a} \approx \frac{f(a+da)-f(a)}{da}
# $$
# for $da \ll 1$.
#
# As an example, we could approximate the derivative of the function $f(a)=a^2$ in e.g. the value $a=4$ using the finite difference method. This amounts to inserting the relevant values and approximating the gradient $f'(4)$ with the fraction above.

# %% [markdown]
# **Answer:**

# %%
# f function - try to change the code to test other types of functions as well (such as different polynomials etc.)
def f_function(a):
  a = Var(a)
  f = a ** 2
  f.backward()
  return a,f

# here is the arbitrary polynomial -0.4x^3 + 5x^2 + 2x - 5
def f_function2(a):
  a = Var(a)
  b = a ** 3
  c = Var(-0.4) * b
  d = a ** 2
  e = Var(5.0) * d
  f = Var(2.0) * a
  g = Var(-3.0)
  h = c + e 
  i = f + g
  j = h + i
  j.backward()
  return a,j

print("Function 1: (autodif)")
for v in f_function(4.0):
  print(v)

print("Function 2 (autodiff):")
for v in f_function2(4.0):
  print(v)

# Insert your finite difference code here
def finite_difference(da=1e-10):
    """
    This function compute the finite difference between

    Input:
    da:          The finite difference                           (float)

    Output:
    finite_difference: numerical approximation to the derivative (float)
    """


    def f(x):
      return x ** 2
    
    def f2(x):
      return (-0.4 * (x** 3)) + (5 * (x ** 2)) + (2 * x) - 5 

    a = 4.0

    fa_da1 = f(a + da)
    fa1 = f(a) 

    fa_da2 = f2(a + da)
    fa2 = f2(a)

    finite_difference1 = (fa_da1 - fa1) / da
    finite_difference2 = (fa_da2 - fa2) / da


    return finite_difference1, finite_difference2

print("Function 1 (finite differences)")
print(finite_difference()[0])

print("Function 2 (finite differences)")
print(finite_difference()[1])
# Out:
# Function 1: (autodif)
# Var(v=4.0000, grad=8.0000)
# Var(v=16.0000, grad=1.0000)
# Function 2 (autodiff):
# Var(v=4.0000, grad=22.8000)
# Var(v=59.4000, grad=1.0000)
# Function 1 (finite differences)
# 8.000000661922968
# Function 2 (finite differences)
# 22.79996635934367

# %% [markdown]
# The finite differences approximation with `da = 1e-10` produces results which are very close to the autodiff numbers for both our functions $f(a)=a^2$ and $f(a)=-0.4a^3 + 5a^2 + 2a - 5$.

# %% [markdown]
# # Create an artificial dataset to play with
#
# We create a non-linear 1d regression task. The generator supports various noise levels and it creates train, validation and test sets. You can modify it yourself if you want more or less challenging tasks.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
def data_generator(noise=0.1, n_samples=300, D1=True):
    # Create covariates and response variable
    if D1:
        X = np.linspace(-3, 3, num=n_samples).reshape(-1,1) # 1-D
        np.random.shuffle(X)
        y = np.random.normal((0.5*np.sin(X[:,0]*3) + X[:,0]), noise) # 1-D with trend
    else:
        X = np.random.multivariate_normal(np.zeros(3), noise*np.eye(3), size = n_samples) # 3-D
        np.random.shuffle(X)
        y = np.sin(X[:,0]) - 5*(X[:,1]**2) + 0.5*X[:,2] # 3-D

    # Stack them together vertically to split data set
    data_set = np.vstack((X.T,y)).T

    train, validation, test = np.split(data_set, [int(0.35*n_samples), int(0.7*n_samples)], axis=0)

    # Standardization of the data, remember we do the standardization with the training set mean and standard deviation
    train_mu = np.mean(train, axis=0)
    train_sigma = np.std(train, axis=0)

    train = (train-train_mu)/train_sigma
    validation = (validation-train_mu)/train_sigma
    test = (test-train_mu)/train_sigma

    x_train, x_validation, x_test = train[:,:-1], validation[:,:-1], test[:,:-1]
    y_train, y_validation, y_test = train[:,-1], validation[:,-1], test[:,-1]

    return x_train, y_train,  x_validation, y_validation, x_test, y_test

# %%
D1 = True
x_train, y_train,  x_validation, y_validation, x_test, y_test = data_generator(noise=0.5, D1=D1)

# %%
if D1:
    plt.scatter(x_train[:,0], y_train);
    plt.scatter(x_validation[:,0], y_validation);
    plt.scatter(x_test[:,0], y_test);
else:
    plt.scatter(x_train[:,1], y_train);
    plt.scatter(x_validation[:,1], y_validation);
    plt.scatter(x_test[:,1], y_test);
plt.show()

# %%
# convert from nparray to Var
def nparray_to_Var(x):
  if x.ndim==1:
    y = [[Var(float(x[i]))] for i in range(x.shape[0])] # always work with list of list
  else:
    y = [[Var(float(x[i,j])) for j in range(x.shape[1])] for i in range(x.shape[0])]
  return y

x_train = nparray_to_Var(x_train)
y_train = nparray_to_Var(y_train)
x_validation = nparray_to_Var(x_validation)
y_validation = nparray_to_Var(y_validation)
x_test = nparray_to_Var(x_test)
y_test = nparray_to_Var(y_test)

# %% [markdown]
# # Defining and initializing the network
#
# The steps to create a feed forward neural network are the following:
#
# 1. **Number of hidden layer and hidden units**. We have to define the number of hidden units in each layer. The number of features in X and the output dimensionality (the size of Y) are given but the numbers in between are set by the researcher. Remember that for each unit in each layer beside in the input has a bias term.
# 2. **Activation functions** for each hidden layer. Each hidden layer in your list must have an activation function (it can also be the linear activation which is equivalent to identity function). The power of neural networks comes from non-linear activation functions that learn representations (features) from the data allowing us to learn from it.
# 3. **Parameter initialization**. We will initialize the weights to have random values. This is done in practice by drawing pseudo random numbers from a Gaussian or uniform distribution. It turns out that for deeper models we have to be careful about how we scale the random numbers. This will be the topic of the exercise below. For now we will just use unit variance Gaussians.
#
# In order to make life easier for ourselves we define a DenseLayer class that takes care of initialization and the forward pass. We can also extend it later with print and advanced initialization capabilities. For the latter we have introduced a Initializer class.
#
# Note that we use Sequence in the code below. A Sequence is an ordered list. This means the order we insert and access items are the same.

# %% [markdown]
# We were unsure if we needed to actually implement an Initializer class or not, so we did.

# %%
import random

class Initializer:

  def init_weights(self, n_in, n_out):
    return [[Var(random.gauss(mu = 0, sigma = 1)) for _ in range(n_in)] for _ in range(n_out)] # use same method as in next section, but leave mean (mu) & std (sigma) as 1

  def init_bias(self, n_out):
    return [Var(0.0) for _ in range(n_out)] # same as before

# %%
import random

class NormalInitializer(Initializer):

  def __init__(self, mean=0, std=0.1):
    self.mean = mean
    self.std = std

  def init_weights(self, n_in, n_out):
    return [[Var(random.gauss(self.mean, self.std)) for _ in range(n_out)] for _ in range(n_in)]

  def init_bias(self, n_out):
    return [Var(0.0) for _ in range(n_out)]

class ConstantInitializer(Initializer):

  def __init__(self, weight=1.0, bias=0.0):
    self.weight = weight
    self.bias = bias

  def init_weights(self, n_in, n_out):
    return [[Var(self.weight) for _ in range(n_out)] for _ in range(n_in)]

  def init_bias(self, n_out):
    return [Var(self.bias) for _ in range(n_out)]

# %%
from typing import Sequence

class DenseLayer:
    def __init__(self, n_in: int, n_out: int, act_fn, initializer = NormalInitializer()):
        self.weights = initializer.init_weights(n_in, n_out)
        self.bias = initializer.init_bias(n_out)
        self.act_fn = act_fn

    def __repr__(self):
        return 'Weights: ' + repr(self.weights) + ' Biases: ' + repr(self.bias)

    def parameters(self) -> Sequence[Var]:
      params = []
      for r in self.weights:
        params += r

      return params + self.bias

    def forward(self, single_input: Sequence[Var]) -> Sequence[Var]:
        # self.weights is a matrix with dimension n_in x n_out. We check that the dimensionality of the input
        # to the current layer matches the number of nodes in the current layer
        assert len(self.weights) == len(single_input), "weights and single_input must match in first dimension"
        weights = self.weights
        out = []
        # For some given data point single_input, we now want to calculate the resulting value in each node in the current layer
        # We therefore loop over the (number of) nodes in the current layer:
        for j in range(len(weights[0])):
            # Initialize the node value depending on its corresponding parameters.
            node = self.bias[j] # We set the bias for each neuron, but since self.bias is a list of Var's, we need to index to the j'th bias # <- Insert code
            # We now finish the linear transformation corresponding to the parameters of the currently considered node.
            for i in range(len(single_input)):
                node += self.weights[i][j] * single_input[i] # We then add the \sum of the weight multiplied with the input, from neuron 1 .. i to neuron j (indexed [i][j])   # <- Insert code
            node = self.act_fn(node)
            out.append(node)

        return out

# %% [markdown]
# ## Exercise f) Add more activation functions
#
# To have a full definition of the neural network, we must define an activation function for every layer. Several activation functions have been proposed and have different characteristics. In the Var class we have already defined the rectified linear init (relu).
#
# Implement the following activation functions in the Var class:
#
# * Identity: $$\mathrm{identity}(x) = x$$
# * Hyperbolic tangent: $$\tanh(x)$$
# * Sigmoid (or logistic function): $$\mathrm{sigmoid}(x) = \frac{1}{1.0 + \exp(-x ) }$$  Hint: $\mathrm{sigmoid}'(x)= \mathrm{sigmoid}(x)(1-\mathrm{sigmoid}(x))$.
#
# Hint: You can seek inspiration in the relu method in the Var class.

# %% [markdown]
# The actual changes have been implemented in the `Var` class.
# ```py
#     def identity(self):
#         return Var(self.v, lambda: [(self, 1)])
#
#     def tanh(self):
#         return Var((exp(self.v)-exp(-self.v))/(exp(self.v)+exp(-self.v)), lambda: [(self, 1-((exp(self.v)-exp(-self.v))/(exp(self.v)+exp(-self.v)))**2)])
#
#     def sigmoid(self):
#         return Var(1/(1+exp(-self.v)), lambda: [(self, (1/(1+exp(-self.v)))*(1-(1/(1+exp(-self.v)))))])
# ```

# %% [markdown]
# ## Exercise g) Complete the forward pass
#
# In the code below we initialize a 1-5-1 network and pass the training set through it. *The forward method in DenseLayer is **not** complete*. It just outputs zeros right now. The method forward should perform an [affine transformation](https://en.wikipedia.org/wiki/Affine_transformation) on the input followed by an application of the activation function.

# %% [markdown]
# **Answer**
#
# We need to do the forward pass, which is described (as in the previous notebook) as:
# $$
# \text{node}_j = b_j + \sum_{i} w_{ij} * x_i
# $$
# We first compute the bias for the single neuron, j:
# ```py
#     node = self.bias[j] # We set the bias for each neuron, but since self.bias is a list of Var's, we need to index to the j'th bias # <- Insert code
# ```
#
# After computing the bias term, we need to index once more, to access the weights and the corresponding inputs, and so we use the next for loop:
# ```py
#     node += self.weights[i][j] * single_input[i] # We then add the \sum of the weight multiplied with the input, from neuron 1 .. i to neuron j (indexed [i][j])   # <- Insert code
# ````

# %%
NN = [
    DenseLayer(1, 5, lambda x: x.relu()),
    DenseLayer(5, 1, lambda x: x.identity())
]

def forward(input, network):

  def forward_single(x, network):
    for layer in network:
        x = layer.forward(x)
    return x

  output = [ forward_single(input[n], network) for n in range(len(input))]
  return output

print(forward(x_train, NN))
# Out:
# [[Var(v=0.0032, grad=0.0000)], [Var(v=0.0063, grad=0.0000)], [Var(v=0.0006, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0047, grad=0.0000)], [Var(v=0.0043, grad=0.0000)], [Var(v=0.0028, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0017, grad=0.0000)], [Var(v=0.0049, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0039, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0021, grad=0.0000)], [Var(v=0.0041, grad=0.0000)], [Var(v=0.0075, grad=0.0000)], [Var(v=0.0036, grad=0.0000)], [Var(v=0.0004, grad=0.0000)], [Var(v=0.0012, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0055, grad=0.0000)], [Var(v=0.0055, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0071, grad=0.0000)], [Var(v=0.0078, grad=0.0000)], [Var(v=0.0008, grad=0.0000)], [Var(v=0.0049, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0012, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0038, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0073, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0047, grad=0.0000)], [Var(v=0.0045, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0046, grad=0.0000)], [Var(v=0.0020, grad=0.0000)], [Var(v=0.0002, grad=0.0000)], [Var(v=0.0050, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0079, grad=0.0000)], [Var(v=0.0069, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0026, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0046, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0022, grad=0.0000)], [Var(v=0.0016, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0058, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0023, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0045, grad=0.0000)], [Var(v=0.0026, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0071, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0074, grad=0.0000)], [Var(v=0.0011, grad=0.0000)], [Var(v=0.0007, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0027, grad=0.0000)], [Var(v=0.0000, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0042, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0019, grad=0.0000)], [Var(v=0.0003, grad=0.0000)], [Var(v=0.0067, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0044, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=0.0021, grad=0.0000)], [Var(v=0.0063, grad=0.0000)]]

# %% [markdown]
# ## Exercise h) Print all network parameters
#
# Make a function that prints all the parameters of the network (weights and biases) with information about in which layer the appear. In the object oriented spirit you should introduce a method in the DenseLayer class to print the parameters of a layer. Hint: You can take inspiration from the corresponding method in Var.

# %% [markdown]
# **Answer**
# In the `Var` class, we were given a pre-defined method to view the parameters:
# ```py
#     def __repr__(self):
#         return "Var(v=%.4f, grad=%.4f)" % (self.v, self.grad)
# ```
# Which we now have to implement (or in our case improve) in the `DenseLayer` class.
# We notice the same method already has been implemented, but is lacking the part about which layer the parameters lie in.
# When we print out the biases, we would just need to print out all biases for the given layer we find ourselves in, but when printing the weights, we would need to print the `out` weights, e.g. those coming from layer $j-1$:
# We re-used the code from earlier to showcase it visually.

# %%
# Create a directed graph
G = nx.DiGraph()

# Add edges with labels
G.add_edge('L1_a', 'L2_c', label='weight L1->L2')
G.add_edge('L1_b', 'L2_c', label='weight L1->L2')

# Manually define positions for a tree layout
pos = {
    'L1_a': (0, 2),
    'L1_b': (0, 0),
    'L2_c': (1, 1),
}

# Draw the graph nodes and edges
nx.draw(G, pos, with_labels=True, node_shape='o', node_size=3000, node_color='lightblue', arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'label')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Show the plot
plt.title("Graph of example two")
plt.show()

# %% [markdown]
# And so we take the already existing `__repr__` method in `DenseLayer` and use it in a function that iteratively loops through each layer to print out the parameters.
# We look at the `__repr__` method:
# ```py
#     def __repr__(self):
#         return 'Weights: ' + repr(self.weights) + ' Biases: ' + repr(self.bias)
# ```

# %%
# Insert code here and in the DenseLayer class
def parameter_lookup(nn): # nn input would have the DenseLayer class
    for layer, neuron in enumerate(nn): # we run the class with nn[1], nn[2], ..., nn[layer], which returns a single layer's parameters, so we "just" run `.__repr__()` on it
        print(f"Layer {layer}: \n{neuron}") # neuron is automatically neuron.__repr__()

# %% [markdown]
# ## Visualization
#
# Now that we have defined our activation functions we can visualize them to see what they look like:

# %%
x = np.linspace(-6, 6, 100)

# convert from Var to ndarray
def Var_to_nparray(x):
  y = np.zeros((len(x),len(x[0])))
  for i in range(len(x)):
    for j in range(len(x[0])):
      y[i,j] = x[i][j].v
  return y

# define 1-1 network with weight = 1 and relu activation
NN = [ DenseLayer(1, 1, lambda x: x.relu(), initializer = ConstantInitializer(1.0)) ]
y = Var_to_nparray(forward(nparray_to_Var(x), NN))

#y = Var_to_nparray(relu(nparray_to_Var(x)))
plt.plot(x,y)
plt.show()

# %%
# Testing all activation layers

x = np.linspace(-6, 6, 100)
units = {
    "identity": lambda x: x.identity(),
    "sigmoid": lambda x: x.sigmoid(),
    "relu": lambda x: x.relu(),
    "tanh": lambda x: x.tanh()
}

plt.figure(figsize=(5, 5))
[plt.plot(x, Var_to_nparray(forward(nparray_to_Var(x), [DenseLayer(1, 1, unit, initializer = ConstantInitializer(1.0))]) ), label=unit_name, lw=2) for unit_name, unit in units.items()] # unit(nparray_to_Var(x))), label=unit_name, lw=2) for unit_name, unit in units.items()]
plt.legend(loc=2, fontsize=16)
plt.title('Our activation functions', fontsize=20)
plt.ylim([-2, 5])
plt.xlim([-6, 6])
plt.show()

# %% [markdown]
# # Advanced initialization schemes
#
# If we are not careful with initialization, the signals we propagate forward ($a^{(l)}$, $l=1,\ldots,L$) and backward ($\delta^l$, $l=L,L-1,\ldots,1$) can blow up or shrink to zero. A statistical analysis of the variance of the signals for different activation functions can be found in these two papers: [Glorot initialization](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf) and [He initialization](https://arxiv.org/pdf/1502.01852v1.pdf).
#
# The result of the analyses are proposals for how to make the initialization such that the variance of the signals (forward and backward) are kept approxmimatly constant when propagating from layer to layer. The exact expressions depend upon the non-linear activation function used. In Glorot initialization, the aim is to keep both the forward and backward variances constant whereas He only aims at keeping the variance in the forward pass constant.
#
# We define $n_{in}$ and $n_{out}$ as the number of input units and output units of a particular layer.
#
# The Glorot initialization has the form:
#
# $$w_{ij} \sim N \bigg( 0, \, \frac{2 \alpha }{n_{in} + n_{out}} \bigg) \ . $$
#
# where $N(\mu,\sigma^2)$ is a Gaussian distribution with mean $\mu$ and variance $\sigma^2$ and $\alpha$ is a parameter that depends upon the activation function used. For $\tanh$, $\alpha=1$ and for Rectified Linear Unit (ReLU) activations, $\alpha=2$. (It is also possible to use a uniform distribution for initialization, see [this blog post](https://mmuratarat.github.io/2019-02-25/xavier-glorot-he-weight-init).)
#
# The He initialization is very similar
#
# $$w_{ij} \sim N \bigg( 0, \, \frac{\alpha}{n_{in}} \bigg) \ . $$

# %% [markdown]
# ## Exercise i) Glorot and He initialization
#
# Using the Initializer class, implement functions that implement Glorot and He
#
# Explain briefly how you would test numerically that these initializations have the sought after property. Hint: See plots in Glorot paper.
#
# Comment: If you want to be more advanced then try to make a universal initializer taking both the activation function and type (Glorot or He) as argument.

# %% [markdown]
# **Answer**
#
# We use the equations to calculate the `std`:

# %%
import math # std is sqrt(sigma^2) and since He and Glorot are gaussian distributed, we use sigma^2
## Glorot
def DenseLayer_Glorot_tanh(n_in: int, n_out: int):
  alpha = 1
  std = math.sqrt((2 * alpha) / (n_in + n_out)) # <- replace with proper initialization
  return DenseLayer(n_in, n_out, lambda x: x.tanh(), initializer = NormalInitializer(std))

## He
def DenseLayer_He_relu(n_in: int, n_out: int):
  alpha = 2
  std = math.sqrt((alpha / n_in)) # <- replace with proper initialization
  return DenseLayer(n_in, n_out, lambda x: x.relu(), initializer = NormalInitializer(std))

# %% [markdown]
# We also try to make it using a universal initializer, using the same method for weights and biases as used in the class provided (unlike the one we made ourselves we don't force mu and sigma, but instead use the given input provided from the `act_func` and `type`).
#
# The class uses a dict to define the values for alpha. Since we ourselves sometimes write e.g. `reLU` we also added a bit of catch statements to ensure no hassle.
#
# The `std` is then computed as before, and mean is set to $0$ (gaussian).

# %%
import math

class Universal_Initializer(Initializer):
    def __init__(self, n_in: int, n_out: int, act_func: str, type: str = "glorot"):
        alphas = {"reLU": 2, "relu": 2, "tanh": 1}
        alpha = alphas.get(act_func, 1) # to access dict, if nothing is found returns 1 instead of KeyError
        
        if type == ("glorot" or "Glorot"):
            var = (2 * alpha) / (n_in + n_out)
            
        elif type == ("he" or "He"):
            var = (alpha / n_in)
            
        else:
            raise ValueError("Unknown activation function given. Only Glorot or He accepted.")
            
        self.mean = 0
        self.std = math.sqrt(var)
        
    def init_weights(self, n_in, n_out):
        return [[Var(random.gauss(self.mean, self.std)) for _ in range(n_in)] for _ in range(n_out)]
    
    def init_bias(self, n_out):
        return [Var(self.bias) for _ in range(n_out)]

# %% [markdown]
# ## Exercise j) Forward pass unit test
#
# Write a bit of code to make a unit test that the forward pass works. This can be done by defining a simple network with for example all weights equal to one (using the ConstantInitializer method) and identity activation functions.
#
# Hints: Use the [assert](https://www.w3schools.com/python/ref_keyword_assert.asp), the nparray_to_Var and the Var_to_nparray commands.

# %% [markdown]
# **Answer**
# We set up a test array to run use the `forward()` on, and use the `DenseLayer` class initialized with `ConstantInitializer`, activation function `identity()` we defined in the `Var` class earlier.
# To easily check if we've done it correctly, we set bias 0 and weights 1 (agian, constant), and then use the `assert()` on a converted `np.array()` to easily check the list format.

# %%
# Insert code here
import numpy as np
test_input = np.array([[2.0], [5.0]])

# Bias = 0, weights all = 1 (since initializer is Constant...)
# test[0] -> 0 + 2.0 * 1 = 2.0
# test[1] -> 0 + 5.0 * 1 = 5.0

test_nn = Var_to_nparray(forward(nparray_to_Var(test_input), [DenseLayer(1, 1, act_fn=lambda x: x.identity(), initializer = ConstantInitializer(weight=1.0, bias=0.0))]) )

print(f"Test input: {test_input.tolist()}\nTest NN:    {test_nn.tolist()}\n")

assert(test_nn.tolist() == test_input.tolist())
print("Test succeeded")
# Out:
# Test input: [[2.0], [5.0]]
# Test NN:    [[2.0], [5.0]]
#
# Test succeeded

# %% [markdown]
# # Loss functions
#
# We are only missing a loss function to we need to define a loss function and its derivative with respect to the output of the neural network $y$

# %%
def squared_loss(t, y):

  # add check that sizes agree

  def squared_loss_single(t, y):
    Loss = Var(0.0)
    for i in range(len(t)): # sum over outputs
      Loss += (t[i]-y[i]) ** 2
    return Loss

  Loss = Var(0.0)
  for n in range(len(t)): # sum over training data
    Loss += squared_loss_single(t[n],y[n])
  return Loss

# %% [markdown]
# ## Exercise k) Implement cross entropy loss
#
# Insert code below to implement cross-entropy loss for general dimensionality of $t$. Use a logits formulation:
# $$
# \rm{Loss} = - \sum_i t_i \, log \, p_i
# $$
# with $p$ given by the the softmax function in terms of the logits $h$:
# $$
# p_i = \frac{\exp(h_i)}{\sum_{i'} \exp(h_{i'})} .
# $$
# Inserting $p$ in the expression for the loss gives
# $$
# \rm{Loss} = - \sum_i t_i h_i + \rm{LogSumExp}(h) \ ,
# $$
# where
# $$
# \rm{LogSumExp}(h) = \log \sum_i \exp h_i \ .
# $$
# This is true for $t$ being a one-hot vector.
#
# Call the function to convince yourself it works.
#
# In practice you want to implement a [numerically stable](https://leimao.github.io/blog/LogSumExp/) version of LogSumExp. But we will not bother about that here.
#
# Help: You can add these methods in the Var class:
# ```py
#     def exp(self):
#         return Var(exp(self.v), lambda: [(self, exp(self.v))])
#
#     def log(self):
#         return Var(log(self.v), lambda: [(self, self.v ** -1)])
# ```

# %% [markdown]
# Normally we would just iterate in a normal way using `+=`, but since we use the `Var` class' `__add__` we can't use in-place addition (regular python class method `__iadd__`). We do the same for the negative sum.
#
# Generally, we initialize our two terms with initialized `Var` value as `0.0` so we have `Var` objects we can work with.
#
# And so we define:
# $$
# \text{first\_term} = - \sum_{i} t_i * h_i
# $$
# And
# $$
# \text{log\_sum\_exp} = \log \left(\sum_i \exp\left(h_i\right)\right)
# $$
#
# Since we go up to two different sums (like in the previous squared loss), we need two different loops.
# As explained before, we use the (re)defined `__add__` and compute both terms, which we then lastly add together and return the computed loss.

# %%
def cross_entropy_loss(t, h):
    # Insert code here
    first_term = Var(0.0) #initialize with Var(0.0)
    for i in range(len(t)):
        first_term = first_term - Var(t[i]) * h[i] # Loss = - \sum_i t_i h_i + LogSumExp which we do in just a second

    sum_exp = Var(0.0)
    for i in range(len(h)):
        sum_exp = sum_exp + h[i].exp() # \sum_i exp(h_i)
    
    log_sum_exp = sum_exp.log() #takes the log of previois
    
    Loss = first_term + log_sum_exp
    
    return Loss

# %% [markdown]
# # Backward pass
#
# Now the magic happens! We get the calculation of the gradients for free. Just do:

# %%
NN = [
    DenseLayer(1, 5, lambda x: x.relu()),
    DenseLayer(5, 1, lambda x: x.identity())
]

output = forward(x_train, NN)

Loss = squared_loss(y_train,output)
Loss.backward()

# %% [markdown]
# and the gradients will be calculated:

# %%
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]
# Out:
# Layer 0
#  Weights: [[Var(v=-0.0805, grad=1.5631), Var(v=-0.0449, grad=1.2905), Var(v=-0.0607, grad=-0.6080), Var(v=0.0414, grad=9.5334), Var(v=0.1532, grad=0.7280)]] Biases: [Var(v=0.0000, grad=-1.4207), Var(v=0.0000, grad=-1.1730), Var(v=0.0000, grad=0.5527), Var(v=0.0000, grad=8.1884), Var(v=0.0000, grad=0.6253)]
# Layer 1
#  Weights: [[Var(v=-0.0163, grad=7.7153)], [Var(v=-0.0135, grad=4.3000)], [Var(v=0.0063, grad=5.8191)], [Var(v=-0.0933, grad=-4.2276)], [Var(v=-0.0071, grad=-15.6470)]] Biases: [Var(v=0.0000, grad=-0.6007)]
# [None, None]

# %% [markdown]
# # Backward pass unit test
#
# Above we used finite differences to test that Nanograd is actually doing what it is supposed to do. We can in principle try the same for the neural network. But we will trust that the test above is enough.

# %% [markdown]
# # Training and validation
#
# We are ready to train some neural networks!
#
# We initialize again:

# %%
NN = [
    DenseLayer(1, 15, lambda x: x.relu()),
    DenseLayer(15, 50, lambda x: x.relu()),
    DenseLayer(50, 1, lambda x: x.identity())
]

output = forward(x_train, NN)

Loss = squared_loss(y_train,output)
Loss.backward()

# %% [markdown]
# and make an update:
#
# We introduce a help function parameters to have a handle in all parameters in the network.

# %%
print('Network before update:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]

def parameters(network):
  params = []
  for layer in range(len(network)):
    params += network[layer].parameters()
  return params

def update_parameters(params, learning_rate=0.01):
  for p in params:
    p.v -= learning_rate*p.grad

def zero_gradients(params):
  for p in params:
    p.grad = 0.0

update_parameters(parameters(NN))

print('\nNetwork after update:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]

zero_gradients(parameters(NN))

print('\nNetwork after zeroing gradients:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]
# Out:
# Network before update:
# Layer 0
#  Weights: [[Var(v=-0.0716, grad=11.2093), Var(v=0.1677, grad=12.8968), Var(v=0.2266, grad=1.3177), Var(v=0.0048, grad=-1.9273), Var(v=-0.1110, grad=-4.2384), Var(v=-0.0980, grad=4.3192), Var(v=0.0268, grad=-0.6467), Var(v=-0.1458, grad=11.3324), Var(v=-0.0072, grad=3.3698), Var(v=-0.0504, grad=7.4980), Var(v=0.0105, grad=-5.2284), Var(v=0.0261, grad=2.9978), Var(v=-0.0671, grad=2.0178), Var(v=0.0427, grad=-0.7127), Var(v=-0.1269, grad=0.3650)]] Biases: [Var(v=0.0000, grad=-10.1825), Var(v=0.0000, grad=11.0733), Var(v=0.0000, grad=1.1314), Var(v=0.0000, grad=-1.6548), Var(v=0.0000, grad=3.8502), Var(v=0.0000, grad=-3.9236), Var(v=0.0000, grad=-0.5552), Var(v=0.0000, grad=-10.2943), Var(v=0.0000, grad=-3.0611), Var(v=0.0000, grad=-6.8111), Var(v=0.0000, grad=-4.4892), Var(v=0.0000, grad=2.5739), Var(v=0.0000, grad=-1.8330), Var(v=0.0000, grad=-0.6119), Var(v=0.0000, grad=-0.3316)]
# Layer 1
#  Weights: [[Var(v=0.0449, grad=0.4545), Var(v=0.0000, grad=-0.0620), Var(v=-0.0290, grad=0.0000), Var(v=-0.0782, grad=-0.0378), Var(v=-0.0660, grad=-1.0980), Var(v=0.2835, grad=-1.0959), Var(v=0.0593, grad=-1.0771), Var(v=-0.0527, grad=-0.6529), Var(v=0.0775, grad=0.0000), Var(v=0.1138, grad=0.0000), Var(v=0.1194, grad=0.0132), Var(v=0.1120, grad=0.0000), Var(v=0.2310, grad=-0.0732), Var(v=-0.0963, grad=0.0000), Var(v=0.0116, grad=-0.4796), Var(v=0.0084, grad=0.0000), Var(v=0.1283, grad=-0.7654), Var(v=0.1443, grad=-0.1754), Var(v=0.0097, grad=0.0000), Var(v=0.1381, grad=0.0000), Var(v=0.1366, grad=0.0000), Var(v=0.0683, grad=0.0000), Var(v=0.0053, grad=0.0000), Var(v=0.0011, grad=0.0000), Var(v=-0.1348, grad=0.0000), Var(v=0.0049, grad=0.0000), Var(v=-0.1057, grad=0.0000), Var(v=0.0879, grad=0.0518), Var(v=0.0990, grad=0.0000), Var(v=0.0287, grad=-0.8515), Var(v=0.0599, grad=0.0000), Var(v=-0.1015, grad=0.0000), Var(v=-0.0901, grad=0.3017), Var(v=0.1466, grad=0.0000), Var(v=-0.0868, grad=1.3179), Var(v=0.0023, grad=0.0000), Var(v=0.1211, grad=-0.5637), Var(v=-0.0606, grad=0.0000), Var(v=0.0746, grad=0.0000), Var(v=-0.1521, grad=0.0000), Var(v=0.0713, grad=-0.7974), Var(v=-0.2873, grad=0.0000), Var(v=0.0637, grad=-1.9610), Var(v=-0.1991, grad=0.0000), Var(v=0.1371, grad=0.0000), Var(v=0.0093, grad=0.0000), Var(v=-0.0264, grad=0.0947), Var(v=-0.0185, grad=0.0000), Var(v=0.0028, grad=0.0000), Var(v=-0.1214, grad=0.0000)], [Var(v=-0.0316, grad=0.0000), Var(v=-0.0118, grad=0.0000), Var(v=-0.0614, grad=0.0000), Var(v=0.0640, grad=0.0995), Var(v=-0.1303, grad=0.0000), Var(v=-0.0497, grad=0.0000), Var(v=-0.1128, grad=0.0000), Var(v=-0.1752, grad=1.7162), Var(v=-0.0338, grad=-2.2518), Var(v=0.1688, grad=0.0000), Var(v=0.0305, grad=0.0000), Var(v=0.0278, grad=0.0000), Var(v=-0.1246, grad=0.0000), Var(v=-0.1673, grad=0.0000), Var(v=0.0518, grad=0.0000), Var(v=-0.1362, grad=0.0000), Var(v=0.1417, grad=2.0121), Var(v=0.0618, grad=0.0000), Var(v=-0.1187, grad=0.7153), Var(v=-0.0979, grad=0.0000), Var(v=0.0290, grad=0.0000), Var(v=-0.0563, grad=0.0000), Var(v=0.0167, grad=0.0000), Var(v=-0.0369, grad=0.0000), Var(v=-0.1444, grad=0.0000), Var(v=0.2770, grad=0.7849), Var(v=-0.0455, grad=0.0000), Var(v=-0.0573, grad=0.0000), Var(v=0.1389, grad=0.9491), Var(v=0.2407, grad=2.2382), Var(v=-0.2125, grad=-1.6741), Var(v=-0.0054, grad=0.0000), Var(v=0.1007, grad=-0.7932), Var(v=-0.0480, grad=0.0000), Var(v=-0.0101, grad=0.0000), Var(v=-0.1503, grad=0.0000), Var(v=0.1712, grad=1.4818), Var(v=0.0350, grad=-0.0460), Var(v=0.0413, grad=0.0000), Var(v=0.0129, grad=1.2843), Var(v=-0.1131, grad=0.0000), Var(v=0.0210, grad=0.0000), Var(v=-0.0889, grad=0.0000), Var(v=-0.0575, grad=0.0000), Var(v=0.2706, grad=-0.8753), Var(v=0.1723, grad=4.2430), Var(v=-0.1406, grad=0.0000), Var(v=-0.0524, grad=0.0000), Var(v=0.0441, grad=1.6586), Var(v=0.2102, grad=0.8634)], [Var(v=-0.1372, grad=0.0000), Var(v=-0.0028, grad=0.0000), Var(v=-0.1067, grad=0.0000), Var(v=0.1207, grad=0.1344), Var(v=0.0340, grad=0.0000), Var(v=-0.0978, grad=0.0000), Var(v=-0.0324, grad=0.0000), Var(v=0.1231, grad=2.3191), Var(v=0.0145, grad=-3.0427), Var(v=-0.1700, grad=0.0000), Var(v=-0.1129, grad=0.0000), Var(v=-0.1751, grad=0.0000), Var(v=0.0455, grad=0.0000), Var(v=-0.1246, grad=0.0000), Var(v=-0.0579, grad=0.0000), Var(v=0.0394, grad=0.0000), Var(v=0.1407, grad=2.7189), Var(v=-0.1362, grad=0.0000), Var(v=0.2321, grad=0.9666), Var(v=-0.2772, grad=0.0000), Var(v=-0.0459, grad=0.0000), Var(v=0.0120, grad=0.0000), Var(v=-0.1057, grad=0.0000), Var(v=-0.0758, grad=0.0000), Var(v=-0.1430, grad=0.0000), Var(v=-0.0014, grad=1.0606), Var(v=-0.2068, grad=0.0000), Var(v=-0.0848, grad=0.0000), Var(v=0.0639, grad=1.2825), Var(v=-0.1065, grad=3.0245), Var(v=0.1373, grad=-2.2621), Var(v=-0.0875, grad=0.0000), Var(v=0.0055, grad=-1.0718), Var(v=-0.0550, grad=0.0000), Var(v=-0.0118, grad=0.0000), Var(v=0.1290, grad=0.0000), Var(v=0.1242, grad=2.0023), Var(v=0.0699, grad=-0.0622), Var(v=-0.0795, grad=0.0000),  ...
# Layer 2
#  Weights: [[Var(v=0.0684, grad=2.4953)], [Var(v=-0.0093, grad=4.7438)], [Var(v=-0.0136, grad=0.0000)], [Var(v=-0.0057, grad=-3.9851)], [Var(v=-0.1652, grad=1.4264)], [Var(v=-0.1649, grad=4.5493)], [Var(v=-0.1621, grad=3.1350)], [Var(v=-0.0982, grad=3.6800)], [Var(v=0.1289, grad=-0.0728)], [Var(v=0.0151, grad=0.0000)], [Var(v=0.0020, grad=0.9071)], [Var(v=0.0772, grad=0.0000)], [Var(v=-0.0110, grad=3.3460)], [Var(v=0.0053, grad=0.0000)], [Var(v=-0.0722, grad=2.4152)], [Var(v=-0.0371, grad=0.0000)], [Var(v=-0.1152, grad=-3.6301)], [Var(v=-0.0264, grad=2.4817)], [Var(v=-0.0409, grad=-3.8503)], [Var(v=0.0771, grad=0.0000)], [Var(v=0.0954, grad=0.0000)], [Var(v=0.1012, grad=0.0000)], [Var(v=0.0400, grad=0.0000)], [Var(v=0.1035, grad=0.0000)], [Var(v=0.0300, grad=0.0000)], [Var(v=-0.0449, grad=-5.5099)], [Var(v=-0.3409, grad=0.0000)], [Var(v=0.0078, grad=2.7339)], [Var(v=-0.0543, grad=-4.4057)], [Var(v=-0.1281, grad=1.6040)], [Var(v=0.0958, grad=-0.1345)], [Var(v=-0.0740, grad=0.0000)], [Var(v=0.0454, grad=-0.5687)], [Var(v=-0.0158, grad=0.0000)], [Var(v=0.1983, grad=0.0673)], [Var(v=-0.1300, grad=0.0000)], [Var(v=-0.0848, grad=-5.6240)], [Var(v=0.0026, grad=-1.7729)], [Var(v=0.0292, grad=0.0000)], [Var(v=-0.0735, grad=-2.0133)], [Var(v=-0.1200, grad=1.0865)], [Var(v=0.1766, grad=0.0000)], [Var(v=-0.2951, grad=0.6918)], [Var(v=-0.2609, grad=0.0000)], [Var(v=0.0501, grad=-6.6861)], [Var(v=-0.2429, grad=-2.0761)], [Var(v=0.0143, grad=1.4183)], [Var(v=-0.1618, grad=0.0000)], [Var(v=-0.0949, grad=-0.8779)], [Var(v=-0.0494, grad=-0.3124)]] Biases: [Var(v=0.0000, grad=-5.1449)]
#
# Network after update:
# Layer 0
#  Weights: [[Var(v=-0.1837, grad=11.2093), Var(v=0.0388, grad=12.8968), Var(v=0.2135, grad=1.3177), Var(v=0.0240, grad=-1.9273), Var(v=-0.0687, grad=-4.2384), Var(v=-0.1412, grad=4.3192), Var(v=0.0333, grad=-0.6467), Var(v=-0.2591, grad=11.3324), Var(v=-0.0409, grad=3.3698), Var(v=-0.1254, grad=7.4980), Var(v=0.0628, grad=-5.2284), Var(v=-0.0039, grad=2.9978), Var(v=-0.0872, grad=2.0178), Var(v=0.0498, grad=-0.7127), Var(v=-0.1306, grad=0.3650)]] Biases: [Var(v=0.1018, grad=-10.1825), Var(v=-0.1107, grad=11.0733), Var(v=-0.0113, grad=1.1314), Var(v=0.0165, grad=-1.6548), Var(v=-0.0385, grad=3.8502), Var(v=0.0392, grad=-3.9236), Var(v=0.0056, grad=-0.5552), Var(v=0.1029, grad=-10.2943), Var(v=0.0306, grad=-3.0611), Var(v=0.0681, grad=-6.8111), Var(v=0.0449, grad=-4.4892), Var(v=-0.0257, grad=2.5739), Var(v=0.0183, grad=-1.8330), Var(v=0.0061, grad=-0.6119), Var(v=0.0033, grad=-0.3316)]
# Layer 1
#  Weights: [[Var(v=0.0404, grad=0.4545), Var(v=0.0007, grad=-0.0620), Var(v=-0.0290, grad=0.0000), Var(v=-0.0778, grad=-0.0378), Var(v=-0.0550, grad=-1.0980), Var(v=0.2945, grad=-1.0959), Var(v=0.0701, grad=-1.0771), Var(v=-0.0462, grad=-0.6529), Var(v=0.0775, grad=0.0000), Var(v=0.1138, grad=0.0000), Var(v=0.1192, grad=0.0132), Var(v=0.1120, grad=0.0000), Var(v=0.2317, grad=-0.0732), Var(v=-0.0963, grad=0.0000), Var(v=0.0164, grad=-0.4796), Var(v=0.0084, grad=0.0000), Var(v=0.1359, grad=-0.7654), Var(v=0.1460, grad=-0.1754), Var(v=0.0097, grad=0.0000), Var(v=0.1381, grad=0.0000), Var(v=0.1366, grad=0.0000), Var(v=0.0683, grad=0.0000), Var(v=0.0053, grad=0.0000), Var(v=0.0011, grad=0.0000), Var(v=-0.1348, grad=0.0000), Var(v=0.0049, grad=0.0000), Var(v=-0.1057, grad=0.0000), Var(v=0.0874, grad=0.0518), Var(v=0.0990, grad=0.0000), Var(v=0.0373, grad=-0.8515), Var(v=0.0599, grad=0.0000), Var(v=-0.1015, grad=0.0000), Var(v=-0.0931, grad=0.3017), Var(v=0.1466, grad=0.0000), Var(v=-0.1000, grad=1.3179), Var(v=0.0023, grad=0.0000), Var(v=0.1267, grad=-0.5637), Var(v=-0.0606, grad=0.0000), Var(v=0.0746, grad=0.0000), Var(v=-0.1521, grad=0.0000), Var(v=0.0793, grad=-0.7974), Var(v=-0.2873, grad=0.0000), Var(v=0.0833, grad=-1.9610), Var(v=-0.1991, grad=0.0000), Var(v=0.1371, grad=0.0000), Var(v=0.0093, grad=0.0000), Var(v=-0.0273, grad=0.0947), Var(v=-0.0185, grad=0.0000), Var(v=0.0028, grad=0.0000), Var(v=-0.1214, grad=0.0000)], [Var(v=-0.0316, grad=0.0000), Var(v=-0.0118, grad=0.0000), Var(v=-0.0614, grad=0.0000), Var(v=0.0630, grad=0.0995), Var(v=-0.1303, grad=0.0000), Var(v=-0.0497, grad=0.0000), Var(v=-0.1128, grad=0.0000), Var(v=-0.1923, grad=1.7162), Var(v=-0.0113, grad=-2.2518), Var(v=0.1688, grad=0.0000), Var(v=0.0305, grad=0.0000), Var(v=0.0278, grad=0.0000), Var(v=-0.1246, grad=0.0000), Var(v=-0.1673, grad=0.0000), Var(v=0.0518, grad=0.0000), Var(v=-0.1362, grad=0.0000), Var(v=0.1215, grad=2.0121), Var(v=0.0618, grad=0.0000), Var(v=-0.1259, grad=0.7153), Var(v=-0.0979, grad=0.0000), Var(v=0.0290, grad=0.0000), Var(v=-0.0563, grad=0.0000), Var(v=0.0167, grad=0.0000), Var(v=-0.0369, grad=0.0000), Var(v=-0.1444, grad=0.0000), Var(v=0.2692, grad=0.7849), Var(v=-0.0455, grad=0.0000), Var(v=-0.0573, grad=0.0000), Var(v=0.1294, grad=0.9491), Var(v=0.2183, grad=2.2382), Var(v=-0.1957, grad=-1.6741), Var(v=-0.0054, grad=0.0000), Var(v=0.1087, grad=-0.7932), Var(v=-0.0480, grad=0.0000), Var(v=-0.0101, grad=0.0000), Var(v=-0.1503, grad=0.0000), Var(v=0.1564, grad=1.4818), Var(v=0.0354, grad=-0.0460), Var(v=0.0413, grad=0.0000), Var(v=0.0000, grad=1.2843), Var(v=-0.1131, grad=0.0000), Var(v=0.0210, grad=0.0000), Var(v=-0.0889, grad=0.0000), Var(v=-0.0575, grad=0.0000), Var(v=0.2793, grad=-0.8753), Var(v=0.1298, grad=4.2430), Var(v=-0.1406, grad=0.0000), Var(v=-0.0524, grad=0.0000), Var(v=0.0276, grad=1.6586), Var(v=0.2016, grad=0.8634)], [Var(v=-0.1372, grad=0.0000), Var(v=-0.0028, grad=0.0000), Var(v=-0.1067, grad=0.0000), Var(v=0.1193, grad=0.1344), Var(v=0.0340, grad=0.0000), Var(v=-0.0978, grad=0.0000), Var(v=-0.0324, grad=0.0000), Var(v=0.0999, grad=2.3191), Var(v=0.0449, grad=-3.0427), Var(v=-0.1700, grad=0.0000), Var(v=-0.1129, grad=0.0000), Var(v=-0.1751, grad=0.0000), Var(v=0.0455, grad=0.0000), Var(v=-0.1246, grad=0.0000), Var(v=-0.0579, grad=0.0000), Var(v=0.0394, grad=0.0000), Var(v=0.1135, grad=2.7189), Var(v=-0.1362, grad=0.0000), Var(v=0.2224, grad=0.9666), Var(v=-0.2772, grad=0.0000), Var(v=-0.0459, grad=0.0000), Var(v=0.0120, grad=0.0000), Var(v=-0.1057, grad=0.0000), Var(v=-0.0758, grad=0.0000), Var(v=-0.1430, grad=0.0000), Var(v=-0.0120, grad=1.0606), Var(v=-0.2068, grad=0.0000), Var(v=-0.0848, grad=0.0000), Var(v=0.0510, grad=1.2825), Var(v=-0.1368, grad=3.0245), Var(v=0.1599, grad=-2.2621), Var(v=-0.0875, grad=0.0000), Var(v=0.0162, grad=-1.0718), Var(v=-0.0550, grad=0.0000), Var(v=-0.0118, grad=0.0000), Var(v=0.1290, grad=0.0000), Var(v=0.1042, grad=2.0023), Var(v=0.0705, grad=-0.0622), Var(v=-0.0795, grad=0.0000),  ...
# Layer 2
#  Weights: [[Var(v=0.0434, grad=2.4953)], [Var(v=-0.0568, grad=4.7438)], [Var(v=-0.0136, grad=0.0000)], [Var(v=0.0342, grad=-3.9851)], [Var(v=-0.1795, grad=1.4264)], [Var(v=-0.2104, grad=4.5493)], [Var(v=-0.1934, grad=3.1350)], [Var(v=-0.1350, grad=3.6800)], [Var(v=0.1296, grad=-0.0728)], [Var(v=0.0151, grad=0.0000)], [Var(v=-0.0071, grad=0.9071)], [Var(v=0.0772, grad=0.0000)], [Var(v=-0.0445, grad=3.3460)], [Var(v=0.0053, grad=0.0000)], [Var(v=-0.0963, grad=2.4152)], [Var(v=-0.0371, grad=0.0000)], [Var(v=-0.0789, grad=-3.6301)], [Var(v=-0.0512, grad=2.4817)], [Var(v=-0.0024, grad=-3.8503)], [Var(v=0.0771, grad=0.0000)], [Var(v=0.0954, grad=0.0000)], [Var(v=0.1012, grad=0.0000)], [Var(v=0.0400, grad=0.0000)], [Var(v=0.1035, grad=0.0000)], [Var(v=0.0300, grad=0.0000)], [Var(v=0.0102, grad=-5.5099)], [Var(v=-0.3409, grad=0.0000)], [Var(v=-0.0195, grad=2.7339)], [Var(v=-0.0103, grad=-4.4057)], [Var(v=-0.1442, grad=1.6040)], [Var(v=0.0972, grad=-0.1345)], [Var(v=-0.0740, grad=0.0000)], [Var(v=0.0511, grad=-0.5687)], [Var(v=-0.0158, grad=0.0000)], [Var(v=0.1976, grad=0.0673)], [Var(v=-0.1300, grad=0.0000)], [Var(v=-0.0286, grad=-5.6240)], [Var(v=0.0204, grad=-1.7729)], [Var(v=0.0292, grad=0.0000)], [Var(v=-0.0534, grad=-2.0133)], [Var(v=-0.1309, grad=1.0865)], [Var(v=0.1766, grad=0.0000)], [Var(v=-0.3020, grad=0.6918)], [Var(v=-0.2609, grad=0.0000)], [Var(v=0.1170, grad=-6.6861)], [Var(v=-0.2221, grad=-2.0761)], [Var(v=0.0001, grad=1.4183)], [Var(v=-0.1618, grad=0.0000)], [Var(v=-0.0862, grad=-0.8779)], [Var(v=-0.0463, grad=-0.3124)]] Biases: [Var(v=0.0514, grad=-5.1449)]
#
# Network after zeroing gradients:
# Layer 0
#  Weights: [[Var(v=-0.1837, grad=0.0000), Var(v=0.0388, grad=0.0000), Var(v=0.2135, grad=0.0000), Var(v=0.0240, grad=0.0000), Var(v=-0.0687, grad=0.0000), Var(v=-0.1412, grad=0.0000), Var(v=0.0333, grad=0.0000), Var(v=-0.2591, grad=0.0000), Var(v=-0.0409, grad=0.0000), Var(v=-0.1254, grad=0.0000), Var(v=0.0628, grad=0.0000), Var(v=-0.0039, grad=0.0000), Var(v=-0.0872, grad=0.0000), Var(v=0.0498, grad=0.0000), Var(v=-0.1306, grad=0.0000)]] Biases: [Var(v=0.1018, grad=0.0000), Var(v=-0.1107, grad=0.0000), Var(v=-0.0113, grad=0.0000), Var(v=0.0165, grad=0.0000), Var(v=-0.0385, grad=0.0000), Var(v=0.0392, grad=0.0000), Var(v=0.0056, grad=0.0000), Var(v=0.1029, grad=0.0000), Var(v=0.0306, grad=0.0000), Var(v=0.0681, grad=0.0000), Var(v=0.0449, grad=0.0000), Var(v=-0.0257, grad=0.0000), Var(v=0.0183, grad=0.0000), Var(v=0.0061, grad=0.0000), Var(v=0.0033, grad=0.0000)]
# Layer 1
#  Weights: [[Var(v=0.0404, grad=0.0000), Var(v=0.0007, grad=0.0000), Var(v=-0.0290, grad=0.0000), Var(v=-0.0778, grad=0.0000), Var(v=-0.0550, grad=0.0000), Var(v=0.2945, grad=0.0000), Var(v=0.0701, grad=0.0000), Var(v=-0.0462, grad=0.0000), Var(v=0.0775, grad=0.0000), Var(v=0.1138, grad=0.0000), Var(v=0.1192, grad=0.0000), Var(v=0.1120, grad=0.0000), Var(v=0.2317, grad=0.0000), Var(v=-0.0963, grad=0.0000), Var(v=0.0164, grad=0.0000), Var(v=0.0084, grad=0.0000), Var(v=0.1359, grad=0.0000), Var(v=0.1460, grad=0.0000), Var(v=0.0097, grad=0.0000), Var(v=0.1381, grad=0.0000), Var(v=0.1366, grad=0.0000), Var(v=0.0683, grad=0.0000), Var(v=0.0053, grad=0.0000), Var(v=0.0011, grad=0.0000), Var(v=-0.1348, grad=0.0000), Var(v=0.0049, grad=0.0000), Var(v=-0.1057, grad=0.0000), Var(v=0.0874, grad=0.0000), Var(v=0.0990, grad=0.0000), Var(v=0.0373, grad=0.0000), Var(v=0.0599, grad=0.0000), Var(v=-0.1015, grad=0.0000), Var(v=-0.0931, grad=0.0000), Var(v=0.1466, grad=0.0000), Var(v=-0.1000, grad=0.0000), Var(v=0.0023, grad=0.0000), Var(v=0.1267, grad=0.0000), Var(v=-0.0606, grad=0.0000), Var(v=0.0746, grad=0.0000), Var(v=-0.1521, grad=0.0000), Var(v=0.0793, grad=0.0000), Var(v=-0.2873, grad=0.0000), Var(v=0.0833, grad=0.0000), Var(v=-0.1991, grad=0.0000), Var(v=0.1371, grad=0.0000), Var(v=0.0093, grad=0.0000), Var(v=-0.0273, grad=0.0000), Var(v=-0.0185, grad=0.0000), Var(v=0.0028, grad=0.0000), Var(v=-0.1214, grad=0.0000)], [Var(v=-0.0316, grad=0.0000), Var(v=-0.0118, grad=0.0000), Var(v=-0.0614, grad=0.0000), Var(v=0.0630, grad=0.0000), Var(v=-0.1303, grad=0.0000), Var(v=-0.0497, grad=0.0000), Var(v=-0.1128, grad=0.0000), Var(v=-0.1923, grad=0.0000), Var(v=-0.0113, grad=0.0000), Var(v=0.1688, grad=0.0000), Var(v=0.0305, grad=0.0000), Var(v=0.0278, grad=0.0000), Var(v=-0.1246, grad=0.0000), Var(v=-0.1673, grad=0.0000), Var(v=0.0518, grad=0.0000), Var(v=-0.1362, grad=0.0000), Var(v=0.1215, grad=0.0000), Var(v=0.0618, grad=0.0000), Var(v=-0.1259, grad=0.0000), Var(v=-0.0979, grad=0.0000), Var(v=0.0290, grad=0.0000), Var(v=-0.0563, grad=0.0000), Var(v=0.0167, grad=0.0000), Var(v=-0.0369, grad=0.0000), Var(v=-0.1444, grad=0.0000), Var(v=0.2692, grad=0.0000), Var(v=-0.0455, grad=0.0000), Var(v=-0.0573, grad=0.0000), Var(v=0.1294, grad=0.0000), Var(v=0.2183, grad=0.0000), Var(v=-0.1957, grad=0.0000), Var(v=-0.0054, grad=0.0000), Var(v=0.1087, grad=0.0000), Var(v=-0.0480, grad=0.0000), Var(v=-0.0101, grad=0.0000), Var(v=-0.1503, grad=0.0000), Var(v=0.1564, grad=0.0000), Var(v=0.0354, grad=0.0000), Var(v=0.0413, grad=0.0000), Var(v=0.0000, grad=0.0000), Var(v=-0.1131, grad=0.0000), Var(v=0.0210, grad=0.0000), Var(v=-0.0889, grad=0.0000), Var(v=-0.0575, grad=0.0000), Var(v=0.2793, grad=0.0000), Var(v=0.1298, grad=0.0000), Var(v=-0.1406, grad=0.0000), Var(v=-0.0524, grad=0.0000), Var(v=0.0276, grad=0.0000), Var(v=0.2016, grad=0.0000)], [Var(v=-0.1372, grad=0.0000), Var(v=-0.0028, grad=0.0000), Var(v=-0.1067, grad=0.0000), Var(v=0.1193, grad=0.0000), Var(v=0.0340, grad=0.0000), Var(v=-0.0978, grad=0.0000), Var(v=-0.0324, grad=0.0000), Var(v=0.0999, grad=0.0000), Var(v=0.0449, grad=0.0000), Var(v=-0.1700, grad=0.0000), Var(v=-0.1129, grad=0.0000), Var(v=-0.1751, grad=0.0000), Var(v=0.0455, grad=0.0000), Var(v=-0.1246, grad=0.0000), Var(v=-0.0579, grad=0.0000), Var(v=0.0394, grad=0.0000), Var(v=0.1135, grad=0.0000), Var(v=-0.1362, grad=0.0000), Var(v=0.2224, grad=0.0000), Var(v=-0.2772, grad=0.0000), Var(v=-0.0459, grad=0.0000), Var(v=0.0120, grad=0.0000), Var(v=-0.1057, grad=0.0000), Var(v=-0.0758, grad=0.0000), Var(v=-0.1430, grad=0.0000), Var(v=-0.0120, grad=0.0000), Var(v=-0.2068, grad=0.0000), Var(v=-0.0848, grad=0.0000), Var(v=0.0510, grad=0.0000), Var(v=-0.1368, grad=0.0000), Var(v=0.1599, grad=0.0000), Var(v=-0.0875, grad=0.0000), Var(v=0.0162, grad=0.0000), Var(v=-0.0550, grad=0.0000), Var(v=-0.0118, grad=0.0000), Var(v=0.1290, grad=0.0000), Var(v=0.1042, grad=0.0000), Var(v=0.0705, grad=0.0000), Var(v=-0.0795, grad=0.0000), Var(v=0.0642, grad=0.00 ...
# Layer 2
#  Weights: [[Var(v=0.0434, grad=0.0000)], [Var(v=-0.0568, grad=0.0000)], [Var(v=-0.0136, grad=0.0000)], [Var(v=0.0342, grad=0.0000)], [Var(v=-0.1795, grad=0.0000)], [Var(v=-0.2104, grad=0.0000)], [Var(v=-0.1934, grad=0.0000)], [Var(v=-0.1350, grad=0.0000)], [Var(v=0.1296, grad=0.0000)], [Var(v=0.0151, grad=0.0000)], [Var(v=-0.0071, grad=0.0000)], [Var(v=0.0772, grad=0.0000)], [Var(v=-0.0445, grad=0.0000)], [Var(v=0.0053, grad=0.0000)], [Var(v=-0.0963, grad=0.0000)], [Var(v=-0.0371, grad=0.0000)], [Var(v=-0.0789, grad=0.0000)], [Var(v=-0.0512, grad=0.0000)], [Var(v=-0.0024, grad=0.0000)], [Var(v=0.0771, grad=0.0000)], [Var(v=0.0954, grad=0.0000)], [Var(v=0.1012, grad=0.0000)], [Var(v=0.0400, grad=0.0000)], [Var(v=0.1035, grad=0.0000)], [Var(v=0.0300, grad=0.0000)], [Var(v=0.0102, grad=0.0000)], [Var(v=-0.3409, grad=0.0000)], [Var(v=-0.0195, grad=0.0000)], [Var(v=-0.0103, grad=0.0000)], [Var(v=-0.1442, grad=0.0000)], [Var(v=0.0972, grad=0.0000)], [Var(v=-0.0740, grad=0.0000)], [Var(v=0.0511, grad=0.0000)], [Var(v=-0.0158, grad=0.0000)], [Var(v=0.1976, grad=0.0000)], [Var(v=-0.1300, grad=0.0000)], [Var(v=-0.0286, grad=0.0000)], [Var(v=0.0204, grad=0.0000)], [Var(v=0.0292, grad=0.0000)], [Var(v=-0.0534, grad=0.0000)], [Var(v=-0.1309, grad=0.0000)], [Var(v=0.1766, grad=0.0000)], [Var(v=-0.3020, grad=0.0000)], [Var(v=-0.2609, grad=0.0000)], [Var(v=0.1170, grad=0.0000)], [Var(v=-0.2221, grad=0.0000)], [Var(v=0.0001, grad=0.0000)], [Var(v=-0.1618, grad=0.0000)], [Var(v=-0.0862, grad=0.0000)], [Var(v=-0.0463, grad=0.0000)]] Biases: [Var(v=0.0514, grad=0.0000)]
# [None, None, None]

# %%
# Initialize an arbitrary neural network
NN = [
    DenseLayer(1, 42, lambda x: x.relu()),
    DenseLayer(42, 1, lambda x: x.identity())
]

# Recommended hyper-parameters for 3-D:
#NN = [
#    DenseLayer(3, 16, lambda x: x.relu()),
#    DenseLayer(16, 1, lambda x: x.identity())
#]


### Notice that, when we switch from tanh to relu activation, we decrease the learning rate. This is due the stability of the gradients
## of the activation functions.

# %%
# Initialize training hyperparameters
EPOCHS = 2500
LEARN_R = 0.0015

# %%
train_loss = []
val_loss = []
avgs = []
avgavg = 0
learningrate_history = []

for e in range(EPOCHS):

    # Forward pass and loss computation
    Loss = squared_loss(y_train, forward(x_train, NN))

    # Backward pass
    Loss.backward()

    # gradient descent update
    learningraterightnow =  LEARN_R - ((e/(EPOCHS / LEARN_R))) + 0.0005
    
    if((e > 75) and (e < 125)):
        train_loss_last_10 = train_loss[-10:]
        train_loss_last_10_but_not_last = train_loss_last_10[:9]
        
        last = train_loss[-1]
        tlb = train_loss_last_10_but_not_last
        avg = sum([(tlb[i] - last) for i in range(len(tlb))]) / len(tlb)
        avgs.append(avg)
        avgavg = abs(sum(avgs) / len(avgs))
    
    if(e == 125):
        print("avgavg: " + str(avgavg))
    
    if((e > 125)):
        train_loss_last_20 = train_loss[-20:]
        train_loss_last_20_but_not_last5 = train_loss_last_10[:15]
        
        last5 = train_loss[-5:]
        last5avg = sum(last5) / len(last5)
        tlb20 = train_loss_last_20_but_not_last5
        avg = sum([(tlb20[i] - last5avg) for i in range(len(tlb20))]) / len(tlb20)
        targetROC = avgavg * (5 - (e/EPOCHS))
        LRboost = exp(log(targetROC) - log(abs(avg)) )
        if(LRboost < 0.3):
            LRBoost = 0.3
        if(LRboost > 3):
            LRboost = 3
        learningraterightnow += (LRboost * LEARN_R)
        if(e % 5 == 0):
            print("(LRBoost) " + str(LRboost * LEARN_R) + ", avgavg: " + str(avgavg) + ", " + "avg: " + str(avg))

    learningrate_history.append(learningraterightnow)

    update_parameters(parameters(NN), learningraterightnow)
    zero_gradients(parameters(NN))

    # Training loss
    train_loss.append(Loss.v)

    # Validation
    Loss_validation = squared_loss(y_validation, forward(x_validation, NN))
    val_loss.append(Loss_validation.v)

    if e%5==0:
        print(learningraterightnow)
        print("{:4d}".format(e),
              "({:5.2f}%)".format(e/EPOCHS*100),
              "Train loss: {:4.4f} \t Validation loss: {:4.4f} \t Learning rate: {:4.5f}".format(train_loss[-1], val_loss[-1], learningraterightnow))
# Out:
# 0.002
#    0 ( 0.00%) Train loss: 102.2273 	 Validation loss: 86.3874 	 Learning rate: 0.00200
# 0.001997
#    5 ( 0.20%) Train loss: 30.3679 	 Validation loss: 20.1479 	 Learning rate: 0.00200
# 0.001994
#   10 ( 0.40%) Train loss: 13.9331 	 Validation loss: 10.4558 	 Learning rate: 0.00199
# 0.001991
#   15 ( 0.60%) Train loss: 13.5194 	 Validation loss: 10.0472 	 Learning rate: 0.00199
# 0.001988
#   20 ( 0.80%) Train loss: 13.2755 	 Validation loss: 9.8696 	 Learning rate: 0.00199
# 0.001985
#   25 ( 1.00%) Train loss: 13.0822 	 Validation loss: 9.7344 	 Learning rate: 0.00198
# 0.0019820000000000003
#   30 ( 1.20%) Train loss: 12.9092 	 Validation loss: 9.6161 	 Learning rate: 0.00198
# 0.001979
#   35 ( 1.40%) Train loss: 12.7528 	 Validation loss: 9.5082 	 Learning rate: 0.00198
# 0.0019760000000000003
#   40 ( 1.60%) Train loss: 12.6072 	 Validation loss: 9.4165 	 Learning rate: 0.00198
# 0.001973
#   45 ( 1.80%) Train loss: 12.4743 	 Validation loss: 9.3336 	 Learning rate: 0.00197
# 0.00197
#   50 ( 2.00%) Train loss: 12.3553 	 Validation loss: 9.2593 	 Learning rate: 0.00197
# 0.001967
#   55 ( 2.20%) Train loss: 12.2587 	 Validation loss: 9.1939 	 Learning rate: 0.00197
# 0.001964
#   60 ( 2.40%) Train loss: 12.1780 	 Validation loss: 9.1351 	 Learning rate: 0.00196
# 0.001961
#   65 ( 2.60%) Train loss: 12.1209 	 Validation loss: 9.0908 	 Learning rate: 0.00196
# 0.001958
#   70 ( 2.80%) Train loss: 12.0775 	 Validation loss: 9.0583 	 Learning rate: 0.00196
# 0.001955
#   75 ( 3.00%) Train loss: 12.0419 	 Validation loss: 9.0315 	 Learning rate: 0.00196
# 0.001952
#   80 ( 3.20%) Train loss: 12.0118 	 Validation loss: 9.0108 	 Learning rate: 0.00195
# 0.001949
#   85 ( 3.40%) Train loss: 11.9870 	 Validation loss: 8.9989 	 Learning rate: 0.00195
# 0.001946
#   90 ( 3.60%) Train loss: 11.9669 	 Validation loss: 8.9914 	 Learning rate: 0.00195
# 0.001943
#   95 ( 3.80%) Train loss: 11.9509 	 Validation loss: 8.9874 	 Learning rate: 0.00194
# 0.00194
#  100 ( 4.00%) Train loss: 11.9382 	 Validation loss: 8.9865 	 Learning rate: 0.00194
# 0.0019370000000000001
#  105 ( 4.20%) Train loss: 11.9284 	 Validation loss: 8.9867 	 Learning rate: 0.00194
# 0.001934
#  110 ( 4.40%) Train loss: 11.9203 	 Validation loss: 8.9897 	 Learning rate: 0.00193
# 0.001931
#  115 ( 4.60%) Train loss: 11.9134 	 Validation loss: 8.9917 	 Learning rate: 0.00193
# 0.001928
#  120 ( 4.80%) Train loss: 11.9079 	 Validation loss: 8.9936 	 Learning rate: 0.00193
# avgavg: 0.01636515688573549
# 0.001925
#  125 ( 5.00%) Train loss: 11.9033 	 Validation loss: 8.9951 	 Learning rate: 0.00193
# (LRBoost) 0.0045000000000000005, avgavg: 0.01636515688573549, avg: 0.01026957803883235
# 0.006422000000000001
#  130 ( 5.20%) Train loss: 11.8923 	 Validation loss: 9.0007 	 Learning rate: 0.00642
# (LRBoost) 0.0045000000000000005, avgavg: 0.01636515688573549, avg: 0.020395832529827372
# 0.006419000000000001
#  135 ( 5.40%) Train loss: 11.8902 	 Validation loss: 8.9778 	 Learning rate: 0.00642
# (LRBoost) 0.000275178734320014, avgavg: 0.01636515688573549, avg: -0.44103700005930124
# 0.002191178734320014
#  140 ( 5.60%) Train loss: 12.4712 	 Validation loss: 9.0460 	 Learning rate: 0.00219
# (LRBoost) 0.0013770661041541464, avgavg: 0.01636515688573549, avg: -0.08809664810424919
# 0.0032900661041541466
#  145 ( 5.80%) Train loss: 11.8781 	 Validation loss: 9.0017 	 Learning rate: 0.00329
# (LRBoost) 0.0037543371732203187, avgavg: 0.01636515688573549, avg: 0.032300192265172355
# 0.0056643371732203185
#  150 ( 6.00%) Train loss: 11.8760 	 Validation loss: 9.0036 	 Learning rate: 0.00566
# (LRBoost) 0.00352531574475681, avgavg: 0.01636515688573549, avg: 0.034384641214883514
# 0.00543231574475681
#  155 ( 6.20%) Train loss: 11.8741 	 Validation loss: 9.0025 	 Learning rate: 0.00543
# (LRBoost) 0.003344343515125535, avgavg: 0.01636515688573549, avg: 0.036230614778050806
# 0.005248343515125535
#  160 ( 6.40%) Train loss: 11.8726 	 Validation loss: 9.0132 	 Learning rate: 0.00525
# (LRBoost) 0.0035410982670003133, avgavg: 0.01636515688573549, avg: 0.034203661400768935
# 0.005442098267000314
#  165 ( 6.60%) Train loss: 11.8951 	 Validation loss: 8.9892 	 Learning rate: 0.00544
# (LRBoost) 0.0001300551419951609, avgavg: 0.01636515688573549, avg: -0.9309084499340742
# 0.002028055141995161
#  170 ( 6.80%) Train loss: 11.9924 	 Validation loss: 9.0422 	 Learning rate: 0.00203
# (LRBoost) 0.0045000000000000005, avgavg: 0.01636515688573549, avg: 0.016008699821922788
# 0.0063950000000000005
#  175 ( 7.00%) Train loss: 11.8677 	 Validation loss: 8.9965 	 Learning rate: 0.00640
# (LRBoost) 0.002823178580059465, avgavg: 0.01636515688573549, avg: 0.0428493048770612
# 0.004715178580059464
#  180 ( 7.20%) Train loss: 11.8655 	 Validation loss: 8.9970 	 Learning rate: 0.00472
# (LRBoost) 0.0026902292489861296, avgavg: 0.01636515688573549, avg: 0.04494863933037365
# 0.004579229248986129
#  185 ( 7.40%) Train loss: 11.8633 	 Validation loss: 8.9965 	 Learning rate: 0.00458
# (LRBoost) 0.0025622199656624156, avgavg: 0.01636515688573549, avg: 0.04717512562462325
# 0.004448219965662416
#  190 ( 7.60%) Train loss: 11.8610 	 Validation loss: 8.9947 	 Learning rate: 0.00445
# (LRBoost) 0.0024357624716594326, avgavg: 0.01636515688573549, avg: 0.049604160788744876
# 0.004318762471659432
#  195 ( 7.80%) Train loss: 11.8584 	 Validation loss: 8.9929 	 Learning rate: 0.00432
# (LRBoost) 0.002309240712416443, avgavg: 0.01636515688573549, avg: 0.052300679252422454
# 0.004189240712416443
#  200 ( 8.00%) Train loss: 11.8556 	 Validation loss: 8.9903 	 Learning rate: 0.00419
# (LRBoost) 0.0021873739745386653, avgavg: 0.01636515688573549, avg: 0.05519209963697804
# 0.0040643739745386655
#  205 ( 8.20%) Train loss: 11.8525 	 Validation loss: 8.9888 	 Learning rate: 0.00406
# (LRBoost) 0.002063596269489771, avgavg: 0.01636515688573549, avg: 0.058478816161676404
# 0.003937596269489771
#  210 ( 8.40%) Train loss: 11.8490 	 Validation loss: 8.9859 	 Learning rate: 0.00394
# (LRBoost) 0.0019445981443203405, avgavg: 0.01636515688573549, avg: 0.06203213335211579
# 0.0038155981443203403
#  215 ( 8.60%) Train loss: 11.8453 	 Validation loss: 8.9832 	 Learning rate: 0.00382
# (LRBoost) 0.0018289825930930868, avgavg: 0.01636515688573549, avg: 0.06592653007713026
# 0.003696982593093087
#  220 ( 8.80%) Train loss: 11.8411 	 Validation loss: 8.9801 	 Learning rate: 0.00370
# (LRBoost) 0.0017136113539649724, avgavg: 0.01636515688573549, avg: 0.07033647401119261
# 0.0035786113539649726
#  225 ( 9.00%) Train loss: 11.8365 	 Validation loss: 8.9767 	 Learning rate: 0.00358
# (LRBoost) 0.001606400517689177, avgavg: 0.01636515688573549, avg: 0.07500015324079748
# 0.003468400517689177
#  230 ( 9.20%) Train loss: 11.8318 	 Validation loss: 8.9735 	 Learning rate: 0.00347
# (LRBoost) 0.0015112537946540274, avgavg: 0.01636515688573549, avg: 0.07968958618873004
# 0.0033702537946540276
#  235 ( 9.40%) Train loss: 11.8272 	 Validation loss: 8.9703 	 Learning rate: 0.00337
# (LRBoost) 0.0014290350345182623, avgavg: 0.01636515688573549, avg: 0.08424012787905646
# 0.0032850350345182623
#  240 ( 9.60%) Train loss: 11.8227 	 Validation loss: 8.9672 	 Learning rate: 0.00329
# (LRBoost) 0.0013568517336431788, avgavg: 0.01636515688573549, avg: 0.08868544410354709
# 0.003209851733643179
#  245 ( 9.80%) Train loss: 11.8183 	 Validation loss: 8.9640 	 Learning rate: 0.00321
# (LRBoost) 0.001292487561170707, avgavg: 0.01636515688573549, avg: 0.0930638767627329
# 0.0031424875611707074
#  250 (10.00%) Train loss: 11.8139 	 Validation loss: 8.9608 	 Learning rate: 0.00314
# (LRBoost) 0.0012329981492290615, avgavg: 0.01636515688573549, avg: 0.09751418338679266
# 0.003079998149229062
#  255 (10.20%) Train loss: 11.8094 	 Validation loss: 8.9575 	 Learning rate: 0.00308
# (LRBoost) 0.0011774460590372562, avgavg: 0.01636515688573549, avg: 0.10207322131351973
# 0.0030214460590372565
#  260 (10.40%) Train loss: 11.8047 	 Validation loss: 8.9541 	 Learning rate: 0.00302
# (LRBoost) 0.001125541152442992, avgavg: 0.01636515688573549, avg: 0.10673676074608843
# 0.002966541152442992
#  265 (10.60%) Train loss: 11.8000 	 Validation loss: 8.9507 	 Learning rate: 0.00297
# (LRBoost) 0.001076774503701638, avgavg: 0.01636515688573549, avg: 0.11152522725482542
# 0.002914774503701638
#  270 (10.80%) Train loss: 11.7951 	 Validation loss: 8.9472 	 Learning rate: 0.00291
# (LRBoost) 0.0010309119657106562, avgavg: 0.01636515688573549, avg: 0.11643906536104823
# 0.002865911965710656
#  275 (11.00%) Train loss: 11.7902 	 Validation loss: 8.9436 	 Learning rate: 0.00287
# (LRBoost) 0.000987670452065698, avgavg: 0.01636515688573549, avg: 0.12148721269858456
# 0.002819670452065698
#  280 (11.20%) Train loss: 11.7850 	 Validation loss: 8.9399 	 Learning rate: 0.00282
# (LRBoost) 0.0009468430598392401, avgavg: 0.01636515688573549, avg: 0.12667382790546036
# 0.0027758430598392404
#  285 (11.40%) Train loss: 11.7798 	 Validation loss: 8.9361 	 Learning rate: 0.00278
# (LRBoost) 0.0009082451634605705, avgavg: 0.01636515688573549, avg: 0.13200305839019535
# 0.0027342451634605703
#  290 (11.60%) Train loss: 11.7743 	 Validation loss: 8.9322 	 Learning rate: 0.00273
# (LRBoost) 0.0008717111547960944, avgavg: 0.01636515688573549, avg: 0.13747907574071797
# 0.002694711154796094
#  295 (11.80%) Train loss: 11.7688 	 Validation loss: 8.9282 	 Learning rate: 0.00269
# (LRBoost) 0.0008370955100827774, avgavg: 0.01636515688573549, avg: 0.14310547238718066
# 0.002657095510082777
#  300 (12.00%) Train loss: 11.7631 	 Validation loss: 8.9239 	 Learning rate: 0.00266
# (LRBoost) 0.0008042615378626783, avgavg: 0.01636515688573549, avg: 0.14888670823566344
# 0.0026212615378626786
#  305 (12.20%) Train loss: 11.7572 	 Validation loss: 8.9197 	 Learning rate: 0.00262
# (LRBoost) 0.0007730953646143273, avgavg: 0.01636515688573549, avg: 0.15482534618737667
# 0.0025870953646143276
#  310 (12.40%) Train loss: 11.7512 	 Validation loss: 8.9160 	 Learning rate: 0.00259
# (LRBoost) 0.0007434878862141926, avgavg: 0.01636515688573549, avg: 0.16092483039749653
# 0.0025544878862141926
#  315 (12.60%) Train loss: 11.7449 	 Validation loss: 8.9115 	 Learning rate: 0.00255
# (LRBoost) 0.0007153212547571905, avgavg: 0.01636515688573549, avg: 0.16719280424786334
# 0.0025233212547571904
#  320 (12.80%) Train loss: 11.7386 	 Validation loss: 8.9070 	 Learning rate: 0.00252
# (LRBoost) 0.0006885142605355248, avgavg: 0.01636515688573549, avg: 0.17363107476860976
# 0.0024935142605355246
#  325 (13.00%) Train loss: 11.7320 	 Validation loss: 8.9018 	 Learning rate: 0.00249
# (LRBoost) 0.0006629823693708614, avgavg: 0.01636515688573549, avg: 0.18024367026990298
# 0.0024649823693708613
#  330 (13.20%) Train loss: 11.7253 	 Validation loss: 8.8970 	 Learning rate: 0.00246
# (LRBoost) 0.0006386498000761573, avgavg: 0.01636515688573549, avg: 0.1870340836163095
# 0.0024376498000761573
#  335 (13.40%) Train loss: 11.7184 	 Validation loss: 8.8918 	 Learning rate: 0.00244
# (LRBoost) 0.0006154559025247905, avgavg: 0.01636515688573549, avg: 0.19400282643892056
# 0.0024114559025247904
#  340 (13.60%) Train loss: 11.7113 	 Validation loss: 8.8873 	 Learning rate: 0.00241
# (LRBoost) 0.000593322301332665, avgavg: 0.01636515688573549, avg: 0.2011572612382743
# 0.002386322301332665
#  345 (13.80%) Train loss: 11.7041 	 Validation loss: 8.8817 	 Learning rate: 0.00239
# (LRBoost) 0.00057217930811945, avgavg: 0.01636515688573549, avg: 0.20850455793152492
# 0.00236217930811945
#  350 (14.00%) Train loss: 11.6966 	 Validation loss: 8.8766 	 Learning rate: 0.00236
# (LRBoost) 0.0005519867720683745, avgavg: 0.01636515688573549, avg: 0.21604303628417867
# 0.0023389867720683744
#  355 (14.20%) Train loss: 11.6889 	 Validation loss: 8.8718 	 Learning rate: 0.00234
# (LRBoost) 0.0005326871085645044, avgavg: 0.01636515688573549, avg: 0.22377827591309654
# 0.002316687108564504
#  360 (14.40%) Train loss: 11.6811 	 Validation loss: 8.8653 	 Learning rate: 0.00232
# (LRBoost) 0.0005142259285418185, avgavg: 0.01636515688573549, avg: 0.23171664568320197
# 0.0022952259285418187
#  365 (14.60%) Train loss: 11.6731 	 Validation loss: 8.8599 	 Learning rate: 0.00230
# (LRBoost) 0.0004965782351863599, avgavg: 0.01636515688573549, avg: 0.2398526624302896
# 0.00227457823518636
#  370 (14.80%) Train loss: 11.6648 	 Validation loss: 8.8548 	 Learning rate: 0.00227
# (LRBoost) 0.00047967275182434366, avgavg: 0.01636515688573549, avg: 0.2482036260990789
# 0.0022546727518243438
#  375 (15.00%) Train loss: 11.6563 	 Validation loss: 8.8482 	 Learning rate: 0.00225
# (LRBoost) 0.000463481680418873, avgavg: 0.01636515688573549, avg: 0.2567683382124514
# 0.0022354816804188733
#  380 (15.20%) Train loss: 11.6476 	 Validation loss: 8.8424 	 Learning rate: 0.00224
# (LRBoost) 0.00044798425356933075, avgavg: 0.01636515688573549, avg: 0.26554130966570033
# 0.002216984253569331
#  385 (15.40%) Train loss: 11.6387 	 Validation loss: 8.8357 	 Learning rate: 0.00222
# (LRBoost) 0.00043312180883048806, avgavg: 0.01636515688573549, avg: 0.27453992735399735
# 0.002199121808830488
#  390 (15.60%) Train loss: 11.6296 	 Validation loss: 8.8302 	 Learning rate: 0.00220
# (LRBoost) 0.0004188754868569685, avgavg: 0.01636515688573549, avg: 0.2837600628123734
# 0.0021818754868569686
#  395 (15.80%) Train loss: 11.6202 	 Validation loss: 8.8226 	 Learning rate: 0.00218
# (LRBoost) 0.00040520763236134627, avgavg: 0.01636515688573549, avg: 0.2932102692589197
# 0.002165207632361346
#  400 (16.00%) Train loss: 11.6106 	 Validation loss: 8.8170 	 Learning rate: 0.00217
# (LRBoost) 0.00039210690590460256, avgavg: 0.01636515688573549, avg: 0.3028815400376462
# 0.0021491069059046027
#  405 (16.20%) Train loss: 11.6008 	 Validation loss: 8.8103 	 Learning rate: 0.00215
# (LRBoost) 0.0003795352636312461, avgavg: 0.01636515688573549, avg: 0.3127847644862477
# 0.0021335352636312464
#  410 (16.40%) Train loss: 11.5908 	 Validation loss: 8.8027 	 Learning rate: 0.00213
# (LRBoost) 0.0003674548577270887, avgavg: 0.01636515688573549, avg: 0.3229342328264998
# 0.0021184548577270887
#  415 (16.60%) Train loss: 11.5805 	 Validation loss: 8.7973 	 Learning rate: 0.00212
# (LRBoost) 0.000355872643283954, avgavg: 0.01636515688573549, avg: 0.33330647732078444
# 0.002103872643283954
#  420 (16.80%) Train loss: 11.5699 	 Validation loss: 8.7893 	 Learning rate: 0.00210
# (LRBoost) 0.0003447197626848531, avgavg: 0.01636515688573549, avg: 0.3439476771325921
# 0.002089719762684853
#  425 (17.00%) Train loss: 11.5592 	 Validation loss: 8.7821 	 Learning rate: 0.00209
# (LRBoost) 0.0003340248109906451, avgavg: 0.01636515688573549, avg: 0.354813361962551
# 0.0020760248109906454
#  430 (17.20%) Train loss: 11.5481 	 Validation loss: 8.7756 	 Learning rate: 0.00208
# (LRBoost) 0.00032372189075531593, avgavg: 0.01636515688573549, avg: 0.3659541541025483
# 0.002062721890755316
#  435 (17.40%) Train loss: 11.5369 	 Validation loss: 8.7671 	 Learning rate: 0.00206
# (LRBoost) 0.0003138389238132227, avgavg: 0.01636515688573549, avg: 0.3773218241586157
# 0.002049838923813223
#  440 (17.60%) Train loss: 11.5253 	 Validation loss: 8.7595 	 Learning rate: 0.00205
# (LRBoost) 0.0003043095548075175, avgavg: 0.01636515688573549, avg: 0.38897621807963245
# 0.002037309554807518
#  445 (17.80%) Train loss: 11.5136 	 Validation loss: 8.7515 	 Learning rate: 0.00204
# (LRBoost) 0.00029515835455815205, avgavg: 0.01636515688573549, avg: 0.40086984649643786
# 0.002025158354558152
#  450 (18.00%) Train loss: 11.5015 	 Validation loss: 8.7437 	 Learning rate: 0.00203
# (LRBoost) 0.0002863410374304479, avgavg: 0.01636515688573549, avg: 0.4130423982344421
# 0.0020133410374304477
#  455 (18.20%) Train loss: 11.4892 	 Validation loss: 8.7352 	 Learning rate: 0.00201
# (LRBoost) 0.00027785879264298946, avgavg: 0.01636515688573549, avg: 0.4254747248342511
# 0.0020018587926429895
#  460 (18.40%) Train loss: 11.4765 	 Validation loss: 8.7267 	 Learning rate: 0.00200
# (LRBoost) 0.0002696908183011937, avgavg: 0.01636515688573549, avg: 0.43817879531931003
# 0.001990690818301194
#  465 (18.60%) Train loss: 11.4637 	 Validation loss: 8.7182 	 Learning rate: 0.00199
# (LRBoost) 0.0002618216847213822, avgavg: 0.01636515688573549, avg: 0.45116088274712707
# 0.0019798216847213826
#  470 (18.80%) Train loss: 11.4505 	 Validation loss: 8.7092 	 Learning rate: 0.00198
# (LRBoost) 0.00025424662698552645, avgavg: 0.01636515688573549, avg: 0.4644097281861018
# 0.0019692466269855264
#  475 (19.00%) Train loss: 11.4371 	 Validation loss: 8.7013 	 Learning rate: 0.00197
# (LRBoost) 0.00024694398022784736, avgavg: 0.01636515688573549, avg: 0.4779444769256006
# 0.001958943980227847
#  480 (19.20%) Train loss: 11.4234 	 Validation loss: 8.6919 	 Learning rate: 0.00196
# (LRBoost) 0.00023990519303571675, avgavg: 0.01636515688573549, avg: 0.4917626604760613
# 0.0019489051930357167
#  485 (19.40%) Train loss: 11.4095 	 Validation loss: 8.6822 	 Learning rate: 0.00195
# (LRBoost) 0.00023312574023801136, avgavg: 0.01636515688573549, avg: 0.5058528517623632
# 0.0019391257402380114
#  490 (19.60%) Train loss: 11.3952 	 Validation loss: 8.6733 	 Learning rate: 0.00194
# (LRBoost) 0.00022658621786984402, avgavg: 0.01636515688573549, avg: 0.5202356354951142
# 0.0019295862178698442
#  495 (19.80%) Train loss: 11.3806 	 Validation loss: 8.6649 	 Learning rate: 0.00193
# (LRBoost) 0.00022028124849581736, avgavg: 0.01636515688573549, avg: 0.5349031312555542
# 0.0019202812484958175
#  500 (20.00%) Train loss: 11.3658 	 Validation loss: 8.6542 	 Learning rate: 0.00192
# (LRBoost) 0.0002141976098754484, avgavg: 0.01636515688573549, avg: 0.5498662388208956
# 0.0019111976098754486
#  505 (20.20%) Train loss: 11.3507 	 Validation loss: 8.6445 	 Learning rate: 0.00191
# (LRBoost) 0.00020832972066066107, avgavg: 0.01636515688573549, avg: 0.5651183050725045
# 0.001902329720660661
#  510 (20.40%) Train loss: 11.3352 	 Validation loss: 8.6345 	 Learning rate: 0.00190
# (LRBoost) 0.0002026705036598311, avgavg: 0.01636515688573549, avg: 0.5806559960143239
# 0.0018936705036598311
#  515 (20.60%) Train loss: 11.3195 	 Validation loss: 8.6235 	 Learning rate: 0.00189
# (LRBoost) 0.00019718601032816933, avgavg: 0.01636515688573549, avg: 0.5965572684334702
# 0.0018851860103281694
#  520 (20.80%) Train loss: 11.3034 	 Validation loss: 8.6141 	 Learning rate: 0.00189
# (LRBoost) 0.00019188489179606456, avgavg: 0.01636515688573549, avg: 0.6127822316984574
# 0.0018768848917960646
#  525 (21.00%) Train loss: 11.2870 	 Validation loss: 8.6024 	 Learning rate: 0.00188
# (LRBoost) 0.00018676551954188258, avgavg: 0.01636515688573549, avg: 0.6293161448732775
# 0.0018687655195418827
#  530 (21.20%) Train loss: 11.2703 	 Validation loss: 8.5909 	 Learning rate: 0.00187
# (LRBoost) 0.00018182577425821143, avgavg: 0.01636515688573549, avg: 0.6461430551416413
# 0.0018608257742582113
#  535 (21.40%) Train loss: 11.2533 	 Validation loss: 8.5795 	 Learning rate: 0.00186
# (LRBoost) 0.00017705810479275071, avgavg: 0.01636515688573549, avg: 0.663264559108994
# 0.0018530581047927507
#  540 (21.60%) Train loss: 11.2360 	 Validation loss: 8.5687 	 Learning rate: 0.00185
# (LRBoost) 0.00017245385314005349, avgavg: 0.01636515688573549, avg: 0.6806880113374326
# 0.0018454538531400535
#  545 (21.80%) Train loss: 11.2183 	 Validation loss: 8.5574 	 Learning rate: 0.00185
# (LRBoost) 0.00016800357955586417, avgavg: 0.01636515688573549, avg: 0.6984266357950218
# 0.0018380035795558642
#  550 (22.00%) Train loss: 11.2003 	 Validation loss: 8.5453 	 Learning rate: 0.00184
# (LRBoost) 0.00016368593578115442, avgavg: 0.01636515688573549, avg: 0.7165495241868548
# 0.0018306859357811545
#  555 (22.20%) Train loss: 11.1820 	 Validation loss: 8.5324 	 Learning rate: 0.00183
# (LRBoost) 0.00015952100697266675, avgavg: 0.01636515688573549, avg: 0.7349501244654103
# 0.0018235210069726668
#  560 (22.40%) Train loss: 11.1635 	 Validation loss: 8.5204 	 Learning rate: 0.00182
# (LRBoost) 0.0001555009046050769, avgavg: 0.01636515688573549, avg: 0.7536347698836842
# 0.001816500904605077
#  565 (22.60%) Train loss: 11.1446 	 Validation loss: 8.5090 	 Learning rate: 0.00182
# (LRBoost) 0.00015161670412855882, avgavg: 0.01636515688573549, avg: 0.7726179886404058
# 0.001809616704128559
#  570 (22.80%) Train loss: 11.1254 	 Validation loss: 8.4957 	 Learning rate: 0.00181
# (LRBoost) 0.00014786194939161952, avgavg: 0.01636515688573549, avg: 0.7919055443216955
# 0.0018028619493916196
#  575 (23.00%) Train loss: 11.1060 	 Validation loss: 8.4822 	 Learning rate: 0.00180
# (LRBoost) 0.00014420408258202267, avgavg: 0.01636515688573549, avg: 0.8116524854988508
# 0.0017962040825820226
#  580 (23.20%) Train loss: 11.0859 	 Validation loss: 8.4691 	 Learning rate: 0.00180
# (LRBoost) 0.00014064471780571622, avgavg: 0.01636515688573549, avg: 0.8318442981821533
# 0.0017896447178057163
#  585 (23.40%) Train loss: 11.0655 	 Validation loss: 8.4542 	 Learning rate: 0.00179
# (LRBoost) 0.00013721062378959533, avgavg: 0.01636515688573549, avg: 0.8523058045767286
# 0.0017832106237895954
#  590 (23.60%) Train loss: 11.0449 	 Validation loss: 8.4417 	 Learning rate: 0.00178
# (LRBoost) 0.00013389658297782332, avgavg: 0.01636515688573549, avg: 0.8730343451271615
# 0.0017768965829778232
#  595 (23.80%) Train loss: 11.0241 	 Validation loss: 8.4270 	 Learning rate: 0.00178
# (LRBoost) 0.00013069927142853025, avgavg: 0.01636515688573549, avg: 0.8940158494154001
# 0.0017706992714285302
#  600 (24.00%) Train loss: 11.0028 	 Validation loss: 8.4131 	 Learning rate: 0.00177
# (LRBoost) 0.000127604074302476, avgavg: 0.01636515688573549, avg: 0.9153165785022889
# 0.001764604074302476
#  605 (24.20%) Train loss: 10.9814 	 Validation loss: 8.4007 	 Learning rate: 0.00176
# (LRBoost) 0.00012461338636042974, avgavg: 0.01636515688573549, avg: 0.93688994924794
# 0.0017586133863604298
#  610 (24.40%) Train loss: 10.9597 	 Validation loss: 8.3868 	 Learning rate: 0.00176
# (LRBoost) 0.00012172723915135361, avgavg: 0.01636515688573549, avg: 0.958700242984046
# 0.0017527272391513536
#  615 (24.60%) Train loss: 10.9377 	 Validation loss: 8.3733 	 Learning rate: 0.00175
# (LRBoost) 0.00011894386342554574, avgavg: 0.01636515688573549, avg: 0.980721786917082
# 0.0017469438634255458
#  620 (24.80%) Train loss: 10.9156 	 Validation loss: 8.3599 	 Learning rate: 0.00175
# (LRBoost) 0.00011626259341611289, avgavg: 0.01636515688573549, avg: 1.002917098137822
# 0.001741262593416113
#  625 (25.00%) Train loss: 10.8932 	 Validation loss: 8.3461 	 Learning rate: 0.00174
# (LRBoost) 0.00011366741879457826, avgavg: 0.01636515688573549, avg: 1.0253830743781038
# 0.0017356674187945784
#  630 (25.20%) Train loss: 10.8706 	 Validation loss: 8.3326 	 Learning rate: 0.00174
# (LRBoost) 0.00011115637395453307, avgavg: 0.01636515688573549, avg: 1.0481050049114153
# 0.001730156373954533
#  635 (25.40%) Train loss: 10.8477 	 Validation loss: 8.3196 	 Learning rate: 0.00173
# (LRBoost) 0.0001087308551252007, avgavg: 0.01636515688573549, avg: 1.071034126097873
# 0.0017247308551252007
#  640 (25.60%) Train loss: 10.8247 	 Validation loss: 8.3067 	 Learning rate: 0.00172
# (LRBoost) 0.00010638326166425847, avgavg: 0.01636515688573549, avg: 1.0942074825230255
# 0.0017193832616642585
#  645 (25.80%) Train loss: 10.8014 	 Validation loss: 8.2935 	 Learning rate: 0.00172
# (LRBoost) 0.00010411041324864048, avgavg: 0.01636515688573549, avg: 1.1176237018644124
# 0.0017141104132486406
#  650 (26.00%) Train loss: 10.7779 	 Validation loss: 8.2798 	 Learning rate: 0.00171
# (LRBoost) 0.00010191049626766388, avgavg: 0.01636515688573549, avg: 1.1412678207497486
# 0.001708910496267664
#  655 (26.20%) Train loss: 10.7541 	 Validation loss: 8.2678 	 Learning rate: 0.00171
# (LRBoost) 9.978229994992717e-05, avgavg: 0.01636515688573549, avg: 1.1651172059033077
# 0.0017037822999499271
#  660 (26.40%) Train loss: 10.7300 	 Validation loss: 8.2532 	 Learning rate: 0.00170
# (LRBoost) 9.771973207908984e-05, avgavg: 0.01636515688573549, avg: 1.1892068937679192
# 0.0016987197320790899
#  665 (26.60%) Train loss: 10.7059 	 Validation loss: 8.2409 	 Learning rate: 0.00170
# (LRBoost) 9.57244233000667e-05, avgavg: 0.01636515688573549, avg: 1.2134821978590034
# 0.0016937244233000666
#  670 (26.80%) Train loss: 10.6814 	 Validation loss: 8.2268 	 Learning rate: 0.00169
# (LRBoost) 9.378825340835843e-05, avgavg: 0.01636515688573549, avg: 1.2380099200562094
# 0.0016887882534083584
#  675 (27.00%) Train loss: 10.6569 	 Validation loss: 8.2145 	 Learning rate: 0.00169
# (LRBoost) 9.191550780144911e-05, avgavg: 0.01636515688573549, avg: 1.2626997925567278
# 0.0016839155078014491
#  680 (27.20%) Train loss: 10.6320 	 Validation loss: 8.2013 	 Learning rate: 0.00168
# (LRBoost) 9.009771372418037e-05, avgavg: 0.01636515688573549, avg: 1.287630866174171
# 0.0016790977137241805
#  685 (27.40%) Train loss: 10.6069 	 Validation loss: 8.1872 	 Learning rate: 0.00168
# (LRBoost) 8.833925651972373e-05, avgavg: 0.01636515688573549, avg: 1.312706335336094
# 0.0016743392565197238
#  690 (27.60%) Train loss: 10.5819 	 Validation loss: 8.1775 	 Learning rate: 0.00167
# (LRBoost) 8.664047406642451e-05, avgavg: 0.01636515688573549, avg: 1.3378782545995365
# 0.0016696404740664246
#  695 (27.80%) Train loss: 10.5566 	 Validation loss: 8.1644 	 Learning rate: 0.00167
# (LRBoost) 8.499350075558522e-05, avgavg: 0.01636515688573549, avg: 1.3632255374937405
# 0.0016649935007555852
#  700 (28.00%) Train loss: 10.5312 	 Validation loss: 8.1520 	 Learning rate: 0.00166
# (LRBoost) 8.339687617710317e-05, avgavg: 0.01636515688573549, avg: 1.3887356528127097
# 0.0016603968761771033
#  705 (28.20%) Train loss: 10.5056 	 Validation loss: 8.1406 	 Learning rate: 0.00166
# (LRBoost) 8.185350576561052e-05, avgavg: 0.01636515688573549, avg: 1.414320849508814
# 0.0016558535057656107
#  710 (28.40%) Train loss: 10.4799 	 Validation loss: 8.1314 	 Learning rate: 0.00166
# (LRBoost) 8.036806432314008e-05, avgavg: 0.01636515688573549, avg: 1.4398508327108908
# 0.0016513680643231402
#  715 (28.60%) Train loss: 10.4543 	 Validation loss: 8.1183 	 Learning rate: 0.00165
# (LRBoost) 7.8928432252053e-05, avgavg: 0.01636515688573549, avg: 1.465491275678668
# 0.001646928432252053
#  720 (28.80%) Train loss: 10.4285 	 Validation loss: 8.1075 	 Learning rate: 0.00165
# (LRBoost) 7.752132896601593e-05, avgavg: 0.01636515688573549, avg: 1.4914583501065501
# 0.001642521328966016
#  725 (29.00%) Train loss: 10.4026 	 Validation loss: 8.0977 	 Learning rate: 0.00164
# (LRBoost) 7.615732622926914e-05, avgavg: 0.01636515688573549, avg: 1.517526200685435
# 0.0016381573262292692
#  730 (29.20%) Train loss: 10.3762 	 Validation loss: 8.0845 	 Learning rate: 0.00164
# (LRBoost) 7.482029304069461e-05, avgavg: 0.01636515688573549, avg: 1.5439881048524478
# 0.0016338202930406946
#  735 (29.40%) Train loss: 10.3497 	 Validation loss: 8.0750 	 Learning rate: 0.00163
# (LRBoost) 7.35257996012216e-05, avgavg: 0.01636515688573549, avg: 1.5705037906698416
# 0.0016295257996012218
#  740 (29.60%) Train loss: 10.3231 	 Validation loss: 8.0624 	 Learning rate: 0.00163
# (LRBoost) 7.226507361612737e-05, avgavg: 0.01636515688573549, avg: 1.5972231914994333
# 0.0016252650736161274
#  745 (29.80%) Train loss: 10.2962 	 Validation loss: 8.0486 	 Learning rate: 0.00163
# (LRBoost) 7.103296350587104e-05, avgavg: 0.01636515688573549, avg: 1.624236838082917
# 0.0016210329635058711
#  750 (30.00%) Train loss: 10.2691 	 Validation loss: 8.0347 	 Learning rate: 0.00162
# (LRBoost) 6.983600395879395e-05, avgavg: 0.01636515688573549, avg: 1.6513725590860635
# 0.0016168360039587942
#  755 (30.20%) Train loss: 10.2420 	 Validation loss: 8.0217 	 Learning rate: 0.00162
# (LRBoost) 6.867848632931713e-05, avgavg: 0.01636515688573549, avg: 1.6784901832338766
# 0.001612678486329317
#  760 (30.40%) Train loss: 10.2148 	 Validation loss: 8.0086 	 Learning rate: 0.00161
# (LRBoost) 6.755782968525193e-05, avgavg: 0.01636515688573549, avg: 1.7056064436838771
# 0.001608557829685252
#  765 (30.60%) Train loss: 10.1878 	 Validation loss: 7.9975 	 Learning rate: 0.00161
# (LRBoost) 6.647621404694523e-05, avgavg: 0.01636515688573549, avg: 1.7326193408136654
# 0.0016044762140469454
#  770 (30.80%) Train loss: 10.1608 	 Validation loss: 7.9864 	 Learning rate: 0.00160
# (LRBoost) 6.542768617404015e-05, avgavg: 0.01636515688573549, avg: 1.7596354910809766
# 0.0016004276861740403
#  775 (31.00%) Train loss: 10.1338 	 Validation loss: 7.9740 	 Learning rate: 0.00160
# (LRBoost) 6.441385417782943e-05, avgavg: 0.01636515688573549, avg: 1.7865688164348534
# 0.0015964138541778295
#  780 (31.20%) Train loss: 10.1069 	 Validation loss: 7.9620 	 Learning rate: 0.00160
# (LRBoost) 6.343398486664848e-05, avgavg: 0.01636515688573549, avg: 1.8133921113682732
# 0.0015924339848666484
#  785 (31.40%) Train loss: 10.0802 	 Validation loss: 7.9521 	 Learning rate: 0.00159
# (LRBoost) 6.248593292832126e-05, avgavg: 0.01636515688573549, avg: 1.8401196379843605
# 0.0015884859329283213
#  790 (31.60%) Train loss: 10.0535 	 Validation loss: 7.9397 	 Learning rate: 0.00159
# (LRBoost) 6.156654327540505e-05, avgavg: 0.01636515688573549, avg: 1.866801199060241
# 0.001584566543275405
#  795 (31.80%) Train loss: 10.0268 	 Validation loss: 7.9294 	 Learning rate: 0.00158
# (LRBoost) 6.067620107178744e-05, avgavg: 0.01636515688573549, avg: 1.893384874276191
# 0.0015806762010717875
#  800 (32.00%) Train loss: 10.0003 	 Validation loss: 7.9181 	 Learning rate: 0.00158
# (LRBoost) 5.981430636227381e-05, avgavg: 0.01636515688573549, avg: 1.9198468201185137
# 0.0015768143063622738
#  805 (32.20%) Train loss: 9.9739 	 Validation loss: 7.9090 	 Learning rate: 0.00158
# (LRBoost) 5.8980187189679604e-05, avgavg: 0.01636515688573549, avg: 1.9461655831542353
# 0.0015729801871896799
#  810 (32.40%) Train loss: 9.9477 	 Validation loss: 7.8966 	 Learning rate: 0.00157
# (LRBoost) 5.8171233976515553e-05, avgavg: 0.01636515688573549, avg: 1.9723857838775083
# 0.0015691712339765157
#  815 (32.60%) Train loss: 9.9216 	 Validation loss: 7.8866 	 Learning rate: 0.00157
# (LRBoost) 5.7391058933620835e-05, avgavg: 0.01636515688573549, avg: 1.9983429751293258
# 0.001565391058933621
#  820 (32.80%) Train loss: 9.8958 	 Validation loss: 7.8759 	 Learning rate: 0.00157
# (LRBoost) 5.663970935151329e-05, avgavg: 0.01636515688573549, avg: 2.023985032711228
# 0.0015616397093515134
#  825 (33.00%) Train loss: 9.8704 	 Validation loss: 7.8681 	 Learning rate: 0.00156
# (LRBoost) 5.5916324190380715e-05, avgavg: 0.01636515688573549, avg: 2.0492911537563594
# 0.0015579163241903808
#  830 (33.20%) Train loss: 9.8454 	 Validation loss: 7.8629 	 Learning rate: 0.00156
# (LRBoost) 5.5223319186220745e-05, avgavg: 0.01636515688573549, avg: 2.0741189542957152
# 0.0015542233191862208
#  835 (33.40%) Train loss: 9.8207 	 Validation loss: 7.8557 	 Learning rate: 0.00155
# (LRBoost) 5.455562808755234e-05, avgavg: 0.01636515688573549, avg: 2.098603601242897
# 0.0015505556280875524
#  840 (33.60%) Train loss: 9.7967 	 Validation loss: 7.8488 	 Learning rate: 0.00155
# (LRBoost) 5.392310832278424e-05, avgavg: 0.01636515688573549, avg: 2.1223098159864997
# 0.0015469231083227843
#  845 (33.80%) Train loss: 9.7735 	 Validation loss: 7.8447 	 Learning rate: 0.00155
# (LRBoost) 5.332455735865071e-05, avgavg: 0.01636515688573549, avg: 2.1452113678489533
# 0.0015433245573586508
#  850 (34.00%) Train loss: 9.7508 	 Validation loss: 7.8389 	 Learning rate: 0.00154
# (LRBoost) 5.274747698007689e-05, avgavg: 0.01636515688573549, avg: 2.167750150473021
# 0.001539747476980077
#  855 (34.20%) Train loss: 9.7285 	 Validation loss: 7.8356 	 Learning rate: 0.00154
# (LRBoost) 5.219142329006196e-05, avgavg: 0.01636515688573549, avg: 2.1899049400275694
# 0.001536191423290062
#  860 (34.40%) Train loss: 9.7066 	 Validation loss: 7.8320 	 Learning rate: 0.00154
# (LRBoost) 5.165399843599841e-05, avgavg: 0.01636515688573549, avg: 2.211738949132356
# 0.0015326539984359985
#  865 (34.60%) Train loss: 9.6849 	 Validation loss: 7.8281 	 Learning rate: 0.00153
# (LRBoost) 5.113473241659128e-05, avgavg: 0.01636515688573549, avg: 2.2332387274135805
# 0.0015291347324165915
#  870 (34.80%) Train loss: 9.6636 	 Validation loss: 7.8238 	 Learning rate: 0.00153
# (LRBoost) 5.063282821644871e-05, avgavg: 0.01636515688573549, avg: 2.254406346610577
# 0.0015256328282164488
#  875 (35.00%) Train loss: 9.6426 	 Validation loss: 7.8190 	 Learning rate: 0.00153
# (LRBoost) 5.01466128216304e-05, avgavg: 0.01636515688573549, avg: 2.275285754856258
# 0.0015221466128216305
#  880 (35.20%) Train loss: 9.6219 	 Validation loss: 7.8148 	 Learning rate: 0.00152
# (LRBoost) 4.9675689857324166e-05, avgavg: 0.01636515688573549, avg: 2.2958670259890774
# 0.0015186756898573242
#  885 (35.40%) Train loss: 9.6016 	 Validation loss: 7.8129 	 Learning rate: 0.00152
# (LRBoost) 4.922520739593652e-05, avgavg: 0.01636515688573549, avg: 2.315880194248689
# 0.0015152252073959366
#  890 (35.60%) Train loss: 9.5820 	 Validation loss: 7.8094 	 Learning rate: 0.00152
# (LRBoost) 4.879270514118093e-05, avgavg: 0.01636515688573549, avg: 2.3354021275447225
# 0.001511792705141181
#  895 (35.80%) Train loss: 9.5627 	 Validation loss: 7.8082 	 Learning rate: 0.00151
# (LRBoost) 4.837673446953781e-05, avgavg: 0.01636515688573549, avg: 2.354468385964357
# 0.0015083767344695378
#  900 (36.00%) Train loss: 9.5439 	 Validation loss: 7.8048 	 Learning rate: 0.00151
# (LRBoost) 4.797753909632065e-05, avgavg: 0.01636515688573549, avg: 2.3730353535951374
# 0.0015049775390963205
#  905 (36.20%) Train loss: 9.5256 	 Validation loss: 7.8047 	 Learning rate: 0.00150
# (LRBoost) 4.7595525654630786e-05, avgavg: 0.01636515688573549, avg: 2.391050406905889
# 0.0015015955256546308
#  910 (36.40%) Train loss: 9.5080 	 Validation loss: 7.8032 	 Learning rate: 0.00150
# (LRBoost) 4.723348793890061e-05, avgavg: 0.01636515688573549, avg: 2.408338034656585
# 0.0014982334879389007
#  915 (36.60%) Train loss: 9.4911 	 Validation loss: 7.7981 	 Learning rate: 0.00150
# (LRBoost) 4.688662679905119e-05, avgavg: 0.01636515688573549, avg: 2.4251074944975812
# 0.0014948866267990512
#  920 (36.80%) Train loss: 9.4747 	 Validation loss: 7.7997 	 Learning rate: 0.00149
# (LRBoost) 4.6550408578787895e-05, avgavg: 0.01636515688573549, avg: 2.4415685713921698
# 0.001491550408578788
#  925 (37.00%) Train loss: 9.4581 	 Validation loss: 7.7995 	 Learning rate: 0.00149
# (LRBoost) 4.6222948823292476e-05, avgavg: 0.01636515688573549, avg: 2.4578033637595924
# 0.0014882229488232927
#  930 (37.20%) Train loss: 9.4423 	 Validation loss: 7.7959 	 Learning rate: 0.00149
# (LRBoost) 4.590477142273969e-05, avgavg: 0.01636515688573549, avg: 2.4737695039227625
# 0.00148490477142274
#  935 (37.40%) Train loss: 9.4264 	 Validation loss: 7.7905 	 Learning rate: 0.00148
# (LRBoost) 4.559250588062882e-05, avgavg: 0.01636515688573549, avg: 2.4896356532069577
# 0.001481592505880629
#  940 (37.60%) Train loss: 9.4096 	 Validation loss: 7.7888 	 Learning rate: 0.00148
# (LRBoost) 4.526084891482124e-05, avgavg: 0.01636515688573549, avg: 2.5067941810444125
# 0.0014782608489148214
#  945 (37.80%) Train loss: 9.3923 	 Validation loss: 7.7890 	 Learning rate: 0.00148
# (LRBoost) 4.494844296018064e-05, avgavg: 0.01636515688573549, avg: 2.523124934908561
# 0.0014749484429601807
#  950 (38.00%) Train loss: 9.3774 	 Validation loss: 7.7835 	 Learning rate: 0.00147
# (LRBoost) 4.465569489423959e-05, avgavg: 0.01636515688573549, avg: 2.5385662907266267
# 0.0014716556948942397
#  955 (38.20%) Train loss: 9.3620 	 Validation loss: 7.7760 	 Learning rate: 0.00147
# (LRBoost) 4.436515753537128e-05, avgavg: 0.01636515688573549, avg: 2.5540841636027403
# 0.0014683651575353712
#  960 (38.40%) Train loss: 9.3468 	 Validation loss: 7.7771 	 Learning rate: 0.00147
# (LRBoost) 4.407969000573001e-05, avgavg: 0.01636515688573549, avg: 2.5695110558048833
# 0.00146507969000573
#  965 (38.60%) Train loss: 9.3308 	 Validation loss: 7.7800 	 Learning rate: 0.00147
# (LRBoost) 4.379352695258527e-05, avgavg: 0.01636515688573549, avg: 2.5851801216671526
# 0.0014617935269525852
#  970 (38.80%) Train loss: 9.3147 	 Validation loss: 7.7764 	 Learning rate: 0.00146
# (LRBoost) 4.3512439012937175e-05, avgavg: 0.01636515688573549, avg: 2.6007519328257964
# 0.0014585124390129372
#  975 (39.00%) Train loss: 9.3000 	 Validation loss: 7.7818 	 Learning rate: 0.00146
# (LRBoost) 4.324219765380536e-05, avgavg: 0.01636515688573549, avg: 2.615869926403923
# 0.0014552421976538055
#  980 (39.20%) Train loss: 9.2846 	 Validation loss: 7.7776 	 Learning rate: 0.00146
# (LRBoost) 4.2975966138886295e-05, avgavg: 0.01636515688573549, avg: 2.630932567243422
# 0.0014519759661388864
#  985 (39.40%) Train loss: 9.2694 	 Validation loss: 7.7824 	 Learning rate: 0.00145
# (LRBoost) 4.271633674913653e-05, avgavg: 0.01636515688573549, avg: 2.6457740071817804
# 0.0014487163367491367
#  990 (39.60%) Train loss: 9.2548 	 Validation loss: 7.7797 	 Learning rate: 0.00145
# (LRBoost) 4.246119809109537e-05, avgavg: 0.01636515688573549, avg: 2.660515554456835
# 0.0014454611980910955
#  995 (39.80%) Train loss: 9.2405 	 Validation loss: 7.7831 	 Learning rate: 0.00145
# (LRBoost) 4.2210345052719894e-05, avgavg: 0.01636515688573549, avg: 2.675163691994001
# 0.00144221034505272
# 1000 (40.00%) Train loss: 9.2256 	 Validation loss: 7.7798 	 Learning rate: 0.00144
# (LRBoost) 4.195941889794991e-05, avgavg: 0.01636515688573549, avg: 2.689991663503053
# 0.00143895941889795
# 1005 (40.20%) Train loss: 9.2096 	 Validation loss: 7.7774 	 Learning rate: 0.00144
# (LRBoost) 4.1686561515817906e-05, avgavg: 0.01636515688573549, avg: 2.706421145515937
# 0.001435686561515818
# 1010 (40.40%) Train loss: 9.1928 	 Validation loss: 7.7670 	 Learning rate: 0.00144
# (LRBoost) 4.139482630562298e-05, avgavg: 0.01636515688573549, avg: 2.7243089575250736
# 0.0014323948263056231
# 1015 (40.60%) Train loss: 9.1744 	 Validation loss: 7.7577 	 Learning rate: 0.00143
# (LRBoost) 4.110755720419324e-05, avgavg: 0.01636515688573549, avg: 2.742152740164466
# 0.0014291075572041931
# 1020 (40.80%) Train loss: 9.1569 	 Validation loss: 7.7463 	 Learning rate: 0.00143
# (LRBoost) 4.0826793478291304e-05, avgavg: 0.01636515688573549, avg: 2.7598078506508394
# 0.0014258267934782911
# 1025 (41.00%) Train loss: 9.1391 	 Validation loss: 7.7339 	 Learning rate: 0.00143
# (LRBoost) 4.055091407977419e-05, avgavg: 0.01636515688573549, avg: 2.7773728963561455
# 0.0014225509140797742
# 1030 (41.20%) Train loss: 9.1213 	 Validation loss: 7.7270 	 Learning rate: 0.00142
# (LRBoost) 4.02698969139889e-05, avgavg: 0.01636515688573549, avg: 2.795535197356513
# 0.001419269896913989
# 1035 (41.40%) Train loss: 9.1033 	 Validation loss: 7.7085 	 Learning rate: 0.00142
# (LRBoost) 3.997517041458509e-05, avgavg: 0.01636515688573549, avg: 2.8149177997065253
# 0.001415975170414585
# 1040 (41.60%) Train loss: 9.0830 	 Validation loss: 7.6969 	 Learning rate: 0.00142
# (LRBoost) 3.967364037087501e-05, avgavg: 0.01636515688573549, avg: 2.835074427861971
# 0.0014126736403708752
# 1045 (41.80%) Train loss: 9.0628 	 Validation loss: 7.6799 	 Learning rate: 0.00141
# (LRBoost) 3.9385078020863936e-05, avgavg: 0.01636515688573549, avg: 2.8545995959547072
# 0.001409385078020864
# 1050 (42.00%) Train loss: 9.0434 	 Validation loss: 7.6678 	 Learning rate: 0.00141
# (LRBoost) 3.910668181219652e-05, avgavg: 0.01636515688573549, avg: 2.8736657554847036
# 0.0014061066818121966
# 1055 (42.20%) Train loss: 9.0246 	 Validation loss: 7.6540 	 Learning rate: 0.00141
# (LRBoost) 3.8834030263628044e-05, avgavg: 0.01636515688573549, avg: 2.8925773632333263
# 0.0014028340302636283
# 1060 (42.40%) Train loss: 9.0066 	 Validation loss: 7.6424 	 Learning rate: 0.00140
# (LRBoost) 3.857499001025128e-05, avgavg: 0.01636515688573549, avg: 2.9107289817364177
# 0.0013995749900102515
# 1065 (42.60%) Train loss: 8.9878 	 Validation loss: 7.6256 	 Learning rate: 0.00140
# (LRBoost) 3.8314575947252204e-05, avgavg: 0.01636515688573549, avg: 2.9292310601814955
# 0.0013963145759472522
# 1070 (42.80%) Train loss: 8.9690 	 Validation loss: 7.6177 	 Learning rate: 0.00140
# (LRBoost) 3.80565447533252e-05, avgavg: 0.01636515688573549, avg: 2.947801782291724
# 0.0013930565447533253
# 1075 (43.00%) Train loss: 8.9506 	 Validation loss: 7.6025 	 Learning rate: 0.00139
# (LRBoost) 3.7797091428321576e-05, avgavg: 0.01636515688573549, avg: 2.966737670640893
# 0.0013897970914283216
# 1080 (43.20%) Train loss: 8.9315 	 Validation loss: 7.5857 	 Learning rate: 0.00139
# (LRBoost) 3.754217400332116e-05, avgavg: 0.01636515688573549, avg: 2.9855745567767813
# 0.001386542174003321
# 1085 (43.40%) Train loss: 8.9126 	 Validation loss: 7.5760 	 Learning rate: 0.00139
# (LRBoost) 3.728860970147973e-05, avgavg: 0.01636515688573549, avg: 3.004559969831732
# 0.0013832886097014797
# 1090 (43.60%) Train loss: 8.8938 	 Validation loss: 7.5589 	 Learning rate: 0.00138
# (LRBoost) 3.704620787069615e-05, avgavg: 0.01636515688573549, avg: 3.022894244937561
# 0.0013800462078706961
# 1095 (43.80%) Train loss: 8.8761 	 Validation loss: 7.5494 	 Learning rate: 0.00138
# (LRBoost) 3.68133447169459e-05, avgavg: 0.01636515688573549, avg: 3.0406819581080784
# 0.001376813344716946
# 1100 (44.00%) Train loss: 8.8586 	 Validation loss: 7.5390 	 Learning rate: 0.00138
# (LRBoost) 3.6591775027542404e-05, avgavg: 0.01636515688573549, avg: 3.057752118981812
# 0.0013735917750275425
# 1105 (44.20%) Train loss: 8.8418 	 Validation loss: 7.5279 	 Learning rate: 0.00137
# (LRBoost) 3.637957827571161e-05, avgavg: 0.01636515688573549, avg: 3.074238005441219
# 0.0013703795782757117
# 1110 (44.40%) Train loss: 8.8256 	 Validation loss: 7.5173 	 Learning rate: 0.00137
# (LRBoost) 3.617417889118678e-05, avgavg: 0.01636515688573549, avg: 3.0903365359785675
# 0.0013671741788911869
# 1115 (44.60%) Train loss: 8.8097 	 Validation loss: 7.5038 	 Learning rate: 0.00137
# (LRBoost) 3.597561376933349e-05, avgavg: 0.01636515688573549, avg: 3.1060287652702407
# 0.0013639756137693337
# 1120 (44.80%) Train loss: 8.7945 	 Validation loss: 7.4962 	 Learning rate: 0.00136
# (LRBoost) 3.578650996981462e-05, avgavg: 0.01636515688573549, avg: 3.121069806453756
# 0.0013607865099698148
# 1125 (45.00%) Train loss: 8.7799 	 Validation loss: 7.4919 	 Learning rate: 0.00136
# (LRBoost) 3.5607116343810596e-05, avgavg: 0.01636515688573549, avg: 3.13541538147876
# 0.0013576071163438107
# 1130 (45.20%) Train loss: 8.7661 	 Validation loss: 7.4879 	 Learning rate: 0.00136
# (LRBoost) 3.544004121656025e-05, avgavg: 0.01636515688573549, avg: 3.148811371914694
# 0.0013544400412165603
# 1135 (45.40%) Train loss: 8.7529 	 Validation loss: 7.4846 	 Learning rate: 0.00135
# (LRBoost) 3.527860662419911e-05, avgavg: 0.01636515688573549, avg: 3.161828655008718
# 0.0013512786066241993
# 1140 (45.60%) Train loss: 8.7403 	 Validation loss: 7.4805 	 Learning rate: 0.00135
# (LRBoost) 3.51241446828519e-05, avgavg: 0.01636515688573549, avg: 3.1743353430880745
# 0.0013481241446828519
# 1145 (45.80%) Train loss: 8.7283 	 Validation loss: 7.4813 	 Learning rate: 0.00135
# (LRBoost) 3.498719820912347e-05, avgavg: 0.01636515688573549, avg: 3.1853570476185546
# 0.0013449871982091233
# 1150 (46.00%) Train loss: 8.7183 	 Validation loss: 7.4801 	 Learning rate: 0.00134
# (LRBoost) 3.486152622639264e-05, avgavg: 0.01636515688573549, avg: 3.1954316112776953
# 0.0013418615262263927
# 1155 (46.20%) Train loss: 8.7082 	 Validation loss: 7.4775 	 Learning rate: 0.00134
# (LRBoost) 3.474157748207402e-05, avgavg: 0.01636515688573549, avg: 3.2050509942445173
# 0.0013387415774820742
# 1160 (46.40%) Train loss: 8.6989 	 Validation loss: 7.4820 	 Learning rate: 0.00134
# (LRBoost) 3.462894614382594e-05, avgavg: 0.01636515688573549, avg: 3.2140577283993053
# 0.001335628946143826
# 1165 (46.60%) Train loss: 8.6902 	 Validation loss: 7.4832 	 Learning rate: 0.00134
# (LRBoost) 3.452151097955579e-05, avgavg: 0.01636515688573549, avg: 3.222638098752809
# 0.001332521510979556
# 1170 (46.80%) Train loss: 8.6819 	 Validation loss: 7.4802 	 Learning rate: 0.00133
# (LRBoost) 3.441802999056725e-05, avgavg: 0.01636515688573549, avg: 3.2309008118433553
# 0.0013294180299905675
# 1175 (47.00%) Train loss: 8.6740 	 Validation loss: 7.4847 	 Learning rate: 0.00133
# (LRBoost) 3.4318052073935075e-05, avgavg: 0.01636515688573549, avg: 3.2388827118872725
# 0.0013263180520739352
# 1180 (47.20%) Train loss: 8.6659 	 Validation loss: 7.4833 	 Learning rate: 0.00133
# (LRBoost) 3.422073013057609e-05, avgavg: 0.01636515688573549, avg: 3.246659252252134
# 0.0013232207301305764
# 1185 (47.40%) Train loss: 8.6585 	 Validation loss: 7.4883 	 Learning rate: 0.00132
# (LRBoost) 3.412780829304302e-05, avgavg: 0.01636515688573549, avg: 3.2540605500658386
# 0.001320127808293043
# 1190 (47.60%) Train loss: 8.6512 	 Validation loss: 7.4872 	 Learning rate: 0.00132
# (LRBoost) 3.40379371077355e-05, avgavg: 0.01636515688573549, avg: 3.2612099494924083
# 0.0013170379371077357
# 1195 (47.80%) Train loss: 8.6443 	 Validation loss: 7.4895 	 Learning rate: 0.00132
# (LRBoost) 3.3951730351222955e-05, avgavg: 0.01636515688573549, avg: 3.2680444424326653
# 0.0013139517303512231
# 1200 (48.00%) Train loss: 8.6376 	 Validation loss: 7.4918 	 Learning rate: 0.00131
# (LRBoost) 3.3867668614407315e-05, avgavg: 0.01636515688573549, avg: 3.27470631289482
# 0.0013108676686144072
# 1205 (48.20%) Train loss: 8.6310 	 Validation loss: 7.4942 	 Learning rate: 0.00131
# (LRBoost) 3.378560488913921e-05, avgavg: 0.01636515688573549, avg: 3.281207280666706
# 0.001307785604889139
# 1210 (48.40%) Train loss: 8.6246 	 Validation loss: 7.4995 	 Learning rate: 0.00131
# (LRBoost) 3.3705814072959186e-05, avgavg: 0.01636515688573549, avg: 3.2875182018585973
# 0.0013047058140729592
# 1215 (48.60%) Train loss: 8.6183 	 Validation loss: 7.4986 	 Learning rate: 0.00130
# (LRBoost) 3.3627196390729066e-05, avgavg: 0.01636515688573549, avg: 3.2937441621863512
# 0.001301627196390729
# 1220 (48.80%) Train loss: 8.6123 	 Validation loss: 7.5023 	 Learning rate: 0.00130
# (LRBoost) 3.355091970589577e-05, avgavg: 0.01636515688573549, avg: 3.2997690466454173
# 0.0012985509197058957
# 1225 (49.00%) Train loss: 8.6062 	 Validation loss: 7.5035 	 Learning rate: 0.00130
# (LRBoost) 3.3475659437586595e-05, avgavg: 0.01636515688573549, avg: 3.3057210140300497
# 0.0012954756594375867
# 1230 (49.20%) Train loss: 8.6005 	 Validation loss: 7.5098 	 Learning rate: 0.00130
# (LRBoost) 3.340292843130144e-05, avgavg: 0.01636515688573549, avg: 3.311449043103451
# 0.0012924029284313017
# 1235 (49.40%) Train loss: 8.5948 	 Validation loss: 7.5098 	 Learning rate: 0.00129
# (LRBoost) 3.333159777526996e-05, avgavg: 0.01636515688573549, avg: 3.3170627062486644
# 0.0012893315977752702
# 1240 (49.60%) Train loss: 8.5892 	 Validation loss: 7.5114 	 Learning rate: 0.00129
# (LRBoost) 3.326142097005089e-05, avgavg: 0.01636515688573549, avg: 3.3225851820606294
# 0.001286261420970051
# 1245 (49.80%) Train loss: 8.5837 	 Validation loss: 7.5134 	 Learning rate: 0.00129
# (LRBoost) 3.319308576357931e-05, avgavg: 0.01636515688573549, avg: 3.3279463610436792
# 0.0012831930857635794
# 1250 (50.00%) Train loss: 8.5785 	 Validation loss: 7.5159 	 Learning rate: 0.00128
# (LRBoost) 3.3126823601298524e-05, avgavg: 0.01636515688573549, avg: 3.3331210633708084
# 0.0012801268236012986
# 1255 (50.20%) Train loss: 8.5735 	 Validation loss: 7.5185 	 Learning rate: 0.00128
# (LRBoost) 3.306261233789486e-05, avgavg: 0.01636515688573549, avg: 3.3381094303580796
# 0.001277062612337895
# 1260 (50.40%) Train loss: 8.5686 	 Validation loss: 7.5213 	 Learning rate: 0.00128
# (LRBoost) 3.299943152821233e-05, avgavg: 0.01636515688573549, avg: 3.3430128174307727
# 0.0012739994315282123
# 1265 (50.60%) Train loss: 8.5639 	 Validation loss: 7.5249 	 Learning rate: 0.00127
# (LRBoost) 3.2939956073206306e-05, avgavg: 0.01636515688573549, avg: 3.347558413588146
# 0.0012709399560732063
# 1270 (50.80%) Train loss: 8.5594 	 Validation loss: 7.5265 	 Learning rate: 0.00127
# (LRBoost) 3.288308092371659e-05, avgavg: 0.01636515688573549, avg: 3.3518553775760696
# 0.0012678830809237165
# 1275 (51.00%) Train loss: 8.5553 	 Validation loss: 7.5296 	 Learning rate: 0.00127
# (LRBoost) 3.282816808398366e-05, avgavg: 0.01636515688573549, avg: 3.3559666160147885
# 0.0012648281680839838
# 1280 (51.20%) Train loss: 8.5512 	 Validation loss: 7.5323 	 Learning rate: 0.00126
# (LRBoost) 3.277500591650629e-05, avgavg: 0.01636515688573549, avg: 3.3599121527131275
# 0.0012617750059165064
# 1285 (51.40%) Train loss: 8.5474 	 Validation loss: 7.5351 	 Learning rate: 0.00126
# (LRBoost) 3.2723184244905036e-05, avgavg: 0.01636515688573549, avg: 3.3637327098017678
# 0.0012587231842449051
# 1290 (51.60%) Train loss: 8.5436 	 Validation loss: 7.5377 	 Learning rate: 0.00126
# (LRBoost) 3.2672319053554025e-05, avgavg: 0.01636515688573549, avg: 3.3674668015593965
# 0.0012556723190535542
# 1295 (51.80%) Train loss: 8.5399 	 Validation loss: 7.5402 	 Learning rate: 0.00126
# (LRBoost) 3.2622290955354563e-05, avgavg: 0.01636515688573549, avg: 3.3711260322779864
# 0.0012526222909553548
# 1300 (52.00%) Train loss: 8.5363 	 Validation loss: 7.5425 	 Learning rate: 0.00125
# (LRBoost) 3.2573176727621064e-05, avgavg: 0.01636515688573549, avg: 3.3747018204789483
# 0.0012495731767276212
# 1305 (52.20%) Train loss: 8.5328 	 Validation loss: 7.5446 	 Learning rate: 0.00125
# ...
# (LRBoost) 2.820814807707009e-05, avgavg: 0.01636515688573549, avg: 3.6254016073494455
# 0.0007772081480770702
# 2085 (83.40%) Train loss: 8.2836 	 Validation loss: 7.6977 	 Learning rate: 0.00078
# (LRBoost) 2.818653214739947e-05, avgavg: 0.01636515688573549, avg: 3.62644008045291
# 0.0007741865321473996
# 2090 (83.60%) Train loss: 8.2825 	 Validation loss: 7.6976 	 Learning rate: 0.00077
# (LRBoost) 2.8164939441335565e-05, avgavg: 0.01636515688573549, avg: 3.6274771564998587
# 0.0007711649394413358
# 2095 (83.80%) Train loss: 8.2815 	 Validation loss: 7.6974 	 Learning rate: 0.00077
# (LRBoost) 2.8143345504915898e-05, avgavg: 0.01636515688573549, avg: 3.628515982549126
# 0.0007681433455049161
# 2100 (84.00%) Train loss: 8.2805 	 Validation loss: 7.6974 	 Learning rate: 0.00077
# (LRBoost) 2.8121776605374725e-05, avgavg: 0.01636515688573549, avg: 3.6295531725696306
# 0.0007651217766053747
# 2105 (84.20%) Train loss: 8.2794 	 Validation loss: 7.6972 	 Learning rate: 0.00077
# (LRBoost) 2.810020235788528e-05, avgavg: 0.01636515688573549, avg: 3.630592645787364
# 0.0007621002023578854
# 2110 (84.40%) Train loss: 8.2784 	 Validation loss: 7.6971 	 Learning rate: 0.00076
# (LRBoost) 2.807865852985949e-05, avgavg: 0.01636515688573549, avg: 3.631629781977628
# 0.0007590786585298596
# 2115 (84.60%) Train loss: 8.2773 	 Validation loss: 7.6970 	 Learning rate: 0.00076
# (LRBoost) 2.8057106492234433e-05, avgavg: 0.01636515688573549, avg: 3.632669573841136
# 0.0007560571064922346
# 2120 (84.80%) Train loss: 8.2763 	 Validation loss: 7.6967 	 Learning rate: 0.00076
# (LRBoost) 2.8035580568249324e-05, avgavg: 0.01636515688573549, avg: 3.633707579755851
# 0.0007530355805682495
# 2125 (85.00%) Train loss: 8.2753 	 Validation loss: 7.6966 	 Learning rate: 0.00075
# (LRBoost) 2.8014054762198004e-05, avgavg: 0.01636515688573549, avg: 3.634747165570866
# 0.0007500140547621982
# 2130 (85.20%) Train loss: 8.2742 	 Validation loss: 7.6964 	 Learning rate: 0.00075
# (LRBoost) 2.799254507354567e-05, avgavg: 0.01636515688573549, avg: 3.6357862568406234
# 0.0007469925450735457
# 2135 (85.40%) Train loss: 8.2732 	 Validation loss: 7.6962 	 Learning rate: 0.00075
# (LRBoost) 2.797104731668675e-05, avgavg: 0.01636515688573549, avg: 3.6368253948448
# 0.0007439710473166868
# 2140 (85.60%) Train loss: 8.2722 	 Validation loss: 7.6960 	 Learning rate: 0.00074
# (LRBoost) 2.794955132344655e-05, avgavg: 0.01636515688573549, avg: 3.637865901832177
# 0.0007409495513234466
# 2145 (85.80%) Train loss: 8.2711 	 Validation loss: 7.6958 	 Learning rate: 0.00074
# (LRBoost) 2.792808518077791e-05, avgavg: 0.01636515688573549, avg: 3.63890412115918
# 0.000737928085180778
# 2150 (86.00%) Train loss: 8.2701 	 Validation loss: 7.6957 	 Learning rate: 0.00074
# (LRBoost) 2.7906615132775324e-05, avgavg: 0.01636515688573549, avg: 3.639944447094905
# 0.0007349066151327755
# 2155 (86.20%) Train loss: 8.2690 	 Validation loss: 7.6954 	 Learning rate: 0.00073
# (LRBoost) 2.7885162507166884e-05, avgavg: 0.01636515688573549, avg: 3.640984100164684
# 0.0007318851625071671
# 2160 (86.40%) Train loss: 8.2680 	 Validation loss: 7.6952 	 Learning rate: 0.00073
# (LRBoost) 2.7863724328897867e-05, avgavg: 0.01636515688573549, avg: 3.642023465728846
# 0.0007288637243288979
# 2165 (86.60%) Train loss: 8.2670 	 Validation loss: 7.6949 	 Learning rate: 0.00073
# (LRBoost) 2.7842284915165563e-05, avgavg: 0.01636515688573549, avg: 3.643064593543451
# 0.0007258422849151657
# 2170 (86.80%) Train loss: 8.2659 	 Validation loss: 7.6947 	 Learning rate: 0.00073
# (LRBoost) 2.782087595786186e-05, avgavg: 0.01636515688573549, avg: 3.6441033366701716
# 0.0007228208759578619
# 2175 (87.00%) Train loss: 8.2649 	 Validation loss: 7.6945 	 Learning rate: 0.00072
# (LRBoost) 2.7799461521134267e-05, avgavg: 0.01636515688573549, avg: 3.645144398190473
# 0.0007197994615211344
# 2180 (87.20%) Train loss: 8.2638 	 Validation loss: 7.6942 	 Learning rate: 0.00072
# (LRBoost) 2.777806406386856e-05, avgavg: 0.01636515688573549, avg: 3.6461848360973024
# 0.0007167780640638687
# 2185 (87.40%) Train loss: 8.2628 	 Validation loss: 7.6940 	 Learning rate: 0.00072
# (LRBoost) 2.77566851017849e-05, avgavg: 0.01636515688573549, avg: 3.647224447873634
# 0.000713756685101785
# 2190 (87.60%) Train loss: 8.2618 	 Validation loss: 7.6938 	 Learning rate: 0.00071
# (LRBoost) 2.773530887557459e-05, avgavg: 0.01636515688573549, avg: 3.6482653024864233
# 0.0007107353088755746
# 2195 (87.80%) Train loss: 8.2607 	 Validation loss: 7.6935 	 Learning rate: 0.00071
# (LRBoost) 2.7713944367675985e-05, avgavg: 0.01636515688573549, avg: 3.6493062197167987
# 0.0007077139443676761
# 2200 (88.00%) Train loss: 8.2597 	 Validation loss: 7.6933 	 Learning rate: 0.00071
# (LRBoost) 2.769264209196478e-05, avgavg: 0.01636515688573549, avg: 3.650340539825899
# 0.0007046926420919649
# 2205 (88.20%) Train loss: 8.2586 	 Validation loss: 7.6931 	 Learning rate: 0.00070
# (LRBoost) 2.7671302011608098e-05, avgavg: 0.01636515688573549, avg: 3.651381440965275
# 0.0007016713020116082
# 2210 (88.40%) Train loss: 8.2576 	 Validation loss: 7.6928 	 Learning rate: 0.00070
# (LRBoost) 2.765001693782433e-05, avgavg: 0.01636515688573549, avg: 3.6524166827443594
# 0.0006986500169378245
# 2215 (88.60%) Train loss: 8.2566 	 Validation loss: 7.6926 	 Learning rate: 0.00070
# (LRBoost) 2.762872147371741e-05, avgavg: 0.01636515688573549, avg: 3.6534548935693154
# 0.0006956287214737176
# 2220 (88.80%) Train loss: 8.2555 	 Validation loss: 7.6924 	 Learning rate: 0.00070
# (LRBoost) 2.7607455295786327e-05, avgavg: 0.01636515688573549, avg: 3.6544908293651437
# 0.0006926074552957863
# 2225 (89.00%) Train loss: 8.2545 	 Validation loss: 7.6920 	 Learning rate: 0.00069
# (LRBoost) 2.7586181485135767e-05, avgavg: 0.01636515688573549, avg: 3.655529373800384
# 0.0006895861814851358
# 2230 (89.20%) Train loss: 8.2535 	 Validation loss: 7.6919 	 Learning rate: 0.00069
# (LRBoost) 2.756496082053506e-05, avgavg: 0.01636515688573549, avg: 3.656562471300782
# 0.0006865649608205352
# 2235 (89.40%) Train loss: 8.2524 	 Validation loss: 7.6916 	 Learning rate: 0.00069
# (LRBoost) 2.754371859117811e-05, avgavg: 0.01636515688573549, avg: 3.6576000243066176
# 0.0006835437185911782
# 2240 (89.60%) Train loss: 8.2514 	 Validation loss: 7.6913 	 Learning rate: 0.00068
# (LRBoost) 2.752257344625776e-05, avgavg: 0.01636515688573549, avg: 3.658626273249965
# 0.000680522573446258
# 2245 (89.80%) Train loss: 8.2504 	 Validation loss: 7.6913 	 Learning rate: 0.00068
# (LRBoost) 2.7501473962260674e-05, avgavg: 0.01636515688573549, avg: 3.659648024152665
# 0.0006775014739622609
# 2250 (90.00%) Train loss: 8.2493 	 Validation loss: 7.6911 	 Learning rate: 0.00068
# (LRBoost) 2.748038112969763e-05, avgavg: 0.01636515688573549, avg: 3.6606704580200615
# 0.0006744803811296977
# 2255 (90.20%) Train loss: 8.2483 	 Validation loss: 7.6910 	 Learning rate: 0.00067
# (LRBoost) 2.7459296915409847e-05, avgavg: 0.01636515688573549, avg: 3.6616933134050043
# 0.0006714592969154099
# 2260 (90.40%) Train loss: 8.2473 	 Validation loss: 7.6909 	 Learning rate: 0.00067
# (LRBoost) 2.7438281084801214e-05, avgavg: 0.01636515688573549, avg: 3.6627086122742014
# 0.0006684382810848013
# 2265 (90.60%) Train loss: 8.2463 	 Validation loss: 7.6908 	 Learning rate: 0.00067
# (LRBoost) 2.741721899980506e-05, avgavg: 0.01636515688573549, avg: 3.6637316485438816
# 0.0006654172189998051
# 2270 (90.80%) Train loss: 8.2453 	 Validation loss: 7.6907 	 Learning rate: 0.00067
# (LRBoost) 2.7396247099423723e-05, avgavg: 0.01636515688573549, avg: 3.6647441939629433
# 0.0006623962470994239
# 2275 (91.00%) Train loss: 8.2443 	 Validation loss: 7.6906 	 Learning rate: 0.00066
# (LRBoost) 2.7375255888146733e-05, avgavg: 0.01636515688573549, avg: 3.6657608766601983
# 0.000659375255888147
# 2280 (91.20%) Train loss: 8.2432 	 Validation loss: 7.6906 	 Learning rate: 0.00066
# (LRBoost) 2.7354313558015716e-05, avgavg: 0.01636515688573549, avg: 3.666772567329916
# 0.0006563543135580158
# 2285 (91.40%) Train loss: 8.2422 	 Validation loss: 7.6904 	 Learning rate: 0.00066
# (LRBoost) 2.733336569278895e-05, avgavg: 0.01636515688573549, avg: 3.6677865510160785
# 0.000653333365692789
# 2290 (91.60%) Train loss: 8.2412 	 Validation loss: 7.6904 	 Learning rate: 0.00065
# (LRBoost) 2.7312447432195995e-05, avgavg: 0.01636515688573549, avg: 3.6687981133919862
# 0.0006503124474321961
# 2295 (91.80%) Train loss: 8.2402 	 Validation loss: 7.6903 	 Learning rate: 0.00065
# (LRBoost) 2.729155660672447e-05, avgavg: 0.01636515688573549, avg: 3.669807537325434
# 0.0006472915566067246
# 2300 (92.00%) Train loss: 8.2392 	 Validation loss: 7.6901 	 Learning rate: 0.00065
# (LRBoost) 2.7270646692546855e-05, avgavg: 0.01636515688573549, avg: 3.6708210772795185
# 0.000644270646692547
# 2305 (92.20%) Train loss: 8.2382 	 Validation loss: 7.6902 	 Learning rate: 0.00064
# (LRBoost) 2.7249799934597894e-05, avgavg: 0.01636515688573549, avg: 3.6718276625711765
# 0.000641249799934598
# 2310 (92.40%) Train loss: 8.2372 	 Validation loss: 7.6901 	 Learning rate: 0.00064
# (LRBoost) 2.7228960000050514e-05, avgavg: 0.01636515688573549, avg: 3.6728348687773633
# 0.0006382289600000505
# 2315 (92.60%) Train loss: 8.2362 	 Validation loss: 7.6899 	 Learning rate: 0.00064
# (LRBoost) 2.7208109517110324e-05, avgavg: 0.01636515688573549, avg: 3.6738450422368274
# 0.0006352081095171104
# 2320 (92.80%) Train loss: 8.2352 	 Validation loss: 7.6899 	 Learning rate: 0.00064
# (LRBoost) 2.71873400864604e-05, avgavg: 0.01636515688573549, avg: 3.6748458094718557
# 0.0006321873400864605
# 2325 (93.00%) Train loss: 8.2342 	 Validation loss: 7.6900 	 Learning rate: 0.00063
# (LRBoost) 2.716657427503053e-05, avgavg: 0.01636515688573549, avg: 3.6758476172147296
# 0.0006291665742750306
# 2330 (93.20%) Train loss: 8.2332 	 Validation loss: 7.6901 	 Learning rate: 0.00063
# (LRBoost) 2.7145838649341828e-05, avgavg: 0.01636515688573549, avg: 3.67684686906959
# 0.000626145838649342
# 2335 (93.40%) Train loss: 8.2322 	 Validation loss: 7.6898 	 Learning rate: 0.00063
# (LRBoost) 2.712514843007918e-05, avgavg: 0.01636515688573549, avg: 3.677841492097312
# 0.0006231251484300794
# 2340 (93.60%) Train loss: 8.2312 	 Validation loss: 7.6906 	 Learning rate: 0.00062
# (LRBoost) 2.710458268799448e-05, avgavg: 0.01636515688573549, avg: 3.678820738640354
# 0.0006201045826879947
# 2345 (93.80%) Train loss: 8.2302 	 Validation loss: 7.6902 	 Learning rate: 0.00062
# (LRBoost) 2.7083913953233588e-05, avgavg: 0.01636515688573549, avg: 3.6798154656014974
# 0.0006170839139532337
# 2350 (94.00%) Train loss: 8.2292 	 Validation loss: 7.6910 	 Learning rate: 0.00062
# (LRBoost) 2.7063411501051494e-05, avgavg: 0.01636515688573549, avg: 3.6807890963636125
# 0.0006140634115010515
# 2355 (94.20%) Train loss: 8.2282 	 Validation loss: 7.6903 	 Learning rate: 0.00061
# (LRBoost) 2.7042850762990658e-05, avgavg: 0.01636515688573549, avg: 3.68177213879665
# 0.0006110428507629908
# 2360 (94.40%) Train loss: 8.2273 	 Validation loss: 7.6908 	 Learning rate: 0.00061
# (LRBoost) 2.7022380616855714e-05, avgavg: 0.01636515688573549, avg: 3.682744330826361
# 0.0006080223806168559
# 2365 (94.60%) Train loss: 8.2263 	 Validation loss: 7.6909 	 Learning rate: 0.00061
# (LRBoost) 2.700190742530474e-05, avgavg: 0.01636515688573549, avg: 3.68371841236241
# 0.0006050019074253049
# 2370 (94.80%) Train loss: 8.2253 	 Validation loss: 7.6909 	 Learning rate: 0.00061
# (LRBoost) 2.6981455253277413e-05, avgavg: 0.01636515688573549, avg: 3.6846911016323647
# 0.0006019814552532776
# 2375 (95.00%) Train loss: 8.2243 	 Validation loss: 7.6914 	 Learning rate: 0.00060
# (LRBoost) 2.6961092627805963e-05, avgavg: 0.01636515688573549, avg: 3.6856530253415145
# 0.000598961092627806
# 2380 (95.20%) Train loss: 8.2234 	 Validation loss: 7.6909 	 Learning rate: 0.00060
# (LRBoost) 2.694069778983845e-05, avgavg: 0.01636515688573549, avg: 3.686620811172547
# 0.0005959406977898385
# 2385 (95.40%) Train loss: 8.2224 	 Validation loss: 7.6912 	 Learning rate: 0.00060
# (LRBoost) 2.692031942576524e-05, avgavg: 0.01636515688573549, avg: 3.687587806772453
# 0.0005929203194257654
# 2390 (95.60%) Train loss: 8.2215 	 Validation loss: 7.6916 	 Learning rate: 0.00059
# (LRBoost) 2.6900039554488777e-05, avgavg: 0.01636515688573549, avg: 3.688542762074016
# 0.0005899000395544889
# 2395 (95.80%) Train loss: 8.2205 	 Validation loss: 7.6913 	 Learning rate: 0.00059
# (LRBoost) 2.6879771042495813e-05, avgavg: 0.01636515688573549, avg: 3.6894975991710965
# 0.000586879771042496
# 2400 (96.00%) Train loss: 8.2195 	 Validation loss: 7.6911 	 Learning rate: 0.00059
# (LRBoost) 2.685950229631502e-05, avgavg: 0.01636515688573549, avg: 3.6904539095089293
# 0.0005838595022963153
# 2405 (96.20%) Train loss: 8.2186 	 Validation loss: 7.6913 	 Learning rate: 0.00058
# (LRBoost) 2.683926017765444e-05, avgavg: 0.01636515688573549, avg: 3.6914080019511575
# 0.0005808392601776545
# 2410 (96.40%) Train loss: 8.2176 	 Validation loss: 7.6915 	 Learning rate: 0.00058
# (LRBoost) 2.6819084621504013e-05, avgavg: 0.01636515688573549, avg: 3.692354370521096
# 0.0005778190846215041
# 2415 (96.60%) Train loss: 8.2167 	 Validation loss: 7.6916 	 Learning rate: 0.00058
# (LRBoost) 2.6798928869371458e-05, avgavg: 0.01636515688573549, avg: 3.6932994347415344
# 0.0005747989288693716
# 2420 (96.80%) Train loss: 8.2157 	 Validation loss: 7.6917 	 Learning rate: 0.00057
# (LRBoost) 2.6778799566485246e-05, avgavg: 0.01636515688573549, avg: 3.6942422728344653
# 0.0005717787995664854
# 2425 (97.00%) Train loss: 8.2148 	 Validation loss: 7.6915 	 Learning rate: 0.00057
# (LRBoost) 2.6758699421145417e-05, avgavg: 0.01636515688573549, avg: 3.695182502983598
# 0.0005687586994211456
# 2430 (97.20%) Train loss: 8.2139 	 Validation loss: 7.6915 	 Learning rate: 0.00057
# (LRBoost) 2.673862463688921e-05, avgavg: 0.01636515688573549, avg: 3.696120641022412
# 0.0005657386246368894
# 2435 (97.40%) Train loss: 8.2129 	 Validation loss: 7.6916 	 Learning rate: 0.00057
# (LRBoost) 2.671858807855328e-05, avgavg: 0.01636515688573549, avg: 3.6970548994536556
# 0.0005627185880785533
# 2440 (97.60%) Train loss: 8.2120 	 Validation loss: 7.6917 	 Learning rate: 0.00056
# (LRBoost) 2.6698579475123103e-05, avgavg: 0.01636515688573549, avg: 3.6979866881545775
# 0.0005596985794751231
# 2445 (97.80%) Train loss: 8.2111 	 Validation loss: 7.6917 	 Learning rate: 0.00056
# (LRBoost) 2.6678603945564496e-05, avgavg: 0.01636515688573549, avg: 3.6989152889085704
# 0.0005566786039455646
# 2450 (98.00%) Train loss: 8.2101 	 Validation loss: 7.6917 	 Learning rate: 0.00056
# (LRBoost) 2.6658657666991278e-05, avgavg: 0.01636515688573549, avg: 3.699841221655163
# 0.0005536586576669915
# 2455 (98.20%) Train loss: 8.2092 	 Validation loss: 7.6919 	 Learning rate: 0.00055
# (LRBoost) 2.663874932712398e-05, avgavg: 0.01636515688573549, avg: 3.700763270417171
# 0.0005506387493271241
# 2460 (98.40%) Train loss: 8.2083 	 Validation loss: 7.6920 	 Learning rate: 0.00055
# (LRBoost) 2.661886828642294e-05, avgavg: 0.01636515688573549, avg: 3.701682902096607
# 0.0005476188682864232
# 2465 (98.60%) Train loss: 8.2074 	 Validation loss: 7.6920 	 Learning rate: 0.00055
# (LRBoost) 2.659902591064314e-05, avgavg: 0.01636515688573549, avg: 3.7025985263223062
# 0.0005445990259106432
# 2470 (98.80%) Train loss: 8.2065 	 Validation loss: 7.6918 	 Learning rate: 0.00054
# (LRBoost) 2.6579215198442956e-05, avgavg: 0.01636515688573549, avg: 3.7035111056802563
# 0.000541579215198443
# 2475 (99.00%) Train loss: 8.2056 	 Validation loss: 7.6919 	 Learning rate: 0.00054
# (LRBoost) 2.6559430603732176e-05, avgavg: 0.01636515688573549, avg: 3.7044214036432037
# 0.0005385594306037322
# 2480 (99.20%) Train loss: 8.2046 	 Validation loss: 7.6919 	 Learning rate: 0.00054
# (LRBoost) 2.6539675974933253e-05, avgavg: 0.01636515688573549, avg: 3.7053288751251188
# 0.0005355396759749334
# 2485 (99.40%) Train loss: 8.2037 	 Validation loss: 7.6918 	 Learning rate: 0.00054
# (LRBoost) 2.651996072663765e-05, avgavg: 0.01636515688573549, avg: 3.7062321950198838
# 0.0005325199607266379
# 2490 (99.60%) Train loss: 8.2028 	 Validation loss: 7.6918 	 Learning rate: 0.00053
# (LRBoost) 2.6500266305916176e-05, avgavg: 0.01636515688573549, avg: 3.707133945410129
# 0.0005295002663059164
# 2495 (99.80%) Train loss: 8.2019 	 Validation loss: 7.6916 	 Learning rate: 0.00053

# %%
plt.plot(range(len(train_loss)), train_loss);
plt.plot(range(len(val_loss)), val_loss);

# %%
figure, axe = plt.subplots()
color = 'blue'
axe.set_xlabel('Epoch')
axe.set_ylabel('Loss', color=color)
axe.plot(range(len(train_loss)-10), train_loss[10:], zorder=2, label=["Training Loss"])
axe.plot(range(len(val_loss)-10), val_loss[10:], zorder=2, label=["Validation Loss"])
axe.tick_params(axis='y', labelcolor=color)

axe2 = axe.twinx()


color = 'red'
axe2.set_ylabel("Learning rate", color=color)
axe2.plot(range(len(learningrate_history)-10), learningrate_history[10:], zorder=2, label="Learning rate", c='red', alpha=0.0)

#plt.figure(figsize=(12,8))
# plt.plot(range(len(train_loss)-10), train_loss[10:], zorder=2, label=["Training Loss"])
# plt.plot(range(len(val_loss)-10), val_loss[10:], zorder=2, label=["Validation Loss"])
# plt.plot(range(len(learningrate_history)-10), learningrate_history[10:], zorder=2, label="Learning rate", c='red')
# plt.grid(alpha=0.3, zorder=1)
plt.legend()
plt.show()

# %% [markdown]
# # Testing
#
# We have kept the calculation of the test error separate in order to emphasize that you should not use the test set in optimization.

# %%
output_test = forward(x_test, NN)

# %%
y_test_np = Var_to_nparray(y_test)
plt.scatter(y_test_np, Var_to_nparray(output_test));
plt.plot([np.min(y_test_np), np.max(y_test_np)], [np.min(y_test_np), np.max(y_test_np)], color='k');
plt.xlabel("y");
plt.ylabel("$\hat{y}$");
plt.title("Model prediction vs real in the test set, the close to the line the better")
plt.grid(True);
plt.axis('equal');
plt.tight_layout();

Loss_test = squared_loss(y_test, forward(x_test, NN))

print("Test loss:  {:4.3f}".format(Loss_test.v))
# Out:
# Test loss:  8.779

# %%
x_test_np = Var_to_nparray(x_test)
x_train_np = Var_to_nparray(x_train)
y_train_np = Var_to_nparray(y_train)
if D1:
    plt.scatter(x_train_np, y_train_np, label="train data");
    plt.scatter(x_test_np, Var_to_nparray(output_test), label="test prediction");
    plt.scatter(x_test_np, y_test_np, label="test data");
    plt.legend();
    plt.xlabel("x");
    plt.ylabel("y");
else:
    plt.scatter(x_train_np[:,1], y_train, label="train data");
    plt.scatter(x_test_np[:,1], Var_to_nparray(output_test), label="test data prediction");
    plt.scatter(x_test_np[:,1], y_test_np, label="test data");
    plt.legend();
    plt.xlabel("x");
    plt.ylabel("y");

# %% [markdown]
# ## Exercise l) Show overfitting, underfitting and just right fitting
#
# Vary the architecture and other things to show clear signs of overfitting (=training loss significantly lower than test loss) and underfitting (=not fitting enoung to training data so that test performance is also hurt).
#
# See also if you can get a good compromise which leads to a low validation loss.
#
# For this problem do you see any big difference between validation and test loss? The answer here will probably be no. Discuss cases where it is important to keep the two separate.
#
# _Insert written answer here._

# %%
# Insert your code for getting overfitting, underfitting and just right fitting

# %% [markdown]
# # Next steps - classification
#
# It is straight forward to extend what we have done to classification.
#
# For numerical stability it is better to make softmax and cross-entropy as one function so we write the cross entropy loss as a function of the logits we talked about last week.
#
# Next week we will see how to perform classification in PyTorch.

# %% [markdown]
# ## Exercise m) optional - Implement backpropagation for classification
#
# Should be possible with very few lines of code. :-)

# %%
# Just add code.

# %% [markdown]
# ## Exercise n) optional - Introduce a NeuralNetwork class
#
# The functions we applied on the neural network (parameters, update_parameters and zero_gradients) can more naturally be included as methods in a NeuralNetwork class. Make such a class and modify the code to use it.

# %%
# just add some code
